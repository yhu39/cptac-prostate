# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import re,sys,os
import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib

# Set font to Arial
matplotlib.rcParams['font.family'] = 'Arial'

# Optional: Set PDF to embed fonts (for Illustrator editing)
matplotlib.rcParams['pdf.fonttype'] = 42  # TrueType fonts for better editing

# %%
DATA_DIR = Path(r"D:\lab\cptac_prostate\data\v4\CPTAC")
OUTPUT_DIR = Path(r"D:\lab\cptac_prostate\runs\20260330_cptac_phospho_tmt_normalized_pca")
print(DATA_DIR.exists(), OUTPUT_DIR.exists())
meta_path = DATA_DIR / "20_MetaData_03_12_2026.csv"
# Out:
# True False

# %%
meta = pd.read_csv(meta_path)
meta
# Out:
#         case_id     common_ID Tissuetype include_or_excludetumor  \
# 0     C3L-07287   C3L.07287.T      tumor                 Include
# 1     C3L-11156   C3L.11156.T      tumor                 Include
# 2     C3L-09494   C3L.09494.T      tumor                 Include
# 3    CHTN-49141  CHTN.49141.T      tumor                 Include
# 4     C3L-11095   C3L.11095.T      tumor                 Include
# ..          ...           ...        ...                     ...
# 178   C3L-07872   C3L.07872.T      tumor                 Include
# 179   C3L-08642   C3L.08642.T      tumor                 Include
# 180   C3L-10399   C3L.10399.T      tumor                 Include
# 181   C3L-05301   C3L.05301.T      tumor                 Include
# 182   C3L-08384   C3L.08384.T      tumor                 Include
#
#          FirstCategory AdditionalSegments SecondCategory ThirdCategory  \
# 0    Sufficient Purity                ETS            ETS           NaN
# 1    Sufficient Purity                ETS            ETS           NaN
# 2    Sufficient Purity                ETS            ETS           NaN
# 3    Sufficient Purity                ETS            ETS           NaN
# 4    Sufficient Purity                ETS            ETS           NaN
# ..                 ...                ...            ...           ...
# 178         Low Purity                NaN            NaN           NaN
# 179         Low Purity                NaN            NaN           NaN
# 180         Low Purity                NaN            NaN           NaN
# 181         Low Purity                NaN            NaN           NaN
# 182         Low Purity                NaN            NaN           NaN
#
#     all_drivers Main_Groups  ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  \
# 0           ERG         ERG  ...    0.342000      0.000000   0.0   0.0   1.0
# 1           ERG         ERG  ...    0.000000      0.498000   0.0   0.0   1.0
# 2           ERG         ERG  ...    0.281000      0.000000   0.0   1.0   0.0
# 3           ERG         ERG  ...    0.420000      0.000000   0.0   1.0   0.0
# 4           ERG         ERG  ...    0.000000      0.369000   0.0   0.0   1.0
# ..          ...         ...  ...         ...           ...   ...   ...   ...
# 178         ERG         ERG  ...    0.000000      0.460832   1.0   0.0   0.0
# 179         ERG         ERG  ...    0.000000      0.334840   0.0   0.0   1.0
# 180         ERG         ERG  ...    0.000000      0.445334   0.0   0.0   1.0
# 181        ETV1        ETV1  ...    0.000000      0.457908   0.0   0.0   1.0
# 182         ERG         ERG  ...    0.789835      0.000000   0.0   0.0   0.0
#
#      LumB  Normal  agg_rank_raw  agg_rank_scaled  risk_group
# 0     0.0     0.0     55.333000         0.409000          IR
# 1     0.0     0.0     44.167000         0.325000          LR
# 2     0.0     0.0    123.167000         0.919000          HR
# 3     0.0     0.0    103.833000         0.773000          HR
# 4     0.0     0.0     44.667000         0.328000          LR
# ..    ...     ...           ...              ...         ...
# 178   0.0     0.0     73.666667         0.546366          IR
# 179   0.0     0.0     46.166667         0.339599          LR
# 180   0.0     0.0     60.000000         0.443609          IR
# 181   0.0     0.0     45.333333         0.333333          LR
# 182   1.0     0.0     88.166667         0.655000          HR
#
# [183 rows x 113 columns]

# %%
meta_include = meta[meta["include_or_excludetumor"] == "Include"]
meta_include
# Out:
#         case_id     common_ID Tissuetype include_or_excludetumor  \
# 0     C3L-07287   C3L.07287.T      tumor                 Include
# 1     C3L-11156   C3L.11156.T      tumor                 Include
# 2     C3L-09494   C3L.09494.T      tumor                 Include
# 3    CHTN-49141  CHTN.49141.T      tumor                 Include
# 4     C3L-11095   C3L.11095.T      tumor                 Include
# ..          ...           ...        ...                     ...
# 178   C3L-07872   C3L.07872.T      tumor                 Include
# 179   C3L-08642   C3L.08642.T      tumor                 Include
# 180   C3L-10399   C3L.10399.T      tumor                 Include
# 181   C3L-05301   C3L.05301.T      tumor                 Include
# 182   C3L-08384   C3L.08384.T      tumor                 Include
#
#          FirstCategory AdditionalSegments SecondCategory ThirdCategory  \
# 0    Sufficient Purity                ETS            ETS           NaN
# 1    Sufficient Purity                ETS            ETS           NaN
# 2    Sufficient Purity                ETS            ETS           NaN
# 3    Sufficient Purity                ETS            ETS           NaN
# 4    Sufficient Purity                ETS            ETS           NaN
# ..                 ...                ...            ...           ...
# 178         Low Purity                NaN            NaN           NaN
# 179         Low Purity                NaN            NaN           NaN
# 180         Low Purity                NaN            NaN           NaN
# 181         Low Purity                NaN            NaN           NaN
# 182         Low Purity                NaN            NaN           NaN
#
#     all_drivers Main_Groups  ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  \
# 0           ERG         ERG  ...    0.342000      0.000000   0.0   0.0   1.0
# 1           ERG         ERG  ...    0.000000      0.498000   0.0   0.0   1.0
# 2           ERG         ERG  ...    0.281000      0.000000   0.0   1.0   0.0
# 3           ERG         ERG  ...    0.420000      0.000000   0.0   1.0   0.0
# 4           ERG         ERG  ...    0.000000      0.369000   0.0   0.0   1.0
# ..          ...         ...  ...         ...           ...   ...   ...   ...
# 178         ERG         ERG  ...    0.000000      0.460832   1.0   0.0   0.0
# 179         ERG         ERG  ...    0.000000      0.334840   0.0   0.0   1.0
# 180         ERG         ERG  ...    0.000000      0.445334   0.0   0.0   1.0
# 181        ETV1        ETV1  ...    0.000000      0.457908   0.0   0.0   1.0
# 182         ERG         ERG  ...    0.789835      0.000000   0.0   0.0   0.0
#
#      LumB  Normal  agg_rank_raw  agg_rank_scaled  risk_group
# 0     0.0     0.0     55.333000         0.409000          IR
# 1     0.0     0.0     44.167000         0.325000          LR
# 2     0.0     0.0    123.167000         0.919000          HR
# 3     0.0     0.0    103.833000         0.773000          HR
# 4     0.0     0.0     44.667000         0.328000          LR
# ..    ...     ...           ...              ...         ...
# 178   0.0     0.0     73.666667         0.546366          IR
# 179   0.0     0.0     46.166667         0.339599          LR
# 180   0.0     0.0     60.000000         0.443609          IR
# 181   0.0     0.0     45.333333         0.333333          LR
# 182   1.0     0.0     88.166667         0.655000          HR
#
# [134 rows x 113 columns]

# %%
purity_map = dict(zip(meta_include["common_ID"], meta_include["FirstCategory"]))
stage_map = dict(zip(meta_include["common_ID"], meta_include["stage"]))
gleason_map = dict(zip(meta_include["common_ID"], meta_include["Gleason_um"]))

# %%
meta_exclude = meta[meta["include_or_excludetumor"] == "exclude"]
meta_exclude
# Out:
#        case_id    common_ID Tissuetype include_or_excludetumor FirstCategory  \
# 144  C3L-09492  C3L.09492.T      tumor                 exclude      No Tumor
# 145  C3L-09497  C3L.09497.T      tumor                 exclude      No Tumor
# 146  C3L-06260  C3L.06260.T      tumor                 exclude      No Tumor
# 147  C3L-06510  C3L.06510.T      tumor                 exclude      No Tumor
# 148  C3L-07890  C3L.07890.T      tumor                 exclude      No Tumor
# 149  C3L-09372  C3L.09372.T      tumor                 exclude      No Tumor
# 150  C3N-09047  C3N.09047.T      tumor                 exclude      No Tumor
# 151  C3L-07868  C3L.07868.T      tumor                 exclude      No Tumor
# 152  C3L-09563  C3L.09563.T      tumor                 exclude      No Tumor
# 153  C3L-10319  C3L.10319.T      tumor                 exclude      No Tumor
# 154  C3L-06657  C3L.06657.T      tumor                 exclude      No Tumor
# 155  C3L-07405  C3L.07405.T      tumor                 exclude      No Tumor
# 156  C3L-06573  C3L.06573.T      tumor                 exclude      No Tumor
# 157  C3L-07813  C3L.07813.T      tumor                 exclude      No Tumor
# 158  C3L-08377  C3L.08377.T      tumor                 exclude      No Tumor
# 159  C3L-08371  C3L.08371.T      tumor                 exclude      No Tumor
#
#     AdditionalSegments SecondCategory ThirdCategory all_drivers Main_Groups  \
# 144                NaN            NaN           NaN         NaN    No Tumor
# 145                NaN            NaN           NaN         NaN    No Tumor
# 146                NaN            NaN           NaN         NaN    No Tumor
# 147                NaN            NaN           NaN         NaN    No Tumor
# 148                NaN            NaN           NaN         NaN    No Tumor
# 149                NaN            NaN           NaN         NaN    No Tumor
# 150                NaN            NaN           NaN         NaN    No Tumor
# 151                NaN            NaN           NaN         NaN    No Tumor
# 152                NaN            NaN           NaN         NaN    No Tumor
# 153                NaN            NaN           NaN         NaN    No Tumor
# 154                NaN            NaN           NaN         NaN    No Tumor
# 155                NaN            NaN           NaN         NaN    No Tumor
# 156                NaN            NaN           NaN         NaN    No Tumor
# 157                NaN            NaN           NaN         NaN    No Tumor
# 158                NaN            NaN           NaN         NaN    No Tumor
# 159                NaN            NaN           NaN         NaN    No Tumor
#
#      ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  LumB  Normal  \
# 144  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 145  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 146  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 147  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 148  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 149  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 150  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 151  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 152  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 153  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 154  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 155  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 156  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 157  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 158  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 159  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
#
#      agg_rank_raw  agg_rank_scaled  risk_group
# 144           NaN              NaN         NaN
# 145           NaN              NaN         NaN
# 146           NaN              NaN         NaN
# 147           NaN              NaN         NaN
# 148           NaN              NaN         NaN
# 149           NaN              NaN         NaN
# 150           NaN              NaN         NaN
# 151           NaN              NaN         NaN
# 152           NaN              NaN         NaN
# 153           NaN              NaN         NaN
# 154           NaN              NaN         NaN
# 155           NaN              NaN         NaN
# 156           NaN              NaN         NaN
# 157           NaN              NaN         NaN
# 158           NaN              NaN         NaN
# 159           NaN              NaN         NaN
#
# [16 rows x 113 columns]

# %%
meta_normal = meta[meta["include_or_excludetumor"] == "normal"]
meta_normal
# Out:
#        case_id    common_ID Tissuetype include_or_excludetumor FirstCategory  \
# 111  C3L-07813  C3L.07813.N     normal                  normal        Normal
# 112  C3L-06504  C3L.06504.N     normal                  normal        Normal
# 113  C3L-06506  C3L.06506.N     normal                  normal        Normal
# 114  C3L-06741  C3L.06741.N     normal                  normal        Normal
# 115  C3L-06890  C3L.06890.N     normal                  normal        Normal
# 116  C3L-06901  C3L.06901.N     normal                  normal        Normal
# 117  C3L-06743  C3L.06743.N     normal                  normal        Normal
# 118  C3L-07607  C3L.07607.N     normal                  normal        Normal
# 119  C3L-06436  C3L.06436.N     normal                  normal        Normal
# 120  C3L-07809  C3L.07809.N     normal                  normal        Normal
# 121  C3L-07872  C3L.07872.N     normal                  normal        Normal
# 122  C3L-08293  C3L.08293.N     normal                  normal        Normal
# 123  C3L-07871  C3L.07871.N     normal                  normal        Normal
# 124  C3L-08084  C3L.08084.N     normal                  normal        Normal
# 125  C3L-08371  C3L.08371.N     normal                  normal        Normal
# 126  C3L-08372  C3L.08372.N     normal                  normal        Normal
# 127  C3L-08818  C3L.08818.N     normal                  normal        Normal
# 128  C3L-08380  C3L.08380.N     normal                  normal        Normal
# 129  C3L-08811  C3L.08811.N     normal                  normal        Normal
# 130  C3L-08378  C3L.08378.N     normal                  normal        Normal
# 131  C3L-08382  C3L.08382.N     normal                  normal        Normal
# 132  C3L-09107  C3L.09107.N     normal                  normal        Normal
# 133  C3L-09701  C3L.09701.N     normal                  normal        Normal
# 134  C3L-06252  C3L.06252.N     normal                  normal        Normal
# 135  C3L-08755  C3L.08755.N     normal                  normal        Normal
# 136  C3L-06260  C3L.06260.N     normal                  normal        Normal
# 137  C3L-06261  C3L.06261.N     normal                  normal        Normal
# 138  C3L-09691  C3L.09691.N     normal                  normal        Normal
# 139  C3L-11176  C3L.11176.N     normal                  normal        Normal
# 140  C3L-08800  C3L.08800.N     normal                  normal        Normal
# 141  C3L-08802  C3L.08802.N     normal                  normal        Normal
# 142  C3L-11192  C3L.11192.N     normal                  normal        Normal
# 143  C3L-11122  C3L.11122.N     normal                  normal        Normal
#
#     AdditionalSegments SecondCategory ThirdCategory all_drivers Main_Groups  \
# 111                NaN            NaN           NaN      normal      normal
# 112                NaN            NaN           NaN      normal      normal
# 113                NaN            NaN           NaN      normal      normal
# 114                NaN            NaN           NaN      normal      normal
# 115                NaN            NaN           NaN      normal      normal
# 116                NaN            NaN           NaN      normal      normal
# 117                NaN            NaN           NaN      normal      normal
# 118                NaN            NaN           NaN      normal      normal
# 119                NaN            NaN           NaN      normal      normal
# 120                NaN            NaN           NaN      normal      normal
# 121                NaN            NaN           NaN      normal      normal
# 122                NaN            NaN           NaN      normal      normal
# 123                NaN            NaN           NaN      normal      normal
# 124                NaN            NaN           NaN      normal      normal
# 125                NaN            NaN           NaN      normal      normal
# 126                NaN            NaN           NaN      normal      normal
# 127                NaN            NaN           NaN      normal      normal
# 128                NaN            NaN           NaN      normal      normal
# 129                NaN            NaN           NaN      normal      normal
# 130                NaN            NaN           NaN      normal      normal
# 131                NaN            NaN           NaN      normal      normal
# 132                NaN            NaN           NaN      normal      normal
# 133                NaN            NaN           NaN      normal      normal
# 134                NaN            NaN           NaN      normal      normal
# 135                NaN            NaN           NaN      normal      normal
# 136                NaN            NaN           NaN      normal      normal
# 137                NaN            NaN           NaN      normal      normal
# 138                NaN            NaN           NaN      normal      normal
# 139                NaN            NaN           NaN      normal      normal
# 140                NaN            NaN           NaN      normal      normal
# 141                NaN            NaN           NaN      normal      normal
# 142                NaN            NaN           NaN      normal      normal
# 143                NaN            NaN           NaN      normal      normal
#
#      ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  LumB  Normal  \
# 111  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 112  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 113  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 114  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 115  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 116  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 117  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 118  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 119  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 120  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 121  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 122  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 123  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 124  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 125  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 126  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 127  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 128  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 129  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 130  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 131  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 132  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 133  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 134  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 135  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 136  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 137  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 138  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 139  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 140  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 141  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 142  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 143  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
#
#      agg_rank_raw  agg_rank_scaled  risk_group
# 111           NaN              NaN         NaN
# 112           NaN              NaN         NaN
# 113           NaN              NaN         NaN
# 114           NaN              NaN         NaN
# 115           NaN              NaN         NaN
# 116           NaN              NaN         NaN
# 117           NaN              NaN         NaN
# 118           NaN              NaN         NaN
# 119           NaN              NaN         NaN
# 120           NaN              NaN         NaN
# 121           NaN              NaN         NaN
# 122           NaN              NaN         NaN
# 123           NaN              NaN         NaN
# 124           NaN              NaN         NaN
# 125           NaN              NaN         NaN
# 126           NaN              NaN         NaN
# 127           NaN              NaN         NaN
# 128           NaN              NaN         NaN
# 129           NaN              NaN         NaN
# 130           NaN              NaN         NaN
# 131           NaN              NaN         NaN
# 132           NaN              NaN         NaN
# 133           NaN              NaN         NaN
# 134           NaN              NaN         NaN
# 135           NaN              NaN         NaN
# 136           NaN              NaN         NaN
# 137           NaN              NaN         NaN
# 138           NaN              NaN         NaN
# 139           NaN              NaN         NaN
# 140           NaN              NaN         NaN
# 141           NaN              NaN         NaN
# 142           NaN              NaN         NaN
# 143           NaN              NaN         NaN
#
# [33 rows x 113 columns]

# %%
tumors_included = meta_include['common_ID'].tolist()
tumors_excluded = meta_exclude['common_ID'].tolist()
print(len(tumors_included), len(tumors_excluded))
# Out:
# 134 16

# %%
normals = meta_normal['common_ID'].tolist()
print(len(normals))
# Out:
# 33

# %%
# data
files = [i for i in DATA_DIR.iterdir() if i.is_file()]
files = [i for i in files if re.search(r"normalized_phospho_TMT_ratio",i.stem, re.IGNORECASE)\
          and not re.search(r"tumor_purity_corrected",i.stem, re.IGNORECASE)\
            and re.search(r"normalized",i.stem, re.IGNORECASE) ]
data_path = files[0]
print(data_path)
header_cols = ["gene_site","Index","SequenceWindow"]
data = pd.read_csv(data_path,sep="\t").set_index(header_cols)
data_nomiss = data.dropna()
# Out:
# D:\lab\cptac_prostate\data\v4\CPTAC\prostate_CPTAC_normalized_phospho_TMT_ratio_single_site_MD.tsv

# %%
files
# Out:
# [WindowsPath('D:/lab/cptac_prostate/data/v4/CPTAC/prostate_CPTAC_normalized_phospho_TMT_ratio_single_site_MD.tsv')]

# %%
data
# Out:
#                                                    C3L.05292.T  C3L.09383.T  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL    -0.131121     0.199339
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP     0.410634    -0.033391
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN          NaN
# FKBP4_S15    ENSP00000001008_S15  ATESGAQsAPLPMEG    -0.083570     0.444164
# ...                                                        ...          ...
# NPLOC4_S103  ENSP00000516165_S103 TGEITASsNKSLNLL          NaN          NaN
# NPLOC4_S21   ENSP00000516165_S21  GAEAAAGsARPLGRQ          NaN          NaN
# NPLOC4_S36   ENSP00000516165_S36  AAAARGSsPEAGAAA     0.087382     0.067726
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ    -0.063231     0.254667
#
#                                                    CHTN.43798.T  C3L.06261.N  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     -0.545422    -0.405854
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET           NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP     -0.004122     0.337995
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL           NaN          NaN
# FKBP4_S15    ENSP00000001008_S15  ATESGAQsAPLPMEG      0.385587     0.414017
# ...                                                         ...          ...
# NPLOC4_S103  ENSP00000516165_S103 TGEITASsNKSLNLL           NaN          NaN
# NPLOC4_S21   ENSP00000516165_S21  GAEAAAGsARPLGRQ           NaN          NaN
# NPLOC4_S36   ENSP00000516165_S36  AAAARGSsPEAGAAA      0.161624     0.133073
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV           NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ     -0.085861    -0.147229
#
#                                                    C3L.08811.T  C3L.06506.N  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     0.175306    -0.108047
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP    -0.021818    -0.085667
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN          NaN
# FKBP4_S15    ENSP00000001008_S15  ATESGAQsAPLPMEG    -0.070448     0.181862
# ...                                                        ...          ...
# NPLOC4_S103  ENSP00000516165_S103 TGEITASsNKSLNLL          NaN          NaN
# NPLOC4_S21   ENSP00000516165_S21  GAEAAAGsARPLGRQ          NaN          NaN
# NPLOC4_S36   ENSP00000516165_S36  AAAARGSsPEAGAAA     0.223666     0.260065
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ     0.055060     0.343219
#
#                                                    C3L.07804.T  C3L.06595.T  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL    -0.237237     0.208280
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP    -0.425397    -0.183158
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN          NaN
# FKBP4_S15    ENSP00000001008_S15  ATESGAQsAPLPMEG    -0.007473     0.500933
# ...                                                        ...          ...
# NPLOC4_S103  ENSP00000516165_S103 TGEITASsNKSLNLL          NaN          NaN
# NPLOC4_S21   ENSP00000516165_S21  GAEAAAGsARPLGRQ          NaN          NaN
# NPLOC4_S36   ENSP00000516165_S36  AAAARGSsPEAGAAA     0.089513     0.346594
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ    -0.528803     0.143409
#
#                                                    C3L.06742.T  CHTN.45205.T  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     0.157449      0.207469
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN           NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP    -0.409795     -0.151450
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN           NaN
# FKBP4_S15    ENSP00000001008_S15  ATESGAQsAPLPMEG    -0.040327     -0.233394
# ...                                                        ...           ...
# NPLOC4_S103  ENSP00000516165_S103 TGEITASsNKSLNLL          NaN           NaN
# NPLOC4_S21   ENSP00000516165_S21  GAEAAAGsARPLGRQ          NaN           NaN
# NPLOC4_S36   ENSP00000516165_S36  AAAARGSsPEAGAAA     0.363083     -0.219072
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN           NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ    -0.919361     -0.153335
#
#                                                    ...  C3L.07875.T  \
# gene_site    Index                SequenceWindow   ...
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL  ...     0.162080
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET  ...          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP  ...          NaN
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL  ...          NaN
# FKBP4_S15    ENSP00000001008_S15  ATESGAQsAPLPMEG  ...     0.200835
# ...                                                ...          ...
# NPLOC4_S103  ENSP00000516165_S103 TGEITASsNKSLNLL  ...          NaN
# NPLOC4_S21   ENSP00000516165_S21  GAEAAAGsARPLGRQ  ...          NaN
# NPLOC4_S36   ENSP00000516165_S36  AAAARGSsPEAGAAA  ...    -0.030615
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV  ...          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ  ...          NaN
#
#                                                    CHTN.44966.T  C3L.11192.N  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL      0.058425    -0.043505
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET           NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP           NaN          NaN
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL           NaN          NaN
# FKBP4_S15    ENSP00000001008_S15  ATESGAQsAPLPMEG      0.421482     0.232805
# ...                                                         ...          ...
# NPLOC4_S103  ENSP00000516165_S103 TGEITASsNKSLNLL           NaN          NaN
# NPLOC4_S21   ENSP00000516165_S21  GAEAAAGsARPLGRQ           NaN          NaN
# NPLOC4_S36   ENSP00000516165_S36  AAAARGSsPEAGAAA     -0.129866    -0.033975
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV           NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ           NaN          NaN
#
#                                                    C3L.08805.T  C3L.09760.T  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     1.072174     0.124070
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP          NaN          NaN
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN          NaN
# FKBP4_S15    ENSP00000001008_S15  ATESGAQsAPLPMEG    -0.053676    -0.211367
# ...                                                        ...          ...
# NPLOC4_S103  ENSP00000516165_S103 TGEITASsNKSLNLL          NaN          NaN
# NPLOC4_S21   ENSP00000516165_S21  GAEAAAGsARPLGRQ          NaN          NaN
# NPLOC4_S36   ENSP00000516165_S36  AAAARGSsPEAGAAA    -0.633595     0.074058
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ          NaN          NaN
#
#                                                    C3L.08444.T  C3L.08291.T  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     0.210644     0.031103
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP          NaN          NaN
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN          NaN
# FKBP4_S15    ENSP00000001008_S15  ATESGAQsAPLPMEG     0.084472     0.145877
# ...                                                        ...          ...
# NPLOC4_S103  ENSP00000516165_S103 TGEITASsNKSLNLL          NaN          NaN
# NPLOC4_S21   ENSP00000516165_S21  GAEAAAGsARPLGRQ          NaN          NaN
# NPLOC4_S36   ENSP00000516165_S36  AAAARGSsPEAGAAA     0.086040     0.192434
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ          NaN          NaN
#
#                                                    C3L.10583.T  C3L.07877.T  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     0.196631     0.276092
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP          NaN          NaN
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN          NaN
# FKBP4_S15    ENSP00000001008_S15  ATESGAQsAPLPMEG     0.392890     0.078774
# ...                                                        ...          ...
# NPLOC4_S103  ENSP00000516165_S103 TGEITASsNKSLNLL          NaN          NaN
# NPLOC4_S21   ENSP00000516165_S21  GAEAAAGsARPLGRQ          NaN          NaN
# NPLOC4_S36   ENSP00000516165_S36  AAAARGSsPEAGAAA    -0.212397    -0.043020
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ          NaN          NaN
#
#                                                    C3L.08736.T
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     0.017274
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP          NaN
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN
# FKBP4_S15    ENSP00000001008_S15  ATESGAQsAPLPMEG    -0.011273
# ...                                                        ...
# NPLOC4_S103  ENSP00000516165_S103 TGEITASsNKSLNLL          NaN
# NPLOC4_S21   ENSP00000516165_S21  GAEAAAGsARPLGRQ          NaN
# NPLOC4_S36   ENSP00000516165_S36  AAAARGSsPEAGAAA    -0.002905
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ          NaN
#
# [42676 rows x 178 columns]

# %%
data_nomiss
# Out:
#                                                              C3L.05292.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL    -0.131121
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE     0.018151
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.566501
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -0.933672
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM     0.270274
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR    -1.599808
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH     0.050849
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV     0.053866
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA     0.436016
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA     0.087382
#
#                                                              C3L.09383.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL     0.199339
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE     0.284165
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.317576
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -0.449811
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM    -0.528125
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR     0.222428
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH    -0.090261
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV    -0.099359
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA     0.085742
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA     0.067726
#
#                                                              CHTN.43798.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL     -0.545422
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE     -0.137198
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-     -0.608033
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS     -0.629266
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM      0.329712
# ...                                                                   ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR     -0.825292
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH     -0.143075
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV     -0.050329
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA      0.296430
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA      0.161624
#
#                                                              C3L.06261.N  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL    -0.405854
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE     0.033718
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.726103
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -0.333800
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM    -0.431005
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR     0.606146
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH    -0.260258
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV     0.113517
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA     0.068697
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA     0.133073
#
#                                                              C3L.08811.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL     0.175306
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE    -0.501746
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.712308
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -0.124117
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM    -0.178826
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR    -1.398442
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH     0.658635
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV    -0.362940
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA     0.860885
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA     0.223666
#
#                                                              C3L.06506.N  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL    -0.108047
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE     0.041820
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.561104
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -0.392489
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM     0.051677
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR    -0.225578
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH    -0.212984
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV     0.141042
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA    -0.397189
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA     0.260065
#
#                                                              C3L.07804.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL    -0.237237
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE     0.459526
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.231544
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -0.176548
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM    -0.534121
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR     0.669166
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH    -0.059771
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV     0.185904
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA    -0.437312
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA     0.089513
#
#                                                              C3L.06595.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL     0.208280
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE    -0.105399
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-     0.092802
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -0.165884
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM     0.041506
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR    -0.326687
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH     0.127268
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV    -0.311766
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA    -0.149302
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA     0.346594
#
#                                                              C3L.06742.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL     0.157449
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE     1.368552
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.455799
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -0.399299
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM     0.543441
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR     1.000654
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH     0.160572
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV     0.371630
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA     0.112729
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA     0.363083
#
#                                                              CHTN.45205.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL      0.207469
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE     -0.024419
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-      0.120407
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS      0.009786
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM     -0.003925
# ...                                                                   ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR     -1.060801
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH      0.421984
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV      0.173395
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA      0.242605
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA     -0.219072
#
#                                                              ...  C3L.07875.T  \
# gene_site             Index                 SequenceWindow   ...
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL  ...     0.162080
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE  ...    -0.282884
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-  ...    -0.197553
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS  ...    -0.977437
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM  ...    -0.024372
# ...                                                          ...          ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR  ...    -0.856135
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH  ...     0.211081
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV  ...    -0.062699
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA  ...     0.281472
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA  ...    -0.030615
#
#                                                              CHTN.44966.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL      0.058425
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE     -0.683706
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-     -0.590890
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS     -1.900941
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM      0.281432
# ...                                                                   ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR     -0.967047
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH      0.013336
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV      0.069774
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA     -0.274746
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA     -0.129866
#
#                                                              C3L.11192.N  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL    -0.043505
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE    -0.548394
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.714704
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS     1.023015
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM    -0.284380
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR     0.962622
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH    -0.486256
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV     0.069271
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA    -0.467719
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA    -0.033975
#
#                                                              C3L.08805.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL     1.072174
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE    -0.163453
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.202773
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -0.206947
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM    -0.357557
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR     0.451017
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH     0.358231
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV    -2.026801
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA     0.191680
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA    -0.633595
#
#                                                              C3L.09760.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL     0.124070
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE    -0.703134
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.261158
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -1.038962
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM     0.160816
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR    -0.488741
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH     0.059229
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV     0.221143
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA     0.409373
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA     0.074058
#
#                                                              C3L.08444.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL     0.210644
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE    -0.686150
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.354960
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -0.397208
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM     0.213884
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR    -1.351965
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH    -0.051634
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV     0.110860
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA     0.424936
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA     0.086040
#
#                                                              C3L.08291.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL     0.031103
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE     0.357636
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.153781
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -1.244405
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM     0.426750
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR    -2.172043
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH    -0.041503
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV     0.497162
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA     0.536146
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA     0.192434
#
#                                                              C3L.10583.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL     0.196631
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE    -0.687826
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.838640
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -1.694942
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM    -0.434905
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR    -0.295624
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH    -0.136928
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV    -0.170814
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA    -0.058488
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA    -0.212397
#
#                                                              C3L.07877.T  \
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL     0.276092
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE    -0.479434
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.283587
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -0.160868
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM    -0.269633
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR     0.315340
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH    -0.167041
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV     0.315384
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA    -0.213062
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA    -0.043020
#
#                                                              C3L.08736.T
# gene_site             Index                 SequenceWindow
# M6PR_S267             ENSP00000000412_S267  DDQLGEEsEERDDHL     0.017274
# FKBP4_S258            ENSP00000001008_S258  SFEKAKEsWEMNSEE     0.652689
# FKBP4_S453            ENSP00000001008_S453  SNTAGSQsQVETEA-    -0.498735
# HSPB6_S16             ENSP00000004982_S16   PSWLRRAsAPLPGLS    -1.291440
# BAIAP2L1_S331         ENSP00000005260_S331  PSLQRSVsVATGLNM    -0.178247
# ...                                                                  ...
# ARHGEF7_S673          ENSP00000514984_S673  RKPERKPsDEEFASR    -0.553573
# ENSG00000290315_S1096 ENSP00000515567_S1096 KKYRGMGsLDAMDKH    -0.230734
# NCOR1_S1025           ENSP00000516022_S1025 SPCGTSKsPNREWEV     0.248351
# CYTH2_S38             ENSP00000516062_S38   TGGTAPDsPRAFLAA     0.851689
# NPLOC4_S36            ENSP00000516165_S36   AAAARGSsPEAGAAA    -0.002905
#
# [6585 rows x 178 columns]

# %%
samples = data.columns.tolist()
len(samples)
# Out:
# 178

# %%
set_tumors_included = set(tumors_included)
set_tumors_excluded = set(tumors_excluded)
set_normals = set(normals)
set_data = set(samples)
print((len(set_tumors_included), len(set_tumors_excluded), len(set_normals), len(set_data)))
# Out:
# (134, 16, 33, 178)

# %%
set_data - set_tumors_included - set_tumors_excluded - set_normals
# Out:
# {'C3L.06436.T',
#  'C3L.07292.N',
#  'C3L.07606.N',
#  'C3L.08546.T',
#  'C3L.09345.T',
#  'C3L.09373.T',
#  'C3L.09793.T',
#  'C3L.09832.T',
#  'C3L.09972.T',
#  'C3L.10301.T',
#  'CHTN.47295.T'}

# %%
data.boxplot(figsize=(40,6), rot=90)
# Out:
# <Axes: >

# %%
from omicsone_streamlit.plots.pca import plot_pca1

# %%
print(len(tumors_included), len(normals))
# Out:
# 134 33

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = "Tumor"
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"

# %%
len(set(data.columns) & set(tumors_included))
# Out:
# 134

# %%
data2 = data_nomiss.T.loc[tumors_included + normals,:]
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')

# %%
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-50,50), ylim=(-50,50), figsize=(6,6),
                    title="PCA of phospho TMT normalized ratio (colored by group)")

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = purity_map.get(i, "Tumor")
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-50,50), ylim=(-50,50), figsize=(6,6),
                    title="PCA of phospho TMT normalized ratio (colored by purity)")

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = re.sub("[ABC]",'',stage_map.get(i, "Tumor"))
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-50,50), ylim=(-50,50), figsize=(6,6),
                    title="PCA of phospho TMT normalized log2ratio (colored by stage)")
