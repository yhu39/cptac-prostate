# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import re,sys,os
import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib

# Set font to Arial
matplotlib.rcParams['font.family'] = 'Arial'

# Optional: Set PDF to embed fonts (for Illustrator editing)
matplotlib.rcParams['pdf.fonttype'] = 42  # TrueType fonts for better editing

# %%
DATA_DIR = Path(r"D:\lab\cptac_prostate\data\v4\CPTAC")
OUTPUT_DIR = Path(r"D:\lab\cptac_prostate\runs\20260330_cptac_phospho_tmt_pca")
print(DATA_DIR.exists(), OUTPUT_DIR.exists())
meta_path = DATA_DIR / "20_MetaData_03_12_2026.csv"
# Out:
# True False

# %%
meta = pd.read_csv(meta_path)
meta
# Out:
#         case_id     common_ID Tissuetype include_or_excludetumor  \
# 0     C3L-07287   C3L.07287.T      tumor                 Include
# 1     C3L-11156   C3L.11156.T      tumor                 Include
# 2     C3L-09494   C3L.09494.T      tumor                 Include
# 3    CHTN-49141  CHTN.49141.T      tumor                 Include
# 4     C3L-11095   C3L.11095.T      tumor                 Include
# ..          ...           ...        ...                     ...
# 178   C3L-07872   C3L.07872.T      tumor                 Include
# 179   C3L-08642   C3L.08642.T      tumor                 Include
# 180   C3L-10399   C3L.10399.T      tumor                 Include
# 181   C3L-05301   C3L.05301.T      tumor                 Include
# 182   C3L-08384   C3L.08384.T      tumor                 Include
#
#          FirstCategory AdditionalSegments SecondCategory ThirdCategory  \
# 0    Sufficient Purity                ETS            ETS           NaN
# 1    Sufficient Purity                ETS            ETS           NaN
# 2    Sufficient Purity                ETS            ETS           NaN
# 3    Sufficient Purity                ETS            ETS           NaN
# 4    Sufficient Purity                ETS            ETS           NaN
# ..                 ...                ...            ...           ...
# 178         Low Purity                NaN            NaN           NaN
# 179         Low Purity                NaN            NaN           NaN
# 180         Low Purity                NaN            NaN           NaN
# 181         Low Purity                NaN            NaN           NaN
# 182         Low Purity                NaN            NaN           NaN
#
#     all_drivers Main_Groups  ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  \
# 0           ERG         ERG  ...    0.342000      0.000000   0.0   0.0   1.0
# 1           ERG         ERG  ...    0.000000      0.498000   0.0   0.0   1.0
# 2           ERG         ERG  ...    0.281000      0.000000   0.0   1.0   0.0
# 3           ERG         ERG  ...    0.420000      0.000000   0.0   1.0   0.0
# 4           ERG         ERG  ...    0.000000      0.369000   0.0   0.0   1.0
# ..          ...         ...  ...         ...           ...   ...   ...   ...
# 178         ERG         ERG  ...    0.000000      0.460832   1.0   0.0   0.0
# 179         ERG         ERG  ...    0.000000      0.334840   0.0   0.0   1.0
# 180         ERG         ERG  ...    0.000000      0.445334   0.0   0.0   1.0
# 181        ETV1        ETV1  ...    0.000000      0.457908   0.0   0.0   1.0
# 182         ERG         ERG  ...    0.789835      0.000000   0.0   0.0   0.0
#
#      LumB  Normal  agg_rank_raw  agg_rank_scaled  risk_group
# 0     0.0     0.0     55.333000         0.409000          IR
# 1     0.0     0.0     44.167000         0.325000          LR
# 2     0.0     0.0    123.167000         0.919000          HR
# 3     0.0     0.0    103.833000         0.773000          HR
# 4     0.0     0.0     44.667000         0.328000          LR
# ..    ...     ...           ...              ...         ...
# 178   0.0     0.0     73.666667         0.546366          IR
# 179   0.0     0.0     46.166667         0.339599          LR
# 180   0.0     0.0     60.000000         0.443609          IR
# 181   0.0     0.0     45.333333         0.333333          LR
# 182   1.0     0.0     88.166667         0.655000          HR
#
# [183 rows x 113 columns]

# %%
meta_include = meta[meta["include_or_excludetumor"] == "Include"]
meta_include
# Out:
#         case_id     common_ID Tissuetype include_or_excludetumor  \
# 0     C3L-07287   C3L.07287.T      tumor                 Include
# 1     C3L-11156   C3L.11156.T      tumor                 Include
# 2     C3L-09494   C3L.09494.T      tumor                 Include
# 3    CHTN-49141  CHTN.49141.T      tumor                 Include
# 4     C3L-11095   C3L.11095.T      tumor                 Include
# ..          ...           ...        ...                     ...
# 178   C3L-07872   C3L.07872.T      tumor                 Include
# 179   C3L-08642   C3L.08642.T      tumor                 Include
# 180   C3L-10399   C3L.10399.T      tumor                 Include
# 181   C3L-05301   C3L.05301.T      tumor                 Include
# 182   C3L-08384   C3L.08384.T      tumor                 Include
#
#          FirstCategory AdditionalSegments SecondCategory ThirdCategory  \
# 0    Sufficient Purity                ETS            ETS           NaN
# 1    Sufficient Purity                ETS            ETS           NaN
# 2    Sufficient Purity                ETS            ETS           NaN
# 3    Sufficient Purity                ETS            ETS           NaN
# 4    Sufficient Purity                ETS            ETS           NaN
# ..                 ...                ...            ...           ...
# 178         Low Purity                NaN            NaN           NaN
# 179         Low Purity                NaN            NaN           NaN
# 180         Low Purity                NaN            NaN           NaN
# 181         Low Purity                NaN            NaN           NaN
# 182         Low Purity                NaN            NaN           NaN
#
#     all_drivers Main_Groups  ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  \
# 0           ERG         ERG  ...    0.342000      0.000000   0.0   0.0   1.0
# 1           ERG         ERG  ...    0.000000      0.498000   0.0   0.0   1.0
# 2           ERG         ERG  ...    0.281000      0.000000   0.0   1.0   0.0
# 3           ERG         ERG  ...    0.420000      0.000000   0.0   1.0   0.0
# 4           ERG         ERG  ...    0.000000      0.369000   0.0   0.0   1.0
# ..          ...         ...  ...         ...           ...   ...   ...   ...
# 178         ERG         ERG  ...    0.000000      0.460832   1.0   0.0   0.0
# 179         ERG         ERG  ...    0.000000      0.334840   0.0   0.0   1.0
# 180         ERG         ERG  ...    0.000000      0.445334   0.0   0.0   1.0
# 181        ETV1        ETV1  ...    0.000000      0.457908   0.0   0.0   1.0
# 182         ERG         ERG  ...    0.789835      0.000000   0.0   0.0   0.0
#
#      LumB  Normal  agg_rank_raw  agg_rank_scaled  risk_group
# 0     0.0     0.0     55.333000         0.409000          IR
# 1     0.0     0.0     44.167000         0.325000          LR
# 2     0.0     0.0    123.167000         0.919000          HR
# 3     0.0     0.0    103.833000         0.773000          HR
# 4     0.0     0.0     44.667000         0.328000          LR
# ..    ...     ...           ...              ...         ...
# 178   0.0     0.0     73.666667         0.546366          IR
# 179   0.0     0.0     46.166667         0.339599          LR
# 180   0.0     0.0     60.000000         0.443609          IR
# 181   0.0     0.0     45.333333         0.333333          LR
# 182   1.0     0.0     88.166667         0.655000          HR
#
# [134 rows x 113 columns]

# %%
purity_map = dict(zip(meta_include["common_ID"], meta_include["FirstCategory"]))
stage_map = dict(zip(meta_include["common_ID"], meta_include["stage"]))
gleason_map = dict(zip(meta_include["common_ID"], meta_include["Gleason_um"]))

# %%
meta_exclude = meta[meta["include_or_excludetumor"] == "exclude"]
meta_exclude
# Out:
#        case_id    common_ID Tissuetype include_or_excludetumor FirstCategory  \
# 144  C3L-09492  C3L.09492.T      tumor                 exclude      No Tumor
# 145  C3L-09497  C3L.09497.T      tumor                 exclude      No Tumor
# 146  C3L-06260  C3L.06260.T      tumor                 exclude      No Tumor
# 147  C3L-06510  C3L.06510.T      tumor                 exclude      No Tumor
# 148  C3L-07890  C3L.07890.T      tumor                 exclude      No Tumor
# 149  C3L-09372  C3L.09372.T      tumor                 exclude      No Tumor
# 150  C3N-09047  C3N.09047.T      tumor                 exclude      No Tumor
# 151  C3L-07868  C3L.07868.T      tumor                 exclude      No Tumor
# 152  C3L-09563  C3L.09563.T      tumor                 exclude      No Tumor
# 153  C3L-10319  C3L.10319.T      tumor                 exclude      No Tumor
# 154  C3L-06657  C3L.06657.T      tumor                 exclude      No Tumor
# 155  C3L-07405  C3L.07405.T      tumor                 exclude      No Tumor
# 156  C3L-06573  C3L.06573.T      tumor                 exclude      No Tumor
# 157  C3L-07813  C3L.07813.T      tumor                 exclude      No Tumor
# 158  C3L-08377  C3L.08377.T      tumor                 exclude      No Tumor
# 159  C3L-08371  C3L.08371.T      tumor                 exclude      No Tumor
#
#     AdditionalSegments SecondCategory ThirdCategory all_drivers Main_Groups  \
# 144                NaN            NaN           NaN         NaN    No Tumor
# 145                NaN            NaN           NaN         NaN    No Tumor
# 146                NaN            NaN           NaN         NaN    No Tumor
# 147                NaN            NaN           NaN         NaN    No Tumor
# 148                NaN            NaN           NaN         NaN    No Tumor
# 149                NaN            NaN           NaN         NaN    No Tumor
# 150                NaN            NaN           NaN         NaN    No Tumor
# 151                NaN            NaN           NaN         NaN    No Tumor
# 152                NaN            NaN           NaN         NaN    No Tumor
# 153                NaN            NaN           NaN         NaN    No Tumor
# 154                NaN            NaN           NaN         NaN    No Tumor
# 155                NaN            NaN           NaN         NaN    No Tumor
# 156                NaN            NaN           NaN         NaN    No Tumor
# 157                NaN            NaN           NaN         NaN    No Tumor
# 158                NaN            NaN           NaN         NaN    No Tumor
# 159                NaN            NaN           NaN         NaN    No Tumor
#
#      ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  LumB  Normal  \
# 144  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 145  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 146  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 147  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 148  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 149  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 150  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 151  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 152  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 153  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 154  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 155  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 156  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 157  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 158  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 159  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
#
#      agg_rank_raw  agg_rank_scaled  risk_group
# 144           NaN              NaN         NaN
# 145           NaN              NaN         NaN
# 146           NaN              NaN         NaN
# 147           NaN              NaN         NaN
# 148           NaN              NaN         NaN
# 149           NaN              NaN         NaN
# 150           NaN              NaN         NaN
# 151           NaN              NaN         NaN
# 152           NaN              NaN         NaN
# 153           NaN              NaN         NaN
# 154           NaN              NaN         NaN
# 155           NaN              NaN         NaN
# 156           NaN              NaN         NaN
# 157           NaN              NaN         NaN
# 158           NaN              NaN         NaN
# 159           NaN              NaN         NaN
#
# [16 rows x 113 columns]

# %%
meta_normal = meta[meta["include_or_excludetumor"] == "normal"]
meta_normal
# Out:
#        case_id    common_ID Tissuetype include_or_excludetumor FirstCategory  \
# 111  C3L-07813  C3L.07813.N     normal                  normal        Normal
# 112  C3L-06504  C3L.06504.N     normal                  normal        Normal
# 113  C3L-06506  C3L.06506.N     normal                  normal        Normal
# 114  C3L-06741  C3L.06741.N     normal                  normal        Normal
# 115  C3L-06890  C3L.06890.N     normal                  normal        Normal
# 116  C3L-06901  C3L.06901.N     normal                  normal        Normal
# 117  C3L-06743  C3L.06743.N     normal                  normal        Normal
# 118  C3L-07607  C3L.07607.N     normal                  normal        Normal
# 119  C3L-06436  C3L.06436.N     normal                  normal        Normal
# 120  C3L-07809  C3L.07809.N     normal                  normal        Normal
# 121  C3L-07872  C3L.07872.N     normal                  normal        Normal
# 122  C3L-08293  C3L.08293.N     normal                  normal        Normal
# 123  C3L-07871  C3L.07871.N     normal                  normal        Normal
# 124  C3L-08084  C3L.08084.N     normal                  normal        Normal
# 125  C3L-08371  C3L.08371.N     normal                  normal        Normal
# 126  C3L-08372  C3L.08372.N     normal                  normal        Normal
# 127  C3L-08818  C3L.08818.N     normal                  normal        Normal
# 128  C3L-08380  C3L.08380.N     normal                  normal        Normal
# 129  C3L-08811  C3L.08811.N     normal                  normal        Normal
# 130  C3L-08378  C3L.08378.N     normal                  normal        Normal
# 131  C3L-08382  C3L.08382.N     normal                  normal        Normal
# 132  C3L-09107  C3L.09107.N     normal                  normal        Normal
# 133  C3L-09701  C3L.09701.N     normal                  normal        Normal
# 134  C3L-06252  C3L.06252.N     normal                  normal        Normal
# 135  C3L-08755  C3L.08755.N     normal                  normal        Normal
# 136  C3L-06260  C3L.06260.N     normal                  normal        Normal
# 137  C3L-06261  C3L.06261.N     normal                  normal        Normal
# 138  C3L-09691  C3L.09691.N     normal                  normal        Normal
# 139  C3L-11176  C3L.11176.N     normal                  normal        Normal
# 140  C3L-08800  C3L.08800.N     normal                  normal        Normal
# 141  C3L-08802  C3L.08802.N     normal                  normal        Normal
# 142  C3L-11192  C3L.11192.N     normal                  normal        Normal
# 143  C3L-11122  C3L.11122.N     normal                  normal        Normal
#
#     AdditionalSegments SecondCategory ThirdCategory all_drivers Main_Groups  \
# 111                NaN            NaN           NaN      normal      normal
# 112                NaN            NaN           NaN      normal      normal
# 113                NaN            NaN           NaN      normal      normal
# 114                NaN            NaN           NaN      normal      normal
# 115                NaN            NaN           NaN      normal      normal
# 116                NaN            NaN           NaN      normal      normal
# 117                NaN            NaN           NaN      normal      normal
# 118                NaN            NaN           NaN      normal      normal
# 119                NaN            NaN           NaN      normal      normal
# 120                NaN            NaN           NaN      normal      normal
# 121                NaN            NaN           NaN      normal      normal
# 122                NaN            NaN           NaN      normal      normal
# 123                NaN            NaN           NaN      normal      normal
# 124                NaN            NaN           NaN      normal      normal
# 125                NaN            NaN           NaN      normal      normal
# 126                NaN            NaN           NaN      normal      normal
# 127                NaN            NaN           NaN      normal      normal
# 128                NaN            NaN           NaN      normal      normal
# 129                NaN            NaN           NaN      normal      normal
# 130                NaN            NaN           NaN      normal      normal
# 131                NaN            NaN           NaN      normal      normal
# 132                NaN            NaN           NaN      normal      normal
# 133                NaN            NaN           NaN      normal      normal
# 134                NaN            NaN           NaN      normal      normal
# 135                NaN            NaN           NaN      normal      normal
# 136                NaN            NaN           NaN      normal      normal
# 137                NaN            NaN           NaN      normal      normal
# 138                NaN            NaN           NaN      normal      normal
# 139                NaN            NaN           NaN      normal      normal
# 140                NaN            NaN           NaN      normal      normal
# 141                NaN            NaN           NaN      normal      normal
# 142                NaN            NaN           NaN      normal      normal
# 143                NaN            NaN           NaN      normal      normal
#
#      ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  LumB  Normal  \
# 111  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 112  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 113  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 114  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 115  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 116  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 117  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 118  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 119  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 120  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 121  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 122  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 123  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 124  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 125  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 126  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 127  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 128  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 129  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 130  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 131  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 132  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 133  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 134  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 135  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 136  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 137  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 138  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 139  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 140  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 141  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 142  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 143  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
#
#      agg_rank_raw  agg_rank_scaled  risk_group
# 111           NaN              NaN         NaN
# 112           NaN              NaN         NaN
# 113           NaN              NaN         NaN
# 114           NaN              NaN         NaN
# 115           NaN              NaN         NaN
# 116           NaN              NaN         NaN
# 117           NaN              NaN         NaN
# 118           NaN              NaN         NaN
# 119           NaN              NaN         NaN
# 120           NaN              NaN         NaN
# 121           NaN              NaN         NaN
# 122           NaN              NaN         NaN
# 123           NaN              NaN         NaN
# 124           NaN              NaN         NaN
# 125           NaN              NaN         NaN
# 126           NaN              NaN         NaN
# 127           NaN              NaN         NaN
# 128           NaN              NaN         NaN
# 129           NaN              NaN         NaN
# 130           NaN              NaN         NaN
# 131           NaN              NaN         NaN
# 132           NaN              NaN         NaN
# 133           NaN              NaN         NaN
# 134           NaN              NaN         NaN
# 135           NaN              NaN         NaN
# 136           NaN              NaN         NaN
# 137           NaN              NaN         NaN
# 138           NaN              NaN         NaN
# 139           NaN              NaN         NaN
# 140           NaN              NaN         NaN
# 141           NaN              NaN         NaN
# 142           NaN              NaN         NaN
# 143           NaN              NaN         NaN
#
# [33 rows x 113 columns]

# %%
tumors_included = meta_include['common_ID'].tolist()
tumors_excluded = meta_exclude['common_ID'].tolist()
print(len(tumors_included), len(tumors_excluded))
# Out:
# 134 16

# %%
normals = meta_normal['common_ID'].tolist()
print(len(normals))
# Out:
# 33

# %%
# data
files = [i for i in DATA_DIR.iterdir() if i.is_file()]
files = [i for i in files if re.search(r"phospho_TMT_ratio",i.stem, re.IGNORECASE) \
         and not re.search(r"tumor_purity_corrected",i.stem, re.IGNORECASE) \
            and not re.search(r"normalized",i.stem, re.IGNORECASE)] 
data_path = files[0]
print(data_path)
header_cols = ["gene_site","Index","SequenceWindow"]
data = pd.read_csv(data_path,sep="\t").set_index(header_cols)
data_nomiss = data.dropna()
# Out:
# D:\lab\cptac_prostate\data\v4\CPTAC\prostate_CPTAC_phospho_TMT_ratio_single_site_MD.tsv

# %%
files
# Out:
# [WindowsPath('D:/lab/cptac_prostate/data/v4/CPTAC/prostate_CPTAC_phospho_TMT_ratio_single_site_MD.tsv')]

# %%
data
# Out:
#                                                    C3L.05292.T  C3L.09383.T  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL    -0.152653     0.105130
# ESRRA_S19    ENSP00000000442_S19  YIKAEPAsPDSPKGS          NaN          NaN
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP     0.387958     0.207588
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN          NaN
# ...                                                        ...          ...
# DNM1_T852    ENSP00000516205_T852 RKGPASPtRPAAPRP          NaN          NaN
# CAMK2D_S349  ENSP00000516208_S349 NKANVVTsPKENIPT          NaN          NaN
# TUBA3FP_S41  ENSP00000516278_S41  GPKADSDsDLETEGA          NaN          NaN
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ    -0.061930     0.659448
#
#                                                    CHTN.43798.T  C3L.06261.N  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     -0.410499    -0.423219
# ESRRA_S19    ENSP00000000442_S19  YIKAEPAsPDSPKGS           NaN          NaN
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET           NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP      0.085628     0.230611
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL           NaN          NaN
# ...                                                         ...          ...
# DNM1_T852    ENSP00000516205_T852 RKGPASPtRPAAPRP           NaN          NaN
# CAMK2D_S349  ENSP00000516208_S349 NKANVVTsPKENIPT           NaN          NaN
# TUBA3FP_S41  ENSP00000516278_S41  GPKADSDsDLETEGA           NaN          NaN
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV           NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ     -0.124220     0.090738
#
#                                                    C3L.08811.T  C3L.06506.N  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     0.270358    -0.189374
# ESRRA_S19    ENSP00000000442_S19  YIKAEPAsPDSPKGS          NaN          NaN
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP     0.152039     0.135502
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN          NaN
# ...                                                        ...          ...
# DNM1_T852    ENSP00000516205_T852 RKGPASPtRPAAPRP          NaN          NaN
# CAMK2D_S349  ENSP00000516208_S349 NKANVVTsPKENIPT          NaN          NaN
# TUBA3FP_S41  ENSP00000516278_S41  GPKADSDsDLETEGA          NaN          NaN
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ     0.020478     0.662730
#
#                                                    C3L.07804.T  C3L.06595.T  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL    -0.337974     0.032672
# ESRRA_S19    ENSP00000000442_S19  YIKAEPAsPDSPKGS          NaN          NaN
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP    -0.548136     0.131133
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN          NaN
# ...                                                        ...          ...
# DNM1_T852    ENSP00000516205_T852 RKGPASPtRPAAPRP          NaN          NaN
# CAMK2D_S349  ENSP00000516208_S349 NKANVVTsPKENIPT          NaN          NaN
# TUBA3FP_S41  ENSP00000516278_S41  GPKADSDsDLETEGA          NaN          NaN
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ    -0.143458     0.301637
#
#                                                    C3L.06742.T  CHTN.45205.T  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     0.066165      0.085354
# ESRRA_S19    ENSP00000000442_S19  YIKAEPAsPDSPKGS          NaN           NaN
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN           NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP    -0.253944     -0.057385
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN           NaN
# ...                                                        ...           ...
# DNM1_T852    ENSP00000516205_T852 RKGPASPtRPAAPRP          NaN           NaN
# CAMK2D_S349  ENSP00000516208_S349 NKANVVTsPKENIPT          NaN           NaN
# TUBA3FP_S41  ENSP00000516278_S41  GPKADSDsDLETEGA          NaN           NaN
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN           NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ    -0.896972     -0.237141
#
#                                                    ...  C3L.07875.T  \
# gene_site    Index                SequenceWindow   ...
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL  ...     0.252478
# ESRRA_S19    ENSP00000000442_S19  YIKAEPAsPDSPKGS  ...          NaN
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET  ...          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP  ...          NaN
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL  ...          NaN
# ...                                                ...          ...
# DNM1_T852    ENSP00000516205_T852 RKGPASPtRPAAPRP  ...     0.042702
# CAMK2D_S349  ENSP00000516208_S349 NKANVVTsPKENIPT  ...          NaN
# TUBA3FP_S41  ENSP00000516278_S41  GPKADSDsDLETEGA  ...     0.137799
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV  ...          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ  ...          NaN
#
#                                                    CHTN.44966.T  C3L.11192.N  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     -0.057686    -0.230422
# ESRRA_S19    ENSP00000000442_S19  YIKAEPAsPDSPKGS           NaN          NaN
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET           NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP           NaN          NaN
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL           NaN          NaN
# ...                                                         ...          ...
# DNM1_T852    ENSP00000516205_T852 RKGPASPtRPAAPRP     -0.074871     0.518712
# CAMK2D_S349  ENSP00000516208_S349 NKANVVTsPKENIPT           NaN          NaN
# TUBA3FP_S41  ENSP00000516278_S41  GPKADSDsDLETEGA     -0.296929     0.538734
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV           NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ           NaN          NaN
#
#                                                    C3L.08805.T  C3L.09760.T  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     1.183299     0.137987
# ESRRA_S19    ENSP00000000442_S19  YIKAEPAsPDSPKGS          NaN          NaN
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP          NaN          NaN
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN          NaN
# ...                                                        ...          ...
# DNM1_T852    ENSP00000516205_T852 RKGPASPtRPAAPRP     0.452699    -0.275853
# CAMK2D_S349  ENSP00000516208_S349 NKANVVTsPKENIPT          NaN          NaN
# TUBA3FP_S41  ENSP00000516278_S41  GPKADSDsDLETEGA    -0.330404    -0.170727
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ          NaN          NaN
#
#                                                    C3L.08444.T  C3L.08291.T  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     0.176602    -0.193945
# ESRRA_S19    ENSP00000000442_S19  YIKAEPAsPDSPKGS          NaN          NaN
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP          NaN          NaN
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN          NaN
# ...                                                        ...          ...
# DNM1_T852    ENSP00000516205_T852 RKGPASPtRPAAPRP    -0.702490    -0.995977
# CAMK2D_S349  ENSP00000516208_S349 NKANVVTsPKENIPT          NaN          NaN
# TUBA3FP_S41  ENSP00000516278_S41  GPKADSDsDLETEGA    -0.485082    -0.404717
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ          NaN          NaN
#
#                                                    C3L.10583.T  C3L.07877.T  \
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     0.002367     0.347335
# ESRRA_S19    ENSP00000000442_S19  YIKAEPAsPDSPKGS          NaN          NaN
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP          NaN          NaN
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN          NaN
# ...                                                        ...          ...
# DNM1_T852    ENSP00000516205_T852 RKGPASPtRPAAPRP     0.746716     0.315820
# CAMK2D_S349  ENSP00000516208_S349 NKANVVTsPKENIPT          NaN          NaN
# TUBA3FP_S41  ENSP00000516278_S41  GPKADSDsDLETEGA     0.578812     0.075428
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ          NaN          NaN
#
#                                                    C3L.08736.T
# gene_site    Index                SequenceWindow
# M6PR_S267    ENSP00000000412_S267 DDQLGEEsEERDDHL     0.161394
# ESRRA_S19    ENSP00000000442_S19  YIKAEPAsPDSPKGS          NaN
# ESRRA_S22    ENSP00000000442_S22  AEPASPDsPKGSSET          NaN
# ESRRA_S27    ENSP00000000442_S27  PDSPKGSsETETEPP          NaN
# FKBP4_S11    ENSP00000001008_S11  EEMKATEsGAQSAPL          NaN
# ...                                                        ...
# DNM1_T852    ENSP00000516205_T852 RKGPASPtRPAAPRP     0.026136
# CAMK2D_S349  ENSP00000516208_S349 NKANVVTsPKENIPT          NaN
# TUBA3FP_S41  ENSP00000516278_S41  GPKADSDsDLETEGA    -0.393899
# EPB41L2_S735 ENSP00000516350_S735 ARDAVKSsHETLNIV          NaN
# EPB41L2_T673 ENSP00000516350_T673 EWEKRRItPLSLQTQ          NaN
#
# [57186 rows x 178 columns]

# %%
data_nomiss
# Out:
#                                                  C3L.05292.T  C3L.09383.T  \
# gene_site  Index                SequenceWindow
# M6PR_S267  ENSP00000000412_S267 DDQLGEEsEERDDHL    -0.152653     0.105130
# FKBP4_S258 ENSP00000001008_S258 SFEKAKEsWEMNSEE    -0.080313     0.215040
# FKBP4_S453 ENSP00000001008_S453 SNTAGSQsQVETEA-    -0.664965    -0.386701
# CFTR_S737  ENSP00000003084_S737 EPLERRLsLVPDSEQ    -0.384231    -0.932330
# HSPB6_S16  ENSP00000004982_S16  PSWLRRAsAPLPGLS    -0.950869    -0.480455
# ...                                                      ...          ...
# SRRM1_T220 ENSP00000516157_T220 APEKKEKtPELPEPS    -0.059522    -0.127516
# SRRM1_T416 ENSP00000516157_T416 PKTRHsPtPQQSNRT     0.123060    -0.122870
# SRRM1_T628 ENSP00000516157_T628 SPPPKRRtAsPPPPP    -0.338267    -0.370862
# SRRM1_T741 ENSP00000516157_T741 PIRRVSRtPEPKKIK    -0.301902    -0.105007
# NPLOC4_S36 ENSP00000516165_S36  AAAARGSsPEAGAAA     0.092981     0.083723
#
#                                                  CHTN.43798.T  C3L.06261.N  \
# gene_site  Index                SequenceWindow
# M6PR_S267  ENSP00000000412_S267 DDQLGEEsEERDDHL     -0.410499    -0.423219
# FKBP4_S258 ENSP00000001008_S258 SFEKAKEsWEMNSEE     -0.212572    -0.243663
# FKBP4_S453 ENSP00000001008_S453 SNTAGSQsQVETEA-     -0.683407    -1.003484
# CFTR_S737  ENSP00000003084_S737 EPLERRLsLVPDSEQ     -0.836805    -0.714878
# HSPB6_S16  ENSP00000004982_S16  PSWLRRAsAPLPGLS     -0.275935     0.171766
# ...                                                       ...          ...
# SRRM1_T220 ENSP00000516157_T220 APEKKEKtPELPEPS     -0.409320    -0.590531
# SRRM1_T416 ENSP00000516157_T416 PKTRHsPtPQQSNRT     -0.073792    -0.671631
# SRRM1_T628 ENSP00000516157_T628 SPPPKRRtAsPPPPP     -0.400699    -0.715744
# SRRM1_T741 ENSP00000516157_T741 PIRRVSRtPEPKKIK     -0.327861    -0.729363
# NPLOC4_S36 ENSP00000516165_S36  AAAARGSsPEAGAAA      0.232393     0.209496
#
#                                                  C3L.08811.T  C3L.06506.N  \
# gene_site  Index                SequenceWindow
# M6PR_S267  ENSP00000000412_S267 DDQLGEEsEERDDHL     0.270358    -0.189374
# FKBP4_S258 ENSP00000001008_S258 SFEKAKEsWEMNSEE    -0.297788    -0.155746
# FKBP4_S453 ENSP00000001008_S453 SNTAGSQsQVETEA-    -0.508349    -0.758670
# CFTR_S737  ENSP00000003084_S737 EPLERRLsLVPDSEQ    -0.660221     0.194315
# HSPB6_S16  ENSP00000004982_S16  PSWLRRAsAPLPGLS    -0.359540     0.000663
# ...                                                      ...          ...
# SRRM1_T220 ENSP00000516157_T220 APEKKEKtPELPEPS     0.201572    -0.253919
# SRRM1_T416 ENSP00000516157_T416 PKTRHsPtPQQSNRT    -0.313469    -0.183969
# SRRM1_T628 ENSP00000516157_T628 SPPPKRRtAsPPPPP     0.368004    -0.101604
# SRRM1_T741 ENSP00000516157_T741 PIRRVSRtPEPKKIK    -0.337793    -0.406915
# NPLOC4_S36 ENSP00000516165_S36  AAAARGSsPEAGAAA     0.116361     0.258886
#
#                                                  C3L.07804.T  C3L.06595.T  \
# gene_site  Index                SequenceWindow
# M6PR_S267  ENSP00000000412_S267 DDQLGEEsEERDDHL    -0.337974     0.032672
# FKBP4_S258 ENSP00000001008_S258 SFEKAKEsWEMNSEE     0.191954    -0.219349
# FKBP4_S453 ENSP00000001008_S453 SNTAGSQsQVETEA-    -0.499116    -0.021148
# CFTR_S737  ENSP00000003084_S737 EPLERRLsLVPDSEQ    -1.214076     0.950273
# HSPB6_S16  ENSP00000004982_S16  PSWLRRAsAPLPGLS    -0.179875    -0.144970
# ...                                                      ...          ...
# SRRM1_T220 ENSP00000516157_T220 APEKKEKtPELPEPS     0.090555     0.149341
# SRRM1_T416 ENSP00000516157_T416 PKTRHsPtPQQSNRT    -0.113390     0.094610
# SRRM1_T628 ENSP00000516157_T628 SPPPKRRtAsPPPPP     0.177564    -0.062989
# SRRM1_T741 ENSP00000516157_T741 PIRRVSRtPEPKKIK    -0.378778    -0.110540
# NPLOC4_S36 ENSP00000516165_S36  AAAARGSsPEAGAAA     0.169640     0.312723
#
#                                                  C3L.06742.T  CHTN.45205.T  \
# gene_site  Index                SequenceWindow
# M6PR_S267  ENSP00000000412_S267 DDQLGEEsEERDDHL     0.066165      0.085354
# FKBP4_S258 ENSP00000001008_S258 SFEKAKEsWEMNSEE     1.642965     -0.006126
# FKBP4_S453 ENSP00000001008_S453 SNTAGSQsQVETEA-    -0.181385      0.138700
# CFTR_S737  ENSP00000003084_S737 EPLERRLsLVPDSEQ    -0.553533     -0.104649
# HSPB6_S16  ENSP00000004982_S16  PSWLRRAsAPLPGLS    -0.527644     -0.330870
# ...                                                      ...           ...
# SRRM1_T220 ENSP00000516157_T220 APEKKEKtPELPEPS     0.467441      0.567972
# SRRM1_T416 ENSP00000516157_T416 PKTRHsPtPQQSNRT     0.559364      0.479827
# SRRM1_T628 ENSP00000516157_T628 SPPPKRRtAsPPPPP     0.173630      0.104672
# SRRM1_T741 ENSP00000516157_T741 PIRRVSRtPEPKKIK     0.262443      0.279190
# NPLOC4_S36 ENSP00000516165_S36  AAAARGSsPEAGAAA     0.394092     -0.186984
#
#                                                  ...  C3L.07875.T  \
# gene_site  Index                SequenceWindow   ...
# M6PR_S267  ENSP00000000412_S267 DDQLGEEsEERDDHL  ...     0.252478
# FKBP4_S258 ENSP00000001008_S258 SFEKAKEsWEMNSEE  ...    -0.449688
# FKBP4_S453 ENSP00000001008_S453 SNTAGSQsQVETEA-  ...    -0.364357
# CFTR_S737  ENSP00000003084_S737 EPLERRLsLVPDSEQ  ...     0.801556
# HSPB6_S16  ENSP00000004982_S16  PSWLRRAsAPLPGLS  ...    -1.139613
# ...                                              ...          ...
# SRRM1_T220 ENSP00000516157_T220 APEKKEKtPELPEPS  ...     0.039659
# SRRM1_T416 ENSP00000516157_T416 PKTRHsPtPQQSNRT  ...     0.017260
# SRRM1_T628 ENSP00000516157_T628 SPPPKRRtAsPPPPP  ...    -0.051742
# SRRM1_T741 ENSP00000516157_T741 PIRRVSRtPEPKKIK  ...     0.073854
# NPLOC4_S36 ENSP00000516165_S36  AAAARGSsPEAGAAA  ...    -0.155709
#
#                                                  CHTN.44966.T  C3L.11192.N  \
# gene_site  Index                SequenceWindow
# M6PR_S267  ENSP00000000412_S267 DDQLGEEsEERDDHL     -0.057686    -0.230422
# FKBP4_S258 ENSP00000001008_S258 SFEKAKEsWEMNSEE     -0.903831    -0.748244
# FKBP4_S453 ENSP00000001008_S453 SNTAGSQsQVETEA-     -0.811015    -0.914554
# CFTR_S737  ENSP00000003084_S737 EPLERRLsLVPDSEQ      0.278902    -0.615359
# HSPB6_S16  ENSP00000004982_S16  PSWLRRAsAPLPGLS     -1.779075     1.965498
# ...                                                       ...          ...
# SRRM1_T220 ENSP00000516157_T220 APEKKEKtPELPEPS     -0.263828    -0.729216
# SRRM1_T416 ENSP00000516157_T416 PKTRHsPtPQQSNRT     -0.265258    -1.076544
# SRRM1_T628 ENSP00000516157_T628 SPPPKRRtAsPPPPP     -0.471699    -0.270337
# SRRM1_T741 ENSP00000516157_T741 PIRRVSRtPEPKKIK      0.005340    -0.565492
# NPLOC4_S36 ENSP00000516165_S36  AAAARGSsPEAGAAA     -0.148875     0.090768
#
#                                                  C3L.08805.T  C3L.09760.T  \
# gene_site  Index                SequenceWindow
# M6PR_S267  ENSP00000000412_S267 DDQLGEEsEERDDHL     1.183299     0.137987
# FKBP4_S258 ENSP00000001008_S258 SFEKAKEsWEMNSEE    -0.405466    -0.620764
# FKBP4_S453 ENSP00000001008_S453 SNTAGSQsQVETEA-    -0.444786    -0.178788
# CFTR_S737  ENSP00000003084_S737 EPLERRLsLVPDSEQ     2.598428     0.355969
# HSPB6_S16  ENSP00000004982_S16  PSWLRRAsAPLPGLS    -0.994687    -1.270175
# ...                                                      ...          ...
# SRRM1_T220 ENSP00000516157_T220 APEKKEKtPELPEPS     0.010298     0.034233
# SRRM1_T416 ENSP00000516157_T416 PKTRHsPtPQQSNRT    -0.380144    -0.104944
# SRRM1_T628 ENSP00000516157_T628 SPPPKRRtAsPPPPP     0.173586     0.186290
# SRRM1_T741 ENSP00000516157_T741 PIRRVSRtPEPKKIK    -0.138961     0.115739
# NPLOC4_S36 ENSP00000516165_S36  AAAARGSsPEAGAAA    -0.714214     0.124264
#
#                                                  C3L.08444.T  C3L.08291.T  \
# gene_site  Index                SequenceWindow
# M6PR_S267  ENSP00000000412_S267 DDQLGEEsEERDDHL     0.176602    -0.193945
# FKBP4_S258 ENSP00000001008_S258 SFEKAKEsWEMNSEE    -0.643077     0.458055
# FKBP4_S453 ENSP00000001008_S453 SNTAGSQsQVETEA-    -0.311887    -0.053362
# CFTR_S737  ENSP00000003084_S737 EPLERRLsLVPDSEQ    -0.661561    -0.427716
# HSPB6_S16  ENSP00000004982_S16  PSWLRRAsAPLPGLS    -0.393223    -1.831931
# ...                                                      ...          ...
# SRRM1_T220 ENSP00000516157_T220 APEKKEKtPELPEPS     0.009183     0.049145
# SRRM1_T416 ENSP00000516157_T416 PKTRHsPtPQQSNRT    -0.131461     0.127151
# SRRM1_T628 ENSP00000516157_T628 SPPPKRRtAsPPPPP    -0.195923     0.125274
# SRRM1_T741 ENSP00000516157_T741 PIRRVSRtPEPKKIK     0.211480     0.358787
# NPLOC4_S36 ENSP00000516165_S36  AAAARGSsPEAGAAA     0.071905     0.294382
#
#                                                  C3L.10583.T  C3L.07877.T  \
# gene_site  Index                SequenceWindow
# M6PR_S267  ENSP00000000412_S267 DDQLGEEsEERDDHL     0.002367     0.347335
# FKBP4_S258 ENSP00000001008_S258 SFEKAKEsWEMNSEE    -0.952692    -0.502935
# FKBP4_S453 ENSP00000001008_S453 SNTAGSQsQVETEA-    -1.103506    -0.307088
# CFTR_S737  ENSP00000003084_S737 EPLERRLsLVPDSEQ    -0.375639     0.436811
# HSPB6_S16  ENSP00000004982_S16  PSWLRRAsAPLPGLS    -1.344243    -0.086774
# ...                                                      ...          ...
# SRRM1_T220 ENSP00000516157_T220 APEKKEKtPELPEPS    -0.502502    -0.262857
# SRRM1_T416 ENSP00000516157_T416 PKTRHsPtPQQSNRT    -0.603184    -0.289414
# SRRM1_T628 ENSP00000516157_T628 SPPPKRRtAsPPPPP    -0.450014    -0.183483
# SRRM1_T741 ENSP00000516157_T741 PIRRVSRtPEPKKIK    -0.744537    -0.185620
# NPLOC4_S36 ENSP00000516165_S36  AAAARGSsPEAGAAA    -0.243123    -0.006714
#
#                                                  C3L.08736.T
# gene_site  Index                SequenceWindow
# M6PR_S267  ENSP00000000412_S267 DDQLGEEsEERDDHL     0.161394
# FKBP4_S258 ENSP00000001008_S258 SFEKAKEsWEMNSEE     0.764775
# FKBP4_S453 ENSP00000001008_S453 SNTAGSQsQVETEA-    -0.386649
# CFTR_S737  ENSP00000003084_S737 EPLERRLsLVPDSEQ    -0.532016
# HSPB6_S16  ENSP00000004982_S16  PSWLRRAsAPLPGLS    -1.857233
# ...                                                      ...
# SRRM1_T220 ENSP00000516157_T220 APEKKEKtPELPEPS    -0.407581
# SRRM1_T416 ENSP00000516157_T416 PKTRHsPtPQQSNRT    -0.497071
# SRRM1_T628 ENSP00000516157_T628 SPPPKRRtAsPPPPP    -0.182057
# SRRM1_T741 ENSP00000516157_T741 PIRRVSRtPEPKKIK     0.008543
# NPLOC4_S36 ENSP00000516165_S36  AAAARGSsPEAGAAA     0.140012
#
# [9498 rows x 178 columns]

# %%
samples = data.columns.tolist()
len(samples)
# Out:
# 178

# %%
set_tumors_included = set(tumors_included)
set_tumors_excluded = set(tumors_excluded)
set_normals = set(normals)
set_data = set(samples)
print((len(set_tumors_included), len(set_tumors_excluded), len(set_normals), len(set_data)))
# Out:
# (134, 16, 33, 178)

# %%
set_data - set_tumors_included - set_tumors_excluded - set_normals
# Out:
# {'C3L.06436.T',
#  'C3L.07292.N',
#  'C3L.07606.N',
#  'C3L.08546.T',
#  'C3L.09345.T',
#  'C3L.09373.T',
#  'C3L.09793.T',
#  'C3L.09832.T',
#  'C3L.09972.T',
#  'C3L.10301.T',
#  'CHTN.47295.T'}

# %%
data.boxplot(figsize=(40,6), rot=90)
# Out:
# <Axes: >

# %%
from omicsone_streamlit.plots.pca import plot_pca1

# %%
print(len(tumors_included), len(normals))
# Out:
# 134 33

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = "Tumor"
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"

# %%
len(set(data.columns) & set(tumors_included))
# Out:
# 134

# %%
data2 = data_nomiss.T.loc[tumors_included + normals,:]
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')

# %%
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-70,70), ylim=(-70,70), figsize=(6,6),
                    title="PCA of phospho TMT ratio (colored by group)")

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = purity_map.get(i, "Tumor")
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-70,70), ylim=(-70,70), figsize=(6,6),
                    title="PCA of phospho TMT ratio (colored by purity)")

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = re.sub("[ABC]",'',stage_map.get(i, "Tumor"))
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-70,70), ylim=(-70,70), figsize=(6,6),
                    title="PCA of phospho TMT log2ratio (colored by stage)")
