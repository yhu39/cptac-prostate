# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import re,sys,os
import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib

# Set font to Arial
matplotlib.rcParams['font.family'] = 'Arial'

# Optional: Set PDF to embed fonts (for Illustrator editing)
matplotlib.rcParams['pdf.fonttype'] = 42  # TrueType fonts for better editing

# %%
DATA_DIR = Path(r"D:\lab\cptac_prostate\data\v4\CPTAC")
OUTPUT_DIR = Path(r"D:\lab\cptac_prostate\runs\20260330_cptac_protein_tmt_pca")
print(DATA_DIR.exists(), OUTPUT_DIR.exists())
meta_path = DATA_DIR / "20_MetaData_03_12_2026.csv"
# Out:
# True False

# %%
meta = pd.read_csv(meta_path)
meta
# Out:
#         case_id     common_ID Tissuetype include_or_excludetumor  \
# 0     C3L-07287   C3L.07287.T      tumor                 Include
# 1     C3L-11156   C3L.11156.T      tumor                 Include
# 2     C3L-09494   C3L.09494.T      tumor                 Include
# 3    CHTN-49141  CHTN.49141.T      tumor                 Include
# 4     C3L-11095   C3L.11095.T      tumor                 Include
# ..          ...           ...        ...                     ...
# 178   C3L-07872   C3L.07872.T      tumor                 Include
# 179   C3L-08642   C3L.08642.T      tumor                 Include
# 180   C3L-10399   C3L.10399.T      tumor                 Include
# 181   C3L-05301   C3L.05301.T      tumor                 Include
# 182   C3L-08384   C3L.08384.T      tumor                 Include
#
#          FirstCategory AdditionalSegments SecondCategory ThirdCategory  \
# 0    Sufficient Purity                ETS            ETS           NaN
# 1    Sufficient Purity                ETS            ETS           NaN
# 2    Sufficient Purity                ETS            ETS           NaN
# 3    Sufficient Purity                ETS            ETS           NaN
# 4    Sufficient Purity                ETS            ETS           NaN
# ..                 ...                ...            ...           ...
# 178         Low Purity                NaN            NaN           NaN
# 179         Low Purity                NaN            NaN           NaN
# 180         Low Purity                NaN            NaN           NaN
# 181         Low Purity                NaN            NaN           NaN
# 182         Low Purity                NaN            NaN           NaN
#
#     all_drivers Main_Groups  ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  \
# 0           ERG         ERG  ...    0.342000      0.000000   0.0   0.0   1.0
# 1           ERG         ERG  ...    0.000000      0.498000   0.0   0.0   1.0
# 2           ERG         ERG  ...    0.281000      0.000000   0.0   1.0   0.0
# 3           ERG         ERG  ...    0.420000      0.000000   0.0   1.0   0.0
# 4           ERG         ERG  ...    0.000000      0.369000   0.0   0.0   1.0
# ..          ...         ...  ...         ...           ...   ...   ...   ...
# 178         ERG         ERG  ...    0.000000      0.460832   1.0   0.0   0.0
# 179         ERG         ERG  ...    0.000000      0.334840   0.0   0.0   1.0
# 180         ERG         ERG  ...    0.000000      0.445334   0.0   0.0   1.0
# 181        ETV1        ETV1  ...    0.000000      0.457908   0.0   0.0   1.0
# 182         ERG         ERG  ...    0.789835      0.000000   0.0   0.0   0.0
#
#      LumB  Normal  agg_rank_raw  agg_rank_scaled  risk_group
# 0     0.0     0.0     55.333000         0.409000          IR
# 1     0.0     0.0     44.167000         0.325000          LR
# 2     0.0     0.0    123.167000         0.919000          HR
# 3     0.0     0.0    103.833000         0.773000          HR
# 4     0.0     0.0     44.667000         0.328000          LR
# ..    ...     ...           ...              ...         ...
# 178   0.0     0.0     73.666667         0.546366          IR
# 179   0.0     0.0     46.166667         0.339599          LR
# 180   0.0     0.0     60.000000         0.443609          IR
# 181   0.0     0.0     45.333333         0.333333          LR
# 182   1.0     0.0     88.166667         0.655000          HR
#
# [183 rows x 113 columns]

# %%
meta_include = meta[meta["include_or_excludetumor"] == "Include"]
meta_include
# Out:
#         case_id     common_ID Tissuetype include_or_excludetumor  \
# 0     C3L-07287   C3L.07287.T      tumor                 Include
# 1     C3L-11156   C3L.11156.T      tumor                 Include
# 2     C3L-09494   C3L.09494.T      tumor                 Include
# 3    CHTN-49141  CHTN.49141.T      tumor                 Include
# 4     C3L-11095   C3L.11095.T      tumor                 Include
# ..          ...           ...        ...                     ...
# 178   C3L-07872   C3L.07872.T      tumor                 Include
# 179   C3L-08642   C3L.08642.T      tumor                 Include
# 180   C3L-10399   C3L.10399.T      tumor                 Include
# 181   C3L-05301   C3L.05301.T      tumor                 Include
# 182   C3L-08384   C3L.08384.T      tumor                 Include
#
#          FirstCategory AdditionalSegments SecondCategory ThirdCategory  \
# 0    Sufficient Purity                ETS            ETS           NaN
# 1    Sufficient Purity                ETS            ETS           NaN
# 2    Sufficient Purity                ETS            ETS           NaN
# 3    Sufficient Purity                ETS            ETS           NaN
# 4    Sufficient Purity                ETS            ETS           NaN
# ..                 ...                ...            ...           ...
# 178         Low Purity                NaN            NaN           NaN
# 179         Low Purity                NaN            NaN           NaN
# 180         Low Purity                NaN            NaN           NaN
# 181         Low Purity                NaN            NaN           NaN
# 182         Low Purity                NaN            NaN           NaN
#
#     all_drivers Main_Groups  ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  \
# 0           ERG         ERG  ...    0.342000      0.000000   0.0   0.0   1.0
# 1           ERG         ERG  ...    0.000000      0.498000   0.0   0.0   1.0
# 2           ERG         ERG  ...    0.281000      0.000000   0.0   1.0   0.0
# 3           ERG         ERG  ...    0.420000      0.000000   0.0   1.0   0.0
# 4           ERG         ERG  ...    0.000000      0.369000   0.0   0.0   1.0
# ..          ...         ...  ...         ...           ...   ...   ...   ...
# 178         ERG         ERG  ...    0.000000      0.460832   1.0   0.0   0.0
# 179         ERG         ERG  ...    0.000000      0.334840   0.0   0.0   1.0
# 180         ERG         ERG  ...    0.000000      0.445334   0.0   0.0   1.0
# 181        ETV1        ETV1  ...    0.000000      0.457908   0.0   0.0   1.0
# 182         ERG         ERG  ...    0.789835      0.000000   0.0   0.0   0.0
#
#      LumB  Normal  agg_rank_raw  agg_rank_scaled  risk_group
# 0     0.0     0.0     55.333000         0.409000          IR
# 1     0.0     0.0     44.167000         0.325000          LR
# 2     0.0     0.0    123.167000         0.919000          HR
# 3     0.0     0.0    103.833000         0.773000          HR
# 4     0.0     0.0     44.667000         0.328000          LR
# ..    ...     ...           ...              ...         ...
# 178   0.0     0.0     73.666667         0.546366          IR
# 179   0.0     0.0     46.166667         0.339599          LR
# 180   0.0     0.0     60.000000         0.443609          IR
# 181   0.0     0.0     45.333333         0.333333          LR
# 182   1.0     0.0     88.166667         0.655000          HR
#
# [134 rows x 113 columns]

# %%
purity_map = dict(zip(meta_include["common_ID"], meta_include["FirstCategory"]))
stage_map = dict(zip(meta_include["common_ID"], meta_include["stage"]))
gleason_map = dict(zip(meta_include["common_ID"], meta_include["Gleason_um"]))

# %%
meta_exclude = meta[meta["include_or_excludetumor"] == "exclude"]
meta_exclude
# Out:
#        case_id    common_ID Tissuetype include_or_excludetumor FirstCategory  \
# 144  C3L-09492  C3L.09492.T      tumor                 exclude      No Tumor
# 145  C3L-09497  C3L.09497.T      tumor                 exclude      No Tumor
# 146  C3L-06260  C3L.06260.T      tumor                 exclude      No Tumor
# 147  C3L-06510  C3L.06510.T      tumor                 exclude      No Tumor
# 148  C3L-07890  C3L.07890.T      tumor                 exclude      No Tumor
# 149  C3L-09372  C3L.09372.T      tumor                 exclude      No Tumor
# 150  C3N-09047  C3N.09047.T      tumor                 exclude      No Tumor
# 151  C3L-07868  C3L.07868.T      tumor                 exclude      No Tumor
# 152  C3L-09563  C3L.09563.T      tumor                 exclude      No Tumor
# 153  C3L-10319  C3L.10319.T      tumor                 exclude      No Tumor
# 154  C3L-06657  C3L.06657.T      tumor                 exclude      No Tumor
# 155  C3L-07405  C3L.07405.T      tumor                 exclude      No Tumor
# 156  C3L-06573  C3L.06573.T      tumor                 exclude      No Tumor
# 157  C3L-07813  C3L.07813.T      tumor                 exclude      No Tumor
# 158  C3L-08377  C3L.08377.T      tumor                 exclude      No Tumor
# 159  C3L-08371  C3L.08371.T      tumor                 exclude      No Tumor
#
#     AdditionalSegments SecondCategory ThirdCategory all_drivers Main_Groups  \
# 144                NaN            NaN           NaN         NaN    No Tumor
# 145                NaN            NaN           NaN         NaN    No Tumor
# 146                NaN            NaN           NaN         NaN    No Tumor
# 147                NaN            NaN           NaN         NaN    No Tumor
# 148                NaN            NaN           NaN         NaN    No Tumor
# 149                NaN            NaN           NaN         NaN    No Tumor
# 150                NaN            NaN           NaN         NaN    No Tumor
# 151                NaN            NaN           NaN         NaN    No Tumor
# 152                NaN            NaN           NaN         NaN    No Tumor
# 153                NaN            NaN           NaN         NaN    No Tumor
# 154                NaN            NaN           NaN         NaN    No Tumor
# 155                NaN            NaN           NaN         NaN    No Tumor
# 156                NaN            NaN           NaN         NaN    No Tumor
# 157                NaN            NaN           NaN         NaN    No Tumor
# 158                NaN            NaN           NaN         NaN    No Tumor
# 159                NaN            NaN           NaN         NaN    No Tumor
#
#      ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  LumB  Normal  \
# 144  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 145  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 146  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 147  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 148  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 149  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 150  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 151  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 152  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 153  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 154  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 155  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 156  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 157  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 158  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 159  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
#
#      agg_rank_raw  agg_rank_scaled  risk_group
# 144           NaN              NaN         NaN
# 145           NaN              NaN         NaN
# 146           NaN              NaN         NaN
# 147           NaN              NaN         NaN
# 148           NaN              NaN         NaN
# 149           NaN              NaN         NaN
# 150           NaN              NaN         NaN
# 151           NaN              NaN         NaN
# 152           NaN              NaN         NaN
# 153           NaN              NaN         NaN
# 154           NaN              NaN         NaN
# 155           NaN              NaN         NaN
# 156           NaN              NaN         NaN
# 157           NaN              NaN         NaN
# 158           NaN              NaN         NaN
# 159           NaN              NaN         NaN
#
# [16 rows x 113 columns]

# %%
meta_normal = meta[meta["include_or_excludetumor"] == "normal"]
meta_normal
# Out:
#        case_id    common_ID Tissuetype include_or_excludetumor FirstCategory  \
# 111  C3L-07813  C3L.07813.N     normal                  normal        Normal
# 112  C3L-06504  C3L.06504.N     normal                  normal        Normal
# 113  C3L-06506  C3L.06506.N     normal                  normal        Normal
# 114  C3L-06741  C3L.06741.N     normal                  normal        Normal
# 115  C3L-06890  C3L.06890.N     normal                  normal        Normal
# 116  C3L-06901  C3L.06901.N     normal                  normal        Normal
# 117  C3L-06743  C3L.06743.N     normal                  normal        Normal
# 118  C3L-07607  C3L.07607.N     normal                  normal        Normal
# 119  C3L-06436  C3L.06436.N     normal                  normal        Normal
# 120  C3L-07809  C3L.07809.N     normal                  normal        Normal
# 121  C3L-07872  C3L.07872.N     normal                  normal        Normal
# 122  C3L-08293  C3L.08293.N     normal                  normal        Normal
# 123  C3L-07871  C3L.07871.N     normal                  normal        Normal
# 124  C3L-08084  C3L.08084.N     normal                  normal        Normal
# 125  C3L-08371  C3L.08371.N     normal                  normal        Normal
# 126  C3L-08372  C3L.08372.N     normal                  normal        Normal
# 127  C3L-08818  C3L.08818.N     normal                  normal        Normal
# 128  C3L-08380  C3L.08380.N     normal                  normal        Normal
# 129  C3L-08811  C3L.08811.N     normal                  normal        Normal
# 130  C3L-08378  C3L.08378.N     normal                  normal        Normal
# 131  C3L-08382  C3L.08382.N     normal                  normal        Normal
# 132  C3L-09107  C3L.09107.N     normal                  normal        Normal
# 133  C3L-09701  C3L.09701.N     normal                  normal        Normal
# 134  C3L-06252  C3L.06252.N     normal                  normal        Normal
# 135  C3L-08755  C3L.08755.N     normal                  normal        Normal
# 136  C3L-06260  C3L.06260.N     normal                  normal        Normal
# 137  C3L-06261  C3L.06261.N     normal                  normal        Normal
# 138  C3L-09691  C3L.09691.N     normal                  normal        Normal
# 139  C3L-11176  C3L.11176.N     normal                  normal        Normal
# 140  C3L-08800  C3L.08800.N     normal                  normal        Normal
# 141  C3L-08802  C3L.08802.N     normal                  normal        Normal
# 142  C3L-11192  C3L.11192.N     normal                  normal        Normal
# 143  C3L-11122  C3L.11122.N     normal                  normal        Normal
#
#     AdditionalSegments SecondCategory ThirdCategory all_drivers Main_Groups  \
# 111                NaN            NaN           NaN      normal      normal
# 112                NaN            NaN           NaN      normal      normal
# 113                NaN            NaN           NaN      normal      normal
# 114                NaN            NaN           NaN      normal      normal
# 115                NaN            NaN           NaN      normal      normal
# 116                NaN            NaN           NaN      normal      normal
# 117                NaN            NaN           NaN      normal      normal
# 118                NaN            NaN           NaN      normal      normal
# 119                NaN            NaN           NaN      normal      normal
# 120                NaN            NaN           NaN      normal      normal
# 121                NaN            NaN           NaN      normal      normal
# 122                NaN            NaN           NaN      normal      normal
# 123                NaN            NaN           NaN      normal      normal
# 124                NaN            NaN           NaN      normal      normal
# 125                NaN            NaN           NaN      normal      normal
# 126                NaN            NaN           NaN      normal      normal
# 127                NaN            NaN           NaN      normal      normal
# 128                NaN            NaN           NaN      normal      normal
# 129                NaN            NaN           NaN      normal      normal
# 130                NaN            NaN           NaN      normal      normal
# 131                NaN            NaN           NaN      normal      normal
# 132                NaN            NaN           NaN      normal      normal
# 133                NaN            NaN           NaN      normal      normal
# 134                NaN            NaN           NaN      normal      normal
# 135                NaN            NaN           NaN      normal      normal
# 136                NaN            NaN           NaN      normal      normal
# 137                NaN            NaN           NaN      normal      normal
# 138                NaN            NaN           NaN      normal      normal
# 139                NaN            NaN           NaN      normal      normal
# 140                NaN            NaN           NaN      normal      normal
# 141                NaN            NaN           NaN      normal      normal
# 142                NaN            NaN           NaN      normal      normal
# 143                NaN            NaN           NaN      normal      normal
#
#      ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  LumB  Normal  \
# 111  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 112  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 113  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 114  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 115  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 116  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 117  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 118  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 119  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 120  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 121  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 122  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 123  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 124  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 125  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 126  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 127  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 128  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 129  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 130  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 131  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 132  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 133  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 134  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 135  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 136  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 137  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 138  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 139  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 140  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 141  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 142  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 143  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
#
#      agg_rank_raw  agg_rank_scaled  risk_group
# 111           NaN              NaN         NaN
# 112           NaN              NaN         NaN
# 113           NaN              NaN         NaN
# 114           NaN              NaN         NaN
# 115           NaN              NaN         NaN
# 116           NaN              NaN         NaN
# 117           NaN              NaN         NaN
# 118           NaN              NaN         NaN
# 119           NaN              NaN         NaN
# 120           NaN              NaN         NaN
# 121           NaN              NaN         NaN
# 122           NaN              NaN         NaN
# 123           NaN              NaN         NaN
# 124           NaN              NaN         NaN
# 125           NaN              NaN         NaN
# 126           NaN              NaN         NaN
# 127           NaN              NaN         NaN
# 128           NaN              NaN         NaN
# 129           NaN              NaN         NaN
# 130           NaN              NaN         NaN
# 131           NaN              NaN         NaN
# 132           NaN              NaN         NaN
# 133           NaN              NaN         NaN
# 134           NaN              NaN         NaN
# 135           NaN              NaN         NaN
# 136           NaN              NaN         NaN
# 137           NaN              NaN         NaN
# 138           NaN              NaN         NaN
# 139           NaN              NaN         NaN
# 140           NaN              NaN         NaN
# 141           NaN              NaN         NaN
# 142           NaN              NaN         NaN
# 143           NaN              NaN         NaN
#
# [33 rows x 113 columns]

# %%
tumors_included = meta_include['common_ID'].tolist()
tumors_excluded = meta_exclude['common_ID'].tolist()
print(len(tumors_included), len(tumors_excluded))
# Out:
# 134 16

# %%
normals = meta_normal['common_ID'].tolist()
print(len(normals))
# Out:
# 33

# %%
# data
files = [i for i in DATA_DIR.iterdir() if i.is_file()]
files = [i for i in files if re.search(r"pY_TMT_ratio",i.stem, re.IGNORECASE) \
         and not re.search(r"tumor_purity_corrected",i.stem, re.IGNORECASE)\
            and not re.search(r"normalized",i.stem, re.IGNORECASE) ]
data_path = files[0]
print(data_path)
header_cols = ["gene_site","Index","SequenceWindow"]
data = pd.read_csv(data_path,sep="\t").set_index(header_cols)
data_nomiss = data.dropna()
# Out:
# D:\lab\cptac_prostate\data\v4\CPTAC\prostate_CPTAC_pY_TMT_ratio_single_site_MD.tsv

# %%
files
# Out:
# [WindowsPath('D:/lab/cptac_prostate/data/v4/CPTAC/prostate_CPTAC_pY_TMT_ratio_single_site_MD.tsv')]

# %%
data
# Out:
#                                                     C3L.05292.T  C3L.09383.T  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF     0.007771    -0.183740
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS          NaN          NaN
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP     0.015442    -0.375862
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN          NaN
# ...                                                         ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.902727    -0.074278
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.622543     0.054878
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN          NaN
#
#                                                     CHTN.43798.T  C3L.06261.N  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF      0.130516    -0.170274
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS           NaN          NaN
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK           NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP     -1.163532    -0.494229
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR           NaN          NaN
# ...                                                          ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK     -1.002384     0.886436
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL           NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT      0.358320     0.109835
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK           NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK           NaN          NaN
#
#                                                     C3L.08811.T  C3L.06506.N  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF     0.452346     0.127803
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS          NaN          NaN
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP     0.102381    -0.959121
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN          NaN
# ...                                                         ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.085031    -0.335410
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.358042     0.483470
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN          NaN
#
#                                                     C3L.07804.T  C3L.06595.T  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF    -0.066630    -0.155750
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS          NaN          NaN
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP     0.602782    -0.622921
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN          NaN
# ...                                                         ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK     1.109780    -0.707351
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.185560    -0.049959
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN          NaN
#
#                                                     C3L.06742.T  CHTN.45205.T  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF     0.854168      0.158306
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS          NaN           NaN
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN           NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.362777     -0.083269
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN           NaN
# ...                                                         ...           ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.679854     -0.718268
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN           NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.172578     -0.075357
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN           NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN           NaN
#
#                                                     ...  C3L.07875.T  \
# gene_site     Index                SequenceWindow   ...
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF  ...          NaN
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS  ...    -0.101565
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK  ...          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP  ...    -0.549456
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR  ...          NaN
# ...                                                 ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK  ...    -0.824548
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL  ...          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT  ...    -0.001194
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK  ...          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK  ...          NaN
#
#                                                     CHTN.44966.T  C3L.11192.N  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF           NaN          NaN
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS     -0.029481    -0.080865
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK           NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP     -0.818834    -0.920586
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR           NaN          NaN
# ...                                                          ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK     -0.537083     1.186222
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL           NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT      0.049886     0.365298
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK           NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK           NaN          NaN
#
#                                                     C3L.08805.T  C3L.09760.T  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF          NaN          NaN
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS     1.172404     0.304243
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.033956     0.499599
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN          NaN
# ...                                                         ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK     0.055278    -0.242540
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.073975    -0.655857
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN          NaN
#
#                                                     C3L.08444.T  C3L.08291.T  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF          NaN          NaN
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS    -0.774474     0.287002
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.609548    -0.125364
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN          NaN
# ...                                                         ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.611673    -0.603313
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.266457    -0.397943
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN          NaN
#
#                                                     C3L.10583.T  C3L.07877.T  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF          NaN          NaN
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS     0.834276    -0.574202
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.208995    -0.838668
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN          NaN
# ...                                                         ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK     0.412426    -0.148677
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT     0.007785    -0.191893
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN          NaN
#
#                                                     C3L.08736.T
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF          NaN
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS     0.289791
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.234925
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN
# ...                                                         ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.139364
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.833233
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN
#
# [1361 rows x 178 columns]

# %%
data_nomiss
# Out:
#                                                    C3L.05292.T  C3L.09383.T  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP     0.015442    -0.375862
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD    -0.114235    -0.722111
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP     0.310122     0.595194
# BCAR1_Y128   ENSP00000162330_Y128 SKAQQGLyQVPGPSP    -0.040449    -0.088164
# BCAR1_Y249   ENSP00000162330_Y249 APGPQDIyDVPPVRG     0.179554     0.005745
# ...                                                        ...          ...
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK     0.083845     0.213511
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -1.273807    -1.565090
# STAT3_Y672   ENSP00000504062_Y672 ADPGAAPyLKTKFIC     1.361964    -0.373369
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.902727    -0.074278
# ANXA6_Y302   ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.622543     0.054878
#
#                                                    CHTN.43798.T  C3L.06261.N  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP     -1.163532    -0.494229
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD      0.102058    -0.187068
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP      0.069838     0.225547
# BCAR1_Y128   ENSP00000162330_Y128 SKAQQGLyQVPGPSP      0.172848    -0.104125
# BCAR1_Y249   ENSP00000162330_Y249 APGPQDIyDVPPVRG     -0.040891     0.014477
# ...                                                         ...          ...
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK      0.462800     0.196913
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH     -1.195885    -1.117502
# STAT3_Y672   ENSP00000504062_Y672 ADPGAAPyLKTKFIC     -1.168888     0.152937
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK     -1.002384     0.886436
# ANXA6_Y302   ENSP00000514965_Y302 TKYEKSLySMIKNDT      0.358320     0.109835
#
#                                                    C3L.08811.T  C3L.06506.N  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP     0.102381    -0.959121
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD    -0.003088    -0.070138
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP     0.478180     0.088927
# BCAR1_Y128   ENSP00000162330_Y128 SKAQQGLyQVPGPSP     0.254596    -0.158604
# BCAR1_Y249   ENSP00000162330_Y249 APGPQDIyDVPPVRG    -0.116087    -0.058120
# ...                                                        ...          ...
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK     0.106564     0.479878
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -0.944680    -1.109961
# STAT3_Y672   ENSP00000504062_Y672 ADPGAAPyLKTKFIC    -0.043557    -0.620996
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.085031    -0.335410
# ANXA6_Y302   ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.358042     0.483470
#
#                                                    C3L.07804.T  C3L.06595.T  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP     0.602782    -0.622921
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD    -1.426197    -0.086839
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP     0.276777     0.264503
# BCAR1_Y128   ENSP00000162330_Y128 SKAQQGLyQVPGPSP     0.962407    -0.195891
# BCAR1_Y249   ENSP00000162330_Y249 APGPQDIyDVPPVRG     0.166548     0.063048
# ...                                                        ...          ...
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK     0.394102     0.213891
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -1.421626    -1.908909
# STAT3_Y672   ENSP00000504062_Y672 ADPGAAPyLKTKFIC    -1.320485    -0.810773
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK     1.109780    -0.707351
# ANXA6_Y302   ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.185560    -0.049959
#
#                                                    C3L.06742.T  CHTN.45205.T  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.362777     -0.083269
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD     0.055798     -0.259609
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP    -0.026284      0.469559
# BCAR1_Y128   ENSP00000162330_Y128 SKAQQGLyQVPGPSP    -1.355665     -0.473180
# BCAR1_Y249   ENSP00000162330_Y249 APGPQDIyDVPPVRG    -0.051477     -0.017858
# ...                                                        ...           ...
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK     0.521847      0.175795
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -0.359126     -0.493581
# STAT3_Y672   ENSP00000504062_Y672 ADPGAAPyLKTKFIC    -1.427709     -0.661264
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.679854     -0.718268
# ANXA6_Y302   ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.172578     -0.075357
#
#                                                    ...  C3L.07875.T  \
# gene_site    Index                SequenceWindow   ...
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP  ...    -0.549456
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD  ...     0.154668
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP  ...     0.275193
# BCAR1_Y128   ENSP00000162330_Y128 SKAQQGLyQVPGPSP  ...     0.557561
# BCAR1_Y249   ENSP00000162330_Y249 APGPQDIyDVPPVRG  ...     0.316122
# ...                                                ...          ...
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK  ...    -0.359833
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH  ...    -0.125174
# STAT3_Y672   ENSP00000504062_Y672 ADPGAAPyLKTKFIC  ...     0.101060
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK  ...    -0.824548
# ANXA6_Y302   ENSP00000514965_Y302 TKYEKSLySMIKNDT  ...    -0.001194
#
#                                                    CHTN.44966.T  C3L.11192.N  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP     -0.818834    -0.920586
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD     -0.322113     0.472714
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP     -0.214003    -0.427348
# BCAR1_Y128   ENSP00000162330_Y128 SKAQQGLyQVPGPSP      0.111724     0.309806
# BCAR1_Y249   ENSP00000162330_Y249 APGPQDIyDVPPVRG      0.340708    -0.042285
# ...                                                         ...          ...
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK      0.504671     0.545402
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH     -0.013787     0.743851
# STAT3_Y672   ENSP00000504062_Y672 ADPGAAPyLKTKFIC     -1.498129    -0.876821
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK     -0.537083     1.186222
# ANXA6_Y302   ENSP00000514965_Y302 TKYEKSLySMIKNDT      0.049886     0.365298
#
#                                                    C3L.08805.T  C3L.09760.T  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.033956     0.499599
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD    -0.081977    -0.363581
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP    -1.276193    -0.064190
# BCAR1_Y128   ENSP00000162330_Y128 SKAQQGLyQVPGPSP     1.192937     0.114411
# BCAR1_Y249   ENSP00000162330_Y249 APGPQDIyDVPPVRG    -0.267634     0.006251
# ...                                                        ...          ...
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK    -0.484584     0.743388
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -0.104898     0.166575
# STAT3_Y672   ENSP00000504062_Y672 ADPGAAPyLKTKFIC     1.736894     1.260736
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK     0.055278    -0.242540
# ANXA6_Y302   ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.073975    -0.655857
#
#                                                    C3L.08444.T  C3L.08291.T  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.609548    -0.125364
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD    -0.256132    -0.467044
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP    -0.139204    -0.455382
# BCAR1_Y128   ENSP00000162330_Y128 SKAQQGLyQVPGPSP     0.240440    -1.270355
# BCAR1_Y249   ENSP00000162330_Y249 APGPQDIyDVPPVRG     0.038183     0.299134
# ...                                                        ...          ...
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK     0.463790     0.137153
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -0.142717    -0.289254
# STAT3_Y672   ENSP00000504062_Y672 ADPGAAPyLKTKFIC    -0.906757    -0.694538
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.611673    -0.603313
# ANXA6_Y302   ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.266457    -0.397943
#
#                                                    C3L.10583.T  C3L.07877.T  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.208995    -0.838668
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD    -0.069758    -0.348371
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP    -0.288295     0.092014
# BCAR1_Y128   ENSP00000162330_Y128 SKAQQGLyQVPGPSP    -0.001029     0.632601
# BCAR1_Y249   ENSP00000162330_Y249 APGPQDIyDVPPVRG     0.012437     0.232233
# ...                                                        ...          ...
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK    -0.295199     0.381574
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -0.140578     0.461418
# STAT3_Y672   ENSP00000504062_Y672 ADPGAAPyLKTKFIC     0.730985    -0.095938
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK     0.412426    -0.148677
# ANXA6_Y302   ENSP00000514965_Y302 TKYEKSLySMIKNDT     0.007785    -0.191893
#
#                                                    C3L.08736.T
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.234925
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD    -0.864185
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP     0.143386
# BCAR1_Y128   ENSP00000162330_Y128 SKAQQGLyQVPGPSP    -0.470197
# BCAR1_Y249   ENSP00000162330_Y249 APGPQDIyDVPPVRG    -0.012032
# ...                                                        ...
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK     0.374587
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -0.015789
# STAT3_Y672   ENSP00000504062_Y672 ADPGAAPyLKTKFIC    -0.777556
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.139364
# ANXA6_Y302   ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.833233
#
# [276 rows x 178 columns]

# %%
samples = data.columns.tolist()
len(samples)
# Out:
# 178

# %%
set_tumors_included = set(tumors_included)
set_tumors_excluded = set(tumors_excluded)
set_normals = set(normals)
set_data = set(samples)
print((len(set_tumors_included), len(set_tumors_excluded), len(set_normals), len(set_data)))
# Out:
# (134, 16, 33, 178)

# %%
set_data - set_tumors_included - set_tumors_excluded - set_normals
# Out:
# {'C3L.06436.T',
#  'C3L.07292.N',
#  'C3L.07606.N',
#  'C3L.08546.T',
#  'C3L.09345.T',
#  'C3L.09373.T',
#  'C3L.09793.T',
#  'C3L.09832.T',
#  'C3L.09972.T',
#  'C3L.10301.T',
#  'CHTN.47295.T'}

# %%
data.boxplot(figsize=(40,6), rot=90)
# Out:
# <Axes: >

# %%
from omicsone_streamlit.plots.pca import plot_pca1

# %%
print(len(tumors_included), len(normals))
# Out:
# 134 33

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = "Tumor"
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"

# %%
len(set(data.columns) & set(tumors_included))
# Out:
# 134

# %%
data2 = data_nomiss.T.loc[tumors_included + normals,:]
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')

# %%
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-20,20), ylim=(-20,20), figsize=(6,6),
                    title="PCA of pY log2ratio (colored by group)")

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = purity_map.get(i, "Tumor")
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-20,20), ylim=(-20,20), figsize=(6,6),
                    title="PCA of pY log2ratio (colored by purity)")

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = re.sub("[ABC]",'',stage_map.get(i, "Tumor"))
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-20,20), ylim=(-20,20), figsize=(6,6),
                    title="PCA of pY log2ratio (colored by stage)")
