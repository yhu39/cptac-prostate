# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import re,sys,os
import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib

# Set font to Arial
matplotlib.rcParams['font.family'] = 'Arial'

# Optional: Set PDF to embed fonts (for Illustrator editing)
matplotlib.rcParams['pdf.fonttype'] = 42  # TrueType fonts for better editing

# %%
DATA_DIR = Path(r"D:\lab\cptac_prostate\data\v4\CPTAC")
OUTPUT_DIR = Path(r"D:\lab\cptac_prostate\runs\20260330_cptac_ubi_tmt_pca")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print(DATA_DIR.exists(), OUTPUT_DIR.exists())
meta_path = DATA_DIR / "20_MetaData_03_12_2026.csv"
# Out:
# True True

# %%
meta = pd.read_csv(meta_path)
meta
# Out:
#         case_id     common_ID Tissuetype include_or_excludetumor  \
# 0     C3L-07287   C3L.07287.T      tumor                 Include
# 1     C3L-11156   C3L.11156.T      tumor                 Include
# 2     C3L-09494   C3L.09494.T      tumor                 Include
# 3    CHTN-49141  CHTN.49141.T      tumor                 Include
# 4     C3L-11095   C3L.11095.T      tumor                 Include
# ..          ...           ...        ...                     ...
# 178   C3L-07872   C3L.07872.T      tumor                 Include
# 179   C3L-08642   C3L.08642.T      tumor                 Include
# 180   C3L-10399   C3L.10399.T      tumor                 Include
# 181   C3L-05301   C3L.05301.T      tumor                 Include
# 182   C3L-08384   C3L.08384.T      tumor                 Include
#
#          FirstCategory AdditionalSegments SecondCategory ThirdCategory  \
# 0    Sufficient Purity                ETS            ETS           NaN
# 1    Sufficient Purity                ETS            ETS           NaN
# 2    Sufficient Purity                ETS            ETS           NaN
# 3    Sufficient Purity                ETS            ETS           NaN
# 4    Sufficient Purity                ETS            ETS           NaN
# ..                 ...                ...            ...           ...
# 178         Low Purity                NaN            NaN           NaN
# 179         Low Purity                NaN            NaN           NaN
# 180         Low Purity                NaN            NaN           NaN
# 181         Low Purity                NaN            NaN           NaN
# 182         Low Purity                NaN            NaN           NaN
#
#     all_drivers Main_Groups  ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  \
# 0           ERG         ERG  ...    0.342000      0.000000   0.0   0.0   1.0
# 1           ERG         ERG  ...    0.000000      0.498000   0.0   0.0   1.0
# 2           ERG         ERG  ...    0.281000      0.000000   0.0   1.0   0.0
# 3           ERG         ERG  ...    0.420000      0.000000   0.0   1.0   0.0
# 4           ERG         ERG  ...    0.000000      0.369000   0.0   0.0   1.0
# ..          ...         ...  ...         ...           ...   ...   ...   ...
# 178         ERG         ERG  ...    0.000000      0.460832   1.0   0.0   0.0
# 179         ERG         ERG  ...    0.000000      0.334840   0.0   0.0   1.0
# 180         ERG         ERG  ...    0.000000      0.445334   0.0   0.0   1.0
# 181        ETV1        ETV1  ...    0.000000      0.457908   0.0   0.0   1.0
# 182         ERG         ERG  ...    0.789835      0.000000   0.0   0.0   0.0
#
#      LumB  Normal  agg_rank_raw  agg_rank_scaled  risk_group
# 0     0.0     0.0     55.333000         0.409000          IR
# 1     0.0     0.0     44.167000         0.325000          LR
# 2     0.0     0.0    123.167000         0.919000          HR
# 3     0.0     0.0    103.833000         0.773000          HR
# 4     0.0     0.0     44.667000         0.328000          LR
# ..    ...     ...           ...              ...         ...
# 178   0.0     0.0     73.666667         0.546366          IR
# 179   0.0     0.0     46.166667         0.339599          LR
# 180   0.0     0.0     60.000000         0.443609          IR
# 181   0.0     0.0     45.333333         0.333333          LR
# 182   1.0     0.0     88.166667         0.655000          HR
#
# [183 rows x 113 columns]

# %%
meta_include = meta[meta["include_or_excludetumor"] == "Include"]
meta_include
# Out:
#         case_id     common_ID Tissuetype include_or_excludetumor  \
# 0     C3L-07287   C3L.07287.T      tumor                 Include
# 1     C3L-11156   C3L.11156.T      tumor                 Include
# 2     C3L-09494   C3L.09494.T      tumor                 Include
# 3    CHTN-49141  CHTN.49141.T      tumor                 Include
# 4     C3L-11095   C3L.11095.T      tumor                 Include
# ..          ...           ...        ...                     ...
# 178   C3L-07872   C3L.07872.T      tumor                 Include
# 179   C3L-08642   C3L.08642.T      tumor                 Include
# 180   C3L-10399   C3L.10399.T      tumor                 Include
# 181   C3L-05301   C3L.05301.T      tumor                 Include
# 182   C3L-08384   C3L.08384.T      tumor                 Include
#
#          FirstCategory AdditionalSegments SecondCategory ThirdCategory  \
# 0    Sufficient Purity                ETS            ETS           NaN
# 1    Sufficient Purity                ETS            ETS           NaN
# 2    Sufficient Purity                ETS            ETS           NaN
# 3    Sufficient Purity                ETS            ETS           NaN
# 4    Sufficient Purity                ETS            ETS           NaN
# ..                 ...                ...            ...           ...
# 178         Low Purity                NaN            NaN           NaN
# 179         Low Purity                NaN            NaN           NaN
# 180         Low Purity                NaN            NaN           NaN
# 181         Low Purity                NaN            NaN           NaN
# 182         Low Purity                NaN            NaN           NaN
#
#     all_drivers Main_Groups  ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  \
# 0           ERG         ERG  ...    0.342000      0.000000   0.0   0.0   1.0
# 1           ERG         ERG  ...    0.000000      0.498000   0.0   0.0   1.0
# 2           ERG         ERG  ...    0.281000      0.000000   0.0   1.0   0.0
# 3           ERG         ERG  ...    0.420000      0.000000   0.0   1.0   0.0
# 4           ERG         ERG  ...    0.000000      0.369000   0.0   0.0   1.0
# ..          ...         ...  ...         ...           ...   ...   ...   ...
# 178         ERG         ERG  ...    0.000000      0.460832   1.0   0.0   0.0
# 179         ERG         ERG  ...    0.000000      0.334840   0.0   0.0   1.0
# 180         ERG         ERG  ...    0.000000      0.445334   0.0   0.0   1.0
# 181        ETV1        ETV1  ...    0.000000      0.457908   0.0   0.0   1.0
# 182         ERG         ERG  ...    0.789835      0.000000   0.0   0.0   0.0
#
#      LumB  Normal  agg_rank_raw  agg_rank_scaled  risk_group
# 0     0.0     0.0     55.333000         0.409000          IR
# 1     0.0     0.0     44.167000         0.325000          LR
# 2     0.0     0.0    123.167000         0.919000          HR
# 3     0.0     0.0    103.833000         0.773000          HR
# 4     0.0     0.0     44.667000         0.328000          LR
# ..    ...     ...           ...              ...         ...
# 178   0.0     0.0     73.666667         0.546366          IR
# 179   0.0     0.0     46.166667         0.339599          LR
# 180   0.0     0.0     60.000000         0.443609          IR
# 181   0.0     0.0     45.333333         0.333333          LR
# 182   1.0     0.0     88.166667         0.655000          HR
#
# [134 rows x 113 columns]

# %%
purity_map = dict(zip(meta_include["common_ID"], meta_include["FirstCategory"]))
stage_map = dict(zip(meta_include["common_ID"], meta_include["stage"]))
gleason_map = dict(zip(meta_include["common_ID"], meta_include["Gleason_um"]))

# %%
meta_exclude = meta[meta["include_or_excludetumor"] == "exclude"]
meta_exclude
# Out:
#        case_id    common_ID Tissuetype include_or_excludetumor FirstCategory  \
# 144  C3L-09492  C3L.09492.T      tumor                 exclude      No Tumor
# 145  C3L-09497  C3L.09497.T      tumor                 exclude      No Tumor
# 146  C3L-06260  C3L.06260.T      tumor                 exclude      No Tumor
# 147  C3L-06510  C3L.06510.T      tumor                 exclude      No Tumor
# 148  C3L-07890  C3L.07890.T      tumor                 exclude      No Tumor
# 149  C3L-09372  C3L.09372.T      tumor                 exclude      No Tumor
# 150  C3N-09047  C3N.09047.T      tumor                 exclude      No Tumor
# 151  C3L-07868  C3L.07868.T      tumor                 exclude      No Tumor
# 152  C3L-09563  C3L.09563.T      tumor                 exclude      No Tumor
# 153  C3L-10319  C3L.10319.T      tumor                 exclude      No Tumor
# 154  C3L-06657  C3L.06657.T      tumor                 exclude      No Tumor
# 155  C3L-07405  C3L.07405.T      tumor                 exclude      No Tumor
# 156  C3L-06573  C3L.06573.T      tumor                 exclude      No Tumor
# 157  C3L-07813  C3L.07813.T      tumor                 exclude      No Tumor
# 158  C3L-08377  C3L.08377.T      tumor                 exclude      No Tumor
# 159  C3L-08371  C3L.08371.T      tumor                 exclude      No Tumor
#
#     AdditionalSegments SecondCategory ThirdCategory all_drivers Main_Groups  \
# 144                NaN            NaN           NaN         NaN    No Tumor
# 145                NaN            NaN           NaN         NaN    No Tumor
# 146                NaN            NaN           NaN         NaN    No Tumor
# 147                NaN            NaN           NaN         NaN    No Tumor
# 148                NaN            NaN           NaN         NaN    No Tumor
# 149                NaN            NaN           NaN         NaN    No Tumor
# 150                NaN            NaN           NaN         NaN    No Tumor
# 151                NaN            NaN           NaN         NaN    No Tumor
# 152                NaN            NaN           NaN         NaN    No Tumor
# 153                NaN            NaN           NaN         NaN    No Tumor
# 154                NaN            NaN           NaN         NaN    No Tumor
# 155                NaN            NaN           NaN         NaN    No Tumor
# 156                NaN            NaN           NaN         NaN    No Tumor
# 157                NaN            NaN           NaN         NaN    No Tumor
# 158                NaN            NaN           NaN         NaN    No Tumor
# 159                NaN            NaN           NaN         NaN    No Tumor
#
#      ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  LumB  Normal  \
# 144  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 145  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 146  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 147  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 148  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 149  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 150  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 151  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 152  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 153  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 154  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 155  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 156  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 157  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 158  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 159  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
#
#      agg_rank_raw  agg_rank_scaled  risk_group
# 144           NaN              NaN         NaN
# 145           NaN              NaN         NaN
# 146           NaN              NaN         NaN
# 147           NaN              NaN         NaN
# 148           NaN              NaN         NaN
# 149           NaN              NaN         NaN
# 150           NaN              NaN         NaN
# 151           NaN              NaN         NaN
# 152           NaN              NaN         NaN
# 153           NaN              NaN         NaN
# 154           NaN              NaN         NaN
# 155           NaN              NaN         NaN
# 156           NaN              NaN         NaN
# 157           NaN              NaN         NaN
# 158           NaN              NaN         NaN
# 159           NaN              NaN         NaN
#
# [16 rows x 113 columns]

# %%
meta_normal = meta[meta["include_or_excludetumor"] == "normal"]
meta_normal
# Out:
#        case_id    common_ID Tissuetype include_or_excludetumor FirstCategory  \
# 111  C3L-07813  C3L.07813.N     normal                  normal        Normal
# 112  C3L-06504  C3L.06504.N     normal                  normal        Normal
# 113  C3L-06506  C3L.06506.N     normal                  normal        Normal
# 114  C3L-06741  C3L.06741.N     normal                  normal        Normal
# 115  C3L-06890  C3L.06890.N     normal                  normal        Normal
# 116  C3L-06901  C3L.06901.N     normal                  normal        Normal
# 117  C3L-06743  C3L.06743.N     normal                  normal        Normal
# 118  C3L-07607  C3L.07607.N     normal                  normal        Normal
# 119  C3L-06436  C3L.06436.N     normal                  normal        Normal
# 120  C3L-07809  C3L.07809.N     normal                  normal        Normal
# 121  C3L-07872  C3L.07872.N     normal                  normal        Normal
# 122  C3L-08293  C3L.08293.N     normal                  normal        Normal
# 123  C3L-07871  C3L.07871.N     normal                  normal        Normal
# 124  C3L-08084  C3L.08084.N     normal                  normal        Normal
# 125  C3L-08371  C3L.08371.N     normal                  normal        Normal
# 126  C3L-08372  C3L.08372.N     normal                  normal        Normal
# 127  C3L-08818  C3L.08818.N     normal                  normal        Normal
# 128  C3L-08380  C3L.08380.N     normal                  normal        Normal
# 129  C3L-08811  C3L.08811.N     normal                  normal        Normal
# 130  C3L-08378  C3L.08378.N     normal                  normal        Normal
# 131  C3L-08382  C3L.08382.N     normal                  normal        Normal
# 132  C3L-09107  C3L.09107.N     normal                  normal        Normal
# 133  C3L-09701  C3L.09701.N     normal                  normal        Normal
# 134  C3L-06252  C3L.06252.N     normal                  normal        Normal
# 135  C3L-08755  C3L.08755.N     normal                  normal        Normal
# 136  C3L-06260  C3L.06260.N     normal                  normal        Normal
# 137  C3L-06261  C3L.06261.N     normal                  normal        Normal
# 138  C3L-09691  C3L.09691.N     normal                  normal        Normal
# 139  C3L-11176  C3L.11176.N     normal                  normal        Normal
# 140  C3L-08800  C3L.08800.N     normal                  normal        Normal
# 141  C3L-08802  C3L.08802.N     normal                  normal        Normal
# 142  C3L-11192  C3L.11192.N     normal                  normal        Normal
# 143  C3L-11122  C3L.11122.N     normal                  normal        Normal
#
#     AdditionalSegments SecondCategory ThirdCategory all_drivers Main_Groups  \
# 111                NaN            NaN           NaN      normal      normal
# 112                NaN            NaN           NaN      normal      normal
# 113                NaN            NaN           NaN      normal      normal
# 114                NaN            NaN           NaN      normal      normal
# 115                NaN            NaN           NaN      normal      normal
# 116                NaN            NaN           NaN      normal      normal
# 117                NaN            NaN           NaN      normal      normal
# 118                NaN            NaN           NaN      normal      normal
# 119                NaN            NaN           NaN      normal      normal
# 120                NaN            NaN           NaN      normal      normal
# 121                NaN            NaN           NaN      normal      normal
# 122                NaN            NaN           NaN      normal      normal
# 123                NaN            NaN           NaN      normal      normal
# 124                NaN            NaN           NaN      normal      normal
# 125                NaN            NaN           NaN      normal      normal
# 126                NaN            NaN           NaN      normal      normal
# 127                NaN            NaN           NaN      normal      normal
# 128                NaN            NaN           NaN      normal      normal
# 129                NaN            NaN           NaN      normal      normal
# 130                NaN            NaN           NaN      normal      normal
# 131                NaN            NaN           NaN      normal      normal
# 132                NaN            NaN           NaN      normal      normal
# 133                NaN            NaN           NaN      normal      normal
# 134                NaN            NaN           NaN      normal      normal
# 135                NaN            NaN           NaN      normal      normal
# 136                NaN            NaN           NaN      normal      normal
# 137                NaN            NaN           NaN      normal      normal
# 138                NaN            NaN           NaN      normal      normal
# 139                NaN            NaN           NaN      normal      normal
# 140                NaN            NaN           NaN      normal      normal
# 141                NaN            NaN           NaN      normal      normal
# 142                NaN            NaN           NaN      normal      normal
# 143                NaN            NaN           NaN      normal      normal
#
#      ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  LumB  Normal  \
# 111  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 112  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 113  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 114  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 115  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 116  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 117  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 118  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 119  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 120  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 121  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 122  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 123  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 124  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 125  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 126  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 127  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 128  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 129  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 130  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 131  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 132  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 133  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 134  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 135  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 136  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 137  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 138  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 139  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 140  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 141  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 142  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 143  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
#
#      agg_rank_raw  agg_rank_scaled  risk_group
# 111           NaN              NaN         NaN
# 112           NaN              NaN         NaN
# 113           NaN              NaN         NaN
# 114           NaN              NaN         NaN
# 115           NaN              NaN         NaN
# 116           NaN              NaN         NaN
# 117           NaN              NaN         NaN
# 118           NaN              NaN         NaN
# 119           NaN              NaN         NaN
# 120           NaN              NaN         NaN
# 121           NaN              NaN         NaN
# 122           NaN              NaN         NaN
# 123           NaN              NaN         NaN
# 124           NaN              NaN         NaN
# 125           NaN              NaN         NaN
# 126           NaN              NaN         NaN
# 127           NaN              NaN         NaN
# 128           NaN              NaN         NaN
# 129           NaN              NaN         NaN
# 130           NaN              NaN         NaN
# 131           NaN              NaN         NaN
# 132           NaN              NaN         NaN
# 133           NaN              NaN         NaN
# 134           NaN              NaN         NaN
# 135           NaN              NaN         NaN
# 136           NaN              NaN         NaN
# 137           NaN              NaN         NaN
# 138           NaN              NaN         NaN
# 139           NaN              NaN         NaN
# 140           NaN              NaN         NaN
# 141           NaN              NaN         NaN
# 142           NaN              NaN         NaN
# 143           NaN              NaN         NaN
#
# [33 rows x 113 columns]

# %%
tumors_included = meta_include['common_ID'].tolist()
tumors_excluded = meta_exclude['common_ID'].tolist()
print(len(tumors_included), len(tumors_excluded))
# Out:
# 134 16

# %%
normals = meta_normal['common_ID'].tolist()
print(len(normals))
# Out:
# 33

# %%
# data
files = [i for i in DATA_DIR.iterdir() if i.is_file()]
files = [i for i in files if re.search(r"ubi_TMT_ratio",i.stem, re.IGNORECASE) \
         and not re.search(r"tumor_purity_corrected",i.stem, re.IGNORECASE) \
            and re.search(r"normalized",i.stem, re.IGNORECASE) ]
data_path = files[0]
print(data_path)
header_cols = ["gene_site","Index","SequenceWindow"]
data = pd.read_csv(data_path,sep="\t").set_index(header_cols)
data_nomiss = data.dropna()
# Out:
# D:\lab\cptac_prostate\data\v4\CPTAC\prostate_CPTAC_normalized_ubi_TMT_ratio_single_site_MD.tsv

# %%
files
# Out:
# [WindowsPath('D:/lab/cptac_prostate/data/v4/CPTAC/prostate_CPTAC_normalized_ubi_TMT_ratio_single_site_MD.tsv')]

# %%
data
# Out:
#                                                    C3L.05292.T  C3L.09383.T  \
# gene_site    Index                SequenceWindow
# ARF5_K142    ENSP00000000233_K142 PVSELTDkLGLQHLR          NaN          NaN
# ARF5_K73     ENSP00000000233_K73  WDVGGQDkIRPLWRH     1.532097    -0.119403
# FKBP4_K179   ENSP00000001008_K179 VALEGYYkDKLFDQR          NaN          NaN
# FKBP4_K222   ENSP00000001008_K222 EHSIVYLkPSYAFGS          NaN          NaN
# FKBP4_K250   ENSP00000001008_K250 LKYELHLkSFEKAKE    -1.036623    -0.244788
# ...                                                        ...          ...
# EPB41L2_K695 ENSP00000516350_K695 FKDILSVkEKYLMPT          NaN          NaN
# EPB41L2_K83  ENSP00000516350_K83  RFIPPWLkKQKSYTL          NaN          NaN
# EPB41L2_K86  ENSP00000516350_K86  PPWLKKQkSYTLVVA    -0.736009    -0.792549
# EPB41L2_K944 ENSP00000516350_K944 QRTEISTkEVPIVQT          NaN          NaN
# EPB41L2_K998 ENSP00000516350_K998 THITKTVkGGISETR    -0.469386    -0.117745
#
#                                                    CHTN.43798.T  C3L.06261.N  \
# gene_site    Index                SequenceWindow
# ARF5_K142    ENSP00000000233_K142 PVSELTDkLGLQHLR           NaN          NaN
# ARF5_K73     ENSP00000000233_K73  WDVGGQDkIRPLWRH      0.098666    -0.252600
# FKBP4_K179   ENSP00000001008_K179 VALEGYYkDKLFDQR           NaN          NaN
# FKBP4_K222   ENSP00000001008_K222 EHSIVYLkPSYAFGS           NaN          NaN
# FKBP4_K250   ENSP00000001008_K250 LKYELHLkSFEKAKE     -0.204607    -0.428873
# ...                                                         ...          ...
# EPB41L2_K695 ENSP00000516350_K695 FKDILSVkEKYLMPT           NaN          NaN
# EPB41L2_K83  ENSP00000516350_K83  RFIPPWLkKQKSYTL           NaN          NaN
# EPB41L2_K86  ENSP00000516350_K86  PPWLKKQkSYTLVVA     -0.983064    -0.576150
# EPB41L2_K944 ENSP00000516350_K944 QRTEISTkEVPIVQT           NaN          NaN
# EPB41L2_K998 ENSP00000516350_K998 THITKTVkGGISETR     -0.287092    -0.806100
#
#                                                    C3L.08811.T  C3L.06506.N  \
# gene_site    Index                SequenceWindow
# ARF5_K142    ENSP00000000233_K142 PVSELTDkLGLQHLR     0.402468          NaN
# ARF5_K73     ENSP00000000233_K73  WDVGGQDkIRPLWRH    -0.183762     0.332808
# FKBP4_K179   ENSP00000001008_K179 VALEGYYkDKLFDQR          NaN          NaN
# FKBP4_K222   ENSP00000001008_K222 EHSIVYLkPSYAFGS          NaN          NaN
# FKBP4_K250   ENSP00000001008_K250 LKYELHLkSFEKAKE     0.232416     0.165417
# ...                                                        ...          ...
# EPB41L2_K695 ENSP00000516350_K695 FKDILSVkEKYLMPT          NaN          NaN
# EPB41L2_K83  ENSP00000516350_K83  RFIPPWLkKQKSYTL          NaN          NaN
# EPB41L2_K86  ENSP00000516350_K86  PPWLKKQkSYTLVVA    -0.311279    -0.675135
# EPB41L2_K944 ENSP00000516350_K944 QRTEISTkEVPIVQT          NaN          NaN
# EPB41L2_K998 ENSP00000516350_K998 THITKTVkGGISETR    -0.179620    -0.343920
#
#                                                    C3L.07804.T  C3L.06595.T  \
# gene_site    Index                SequenceWindow
# ARF5_K142    ENSP00000000233_K142 PVSELTDkLGLQHLR          NaN          NaN
# ARF5_K73     ENSP00000000233_K73  WDVGGQDkIRPLWRH    -0.722082    -0.034021
# FKBP4_K179   ENSP00000001008_K179 VALEGYYkDKLFDQR          NaN          NaN
# FKBP4_K222   ENSP00000001008_K222 EHSIVYLkPSYAFGS          NaN          NaN
# FKBP4_K250   ENSP00000001008_K250 LKYELHLkSFEKAKE    -0.329974    -0.882156
# ...                                                        ...          ...
# EPB41L2_K695 ENSP00000516350_K695 FKDILSVkEKYLMPT          NaN          NaN
# EPB41L2_K83  ENSP00000516350_K83  RFIPPWLkKQKSYTL          NaN          NaN
# EPB41L2_K86  ENSP00000516350_K86  PPWLKKQkSYTLVVA    -0.064949     0.117368
# EPB41L2_K944 ENSP00000516350_K944 QRTEISTkEVPIVQT          NaN          NaN
# EPB41L2_K998 ENSP00000516350_K998 THITKTVkGGISETR    -0.301601     0.265449
#
#                                                    C3L.06742.T  CHTN.45205.T  \
# gene_site    Index                SequenceWindow
# ARF5_K142    ENSP00000000233_K142 PVSELTDkLGLQHLR          NaN           NaN
# ARF5_K73     ENSP00000000233_K73  WDVGGQDkIRPLWRH    -0.589605     -0.112418
# FKBP4_K179   ENSP00000001008_K179 VALEGYYkDKLFDQR          NaN           NaN
# FKBP4_K222   ENSP00000001008_K222 EHSIVYLkPSYAFGS          NaN           NaN
# FKBP4_K250   ENSP00000001008_K250 LKYELHLkSFEKAKE     0.278785     -0.257209
# ...                                                        ...           ...
# EPB41L2_K695 ENSP00000516350_K695 FKDILSVkEKYLMPT          NaN           NaN
# EPB41L2_K83  ENSP00000516350_K83  RFIPPWLkKQKSYTL          NaN           NaN
# EPB41L2_K86  ENSP00000516350_K86  PPWLKKQkSYTLVVA    -0.769245      0.012084
# EPB41L2_K944 ENSP00000516350_K944 QRTEISTkEVPIVQT          NaN           NaN
# EPB41L2_K998 ENSP00000516350_K998 THITKTVkGGISETR    -0.832257     -0.032744
#
#                                                    ...  C3L.08371.N  \
# gene_site    Index                SequenceWindow   ...
# ARF5_K142    ENSP00000000233_K142 PVSELTDkLGLQHLR  ...          NaN
# ARF5_K73     ENSP00000000233_K73  WDVGGQDkIRPLWRH  ...    -0.689048
# FKBP4_K179   ENSP00000001008_K179 VALEGYYkDKLFDQR  ...          NaN
# FKBP4_K222   ENSP00000001008_K222 EHSIVYLkPSYAFGS  ...          NaN
# FKBP4_K250   ENSP00000001008_K250 LKYELHLkSFEKAKE  ...     0.074793
# ...                                                ...          ...
# EPB41L2_K695 ENSP00000516350_K695 FKDILSVkEKYLMPT  ...          NaN
# EPB41L2_K83  ENSP00000516350_K83  RFIPPWLkKQKSYTL  ...          NaN
# EPB41L2_K86  ENSP00000516350_K86  PPWLKKQkSYTLVVA  ...     0.602494
# EPB41L2_K944 ENSP00000516350_K944 QRTEISTkEVPIVQT  ...          NaN
# EPB41L2_K998 ENSP00000516350_K998 THITKTVkGGISETR  ...     0.832343
#
#                                                    C3L.07465.T  C3L.09972.T  \
# gene_site    Index                SequenceWindow
# ARF5_K142    ENSP00000000233_K142 PVSELTDkLGLQHLR          NaN          NaN
# ARF5_K73     ENSP00000000233_K73  WDVGGQDkIRPLWRH     0.116697     0.106626
# FKBP4_K179   ENSP00000001008_K179 VALEGYYkDKLFDQR          NaN          NaN
# FKBP4_K222   ENSP00000001008_K222 EHSIVYLkPSYAFGS          NaN          NaN
# FKBP4_K250   ENSP00000001008_K250 LKYELHLkSFEKAKE    -0.377876     0.062219
# ...                                                        ...          ...
# EPB41L2_K695 ENSP00000516350_K695 FKDILSVkEKYLMPT          NaN          NaN
# EPB41L2_K83  ENSP00000516350_K83  RFIPPWLkKQKSYTL          NaN          NaN
# EPB41L2_K86  ENSP00000516350_K86  PPWLKKQkSYTLVVA    -0.105598     0.941922
# EPB41L2_K944 ENSP00000516350_K944 QRTEISTkEVPIVQT          NaN          NaN
# EPB41L2_K998 ENSP00000516350_K998 THITKTVkGGISETR     0.336707     0.197318
#
#                                                    C3N.08952.T  C3N.08880.T  \
# gene_site    Index                SequenceWindow
# ARF5_K142    ENSP00000000233_K142 PVSELTDkLGLQHLR          NaN          NaN
# ARF5_K73     ENSP00000000233_K73  WDVGGQDkIRPLWRH     0.325935     0.190788
# FKBP4_K179   ENSP00000001008_K179 VALEGYYkDKLFDQR          NaN          NaN
# FKBP4_K222   ENSP00000001008_K222 EHSIVYLkPSYAFGS          NaN          NaN
# FKBP4_K250   ENSP00000001008_K250 LKYELHLkSFEKAKE    -0.006570     0.367416
# ...                                                        ...          ...
# EPB41L2_K695 ENSP00000516350_K695 FKDILSVkEKYLMPT          NaN          NaN
# EPB41L2_K83  ENSP00000516350_K83  RFIPPWLkKQKSYTL          NaN          NaN
# EPB41L2_K86  ENSP00000516350_K86  PPWLKKQkSYTLVVA     0.108946     0.393263
# EPB41L2_K944 ENSP00000516350_K944 QRTEISTkEVPIVQT          NaN          NaN
# EPB41L2_K998 ENSP00000516350_K998 THITKTVkGGISETR     0.265561     0.119684
#
#                                                    C3L.07606.N  C3L.07861.T  \
# gene_site    Index                SequenceWindow
# ARF5_K142    ENSP00000000233_K142 PVSELTDkLGLQHLR          NaN          NaN
# ARF5_K73     ENSP00000000233_K73  WDVGGQDkIRPLWRH    -1.355962    -0.117618
# FKBP4_K179   ENSP00000001008_K179 VALEGYYkDKLFDQR          NaN          NaN
# FKBP4_K222   ENSP00000001008_K222 EHSIVYLkPSYAFGS          NaN          NaN
# FKBP4_K250   ENSP00000001008_K250 LKYELHLkSFEKAKE     0.409014    -0.063714
# ...                                                        ...          ...
# EPB41L2_K695 ENSP00000516350_K695 FKDILSVkEKYLMPT          NaN          NaN
# EPB41L2_K83  ENSP00000516350_K83  RFIPPWLkKQKSYTL          NaN          NaN
# EPB41L2_K86  ENSP00000516350_K86  PPWLKKQkSYTLVVA     0.029734    -0.119493
# EPB41L2_K944 ENSP00000516350_K944 QRTEISTkEVPIVQT          NaN          NaN
# EPB41L2_K998 ENSP00000516350_K998 THITKTVkGGISETR     0.647184     0.651304
#
#                                                    C3L.07606.T  C3L.07292.N  \
# gene_site    Index                SequenceWindow
# ARF5_K142    ENSP00000000233_K142 PVSELTDkLGLQHLR          NaN          NaN
# ARF5_K73     ENSP00000000233_K73  WDVGGQDkIRPLWRH    -0.533808    -0.520944
# FKBP4_K179   ENSP00000001008_K179 VALEGYYkDKLFDQR          NaN          NaN
# FKBP4_K222   ENSP00000001008_K222 EHSIVYLkPSYAFGS          NaN          NaN
# FKBP4_K250   ENSP00000001008_K250 LKYELHLkSFEKAKE     0.612627     0.216953
# ...                                                        ...          ...
# EPB41L2_K695 ENSP00000516350_K695 FKDILSVkEKYLMPT          NaN          NaN
# EPB41L2_K83  ENSP00000516350_K83  RFIPPWLkKQKSYTL          NaN          NaN
# EPB41L2_K86  ENSP00000516350_K86  PPWLKKQkSYTLVVA     0.268983     0.032642
# EPB41L2_K944 ENSP00000516350_K944 QRTEISTkEVPIVQT          NaN          NaN
# EPB41L2_K998 ENSP00000516350_K998 THITKTVkGGISETR     0.455965    -0.100731
#
#                                                    CHTN.49141.T
# gene_site    Index                SequenceWindow
# ARF5_K142    ENSP00000000233_K142 PVSELTDkLGLQHLR           NaN
# ARF5_K73     ENSP00000000233_K73  WDVGGQDkIRPLWRH     -1.608762
# FKBP4_K179   ENSP00000001008_K179 VALEGYYkDKLFDQR           NaN
# FKBP4_K222   ENSP00000001008_K222 EHSIVYLkPSYAFGS           NaN
# FKBP4_K250   ENSP00000001008_K250 LKYELHLkSFEKAKE      0.004498
# ...                                                         ...
# EPB41L2_K695 ENSP00000516350_K695 FKDILSVkEKYLMPT           NaN
# EPB41L2_K83  ENSP00000516350_K83  RFIPPWLkKQKSYTL           NaN
# EPB41L2_K86  ENSP00000516350_K86  PPWLKKQkSYTLVVA      0.395729
# EPB41L2_K944 ENSP00000516350_K944 QRTEISTkEVPIVQT           NaN
# EPB41L2_K998 ENSP00000516350_K998 THITKTVkGGISETR      0.411853
#
# [17838 rows x 171 columns]

# %%
data_nomiss
# Out:
#                                                     C3L.05292.T  C3L.09383.T  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K279 ENSP00000005260_K279 KDYDTLSkCSPKMPP     1.249167    -0.757687
# RPS20_K30     ENSP00000009589_K30  TLTSRNVkSLEKVCA     0.495688    -0.525935
# RPS20_K34     ENSP00000009589_K34  RNVKSLEkVCADLIR     0.071532    -0.321470
# RPS20_K8      ENSP00000009589_K8   MAFKDTGkTPVEPEV     0.230661     0.228702
# RTF2_K122     ENSP00000023939_K122 IKNVTELkLSDNPAW    -0.189754    -0.667366
# ...                                                         ...          ...
# EPB41L2_K270  ENSP00000516350_K270 FQESPEQkNWLDPAK     0.096019    -0.053565
# EPB41L2_K374  ENSP00000516350_K374 QTKELEEkVAELHKT     0.155735     0.135034
# EPB41L2_K399  ENSP00000516350_K399 SQFLENAkRLSMYGV     0.393942     0.783797
# EPB41L2_K86   ENSP00000516350_K86  PPWLKKQkSYTLVVA    -0.736009    -0.792549
# EPB41L2_K998  ENSP00000516350_K998 THITKTVkGGISETR    -0.469386    -0.117745
#
#                                                     CHTN.43798.T  C3L.06261.N  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K279 ENSP00000005260_K279 KDYDTLSkCSPKMPP      0.331505     0.247987
# RPS20_K30     ENSP00000009589_K30  TLTSRNVkSLEKVCA     -0.679898     0.370659
# RPS20_K34     ENSP00000009589_K34  RNVKSLEkVCADLIR      0.711634     0.142783
# RPS20_K8      ENSP00000009589_K8   MAFKDTGkTPVEPEV     -1.066245     0.740088
# RTF2_K122     ENSP00000023939_K122 IKNVTELkLSDNPAW      0.865966    -0.869042
# ...                                                          ...          ...
# EPB41L2_K270  ENSP00000516350_K270 FQESPEQkNWLDPAK     -0.137337     0.257652
# EPB41L2_K374  ENSP00000516350_K374 QTKELEEkVAELHKT     -0.179189     0.098494
# EPB41L2_K399  ENSP00000516350_K399 SQFLENAkRLSMYGV      0.482179     0.536852
# EPB41L2_K86   ENSP00000516350_K86  PPWLKKQkSYTLVVA     -0.983064    -0.576150
# EPB41L2_K998  ENSP00000516350_K998 THITKTVkGGISETR     -0.287092    -0.806100
#
#                                                     C3L.08811.T  C3L.06506.N  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K279 ENSP00000005260_K279 KDYDTLSkCSPKMPP     0.091506    -0.984783
# RPS20_K30     ENSP00000009589_K30  TLTSRNVkSLEKVCA     0.632420    -0.757156
# RPS20_K34     ENSP00000009589_K34  RNVKSLEkVCADLIR    -0.642919     0.503261
# RPS20_K8      ENSP00000009589_K8   MAFKDTGkTPVEPEV     0.741800    -0.375151
# RTF2_K122     ENSP00000023939_K122 IKNVTELkLSDNPAW    -1.119579     0.280485
# ...                                                         ...          ...
# EPB41L2_K270  ENSP00000516350_K270 FQESPEQkNWLDPAK    -0.131630     0.140285
# EPB41L2_K374  ENSP00000516350_K374 QTKELEEkVAELHKT    -0.395692    -0.313864
# EPB41L2_K399  ENSP00000516350_K399 SQFLENAkRLSMYGV     0.181073     0.397125
# EPB41L2_K86   ENSP00000516350_K86  PPWLKKQkSYTLVVA    -0.311279    -0.675135
# EPB41L2_K998  ENSP00000516350_K998 THITKTVkGGISETR    -0.179620    -0.343920
#
#                                                     C3L.07804.T  C3L.06595.T  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K279 ENSP00000005260_K279 KDYDTLSkCSPKMPP     0.761747     0.018729
# RPS20_K30     ENSP00000009589_K30  TLTSRNVkSLEKVCA     0.295591    -0.507033
# RPS20_K34     ENSP00000009589_K34  RNVKSLEkVCADLIR    -0.659277     0.011270
# RPS20_K8      ENSP00000009589_K8   MAFKDTGkTPVEPEV     0.973612    -0.833959
# RTF2_K122     ENSP00000023939_K122 IKNVTELkLSDNPAW    -0.247879     1.311822
# ...                                                         ...          ...
# EPB41L2_K270  ENSP00000516350_K270 FQESPEQkNWLDPAK     0.108434    -1.325826
# EPB41L2_K374  ENSP00000516350_K374 QTKELEEkVAELHKT     0.209039    -0.409315
# EPB41L2_K399  ENSP00000516350_K399 SQFLENAkRLSMYGV     0.891389     0.487043
# EPB41L2_K86   ENSP00000516350_K86  PPWLKKQkSYTLVVA    -0.064949     0.117368
# EPB41L2_K998  ENSP00000516350_K998 THITKTVkGGISETR    -0.301601     0.265449
#
#                                                     C3L.06742.T  CHTN.45205.T  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K279 ENSP00000005260_K279 KDYDTLSkCSPKMPP    -1.394850     -0.495487
# RPS20_K30     ENSP00000009589_K30  TLTSRNVkSLEKVCA     0.321027     -0.435678
# RPS20_K34     ENSP00000009589_K34  RNVKSLEkVCADLIR    -0.320110     -0.193164
# RPS20_K8      ENSP00000009589_K8   MAFKDTGkTPVEPEV    -1.270654     -0.747110
# RTF2_K122     ENSP00000023939_K122 IKNVTELkLSDNPAW     0.647454      0.551585
# ...                                                         ...           ...
# EPB41L2_K270  ENSP00000516350_K270 FQESPEQkNWLDPAK    -0.012452     -0.035940
# EPB41L2_K374  ENSP00000516350_K374 QTKELEEkVAELHKT    -0.554360     -0.593986
# EPB41L2_K399  ENSP00000516350_K399 SQFLENAkRLSMYGV     0.413670      0.951778
# EPB41L2_K86   ENSP00000516350_K86  PPWLKKQkSYTLVVA    -0.769245      0.012084
# EPB41L2_K998  ENSP00000516350_K998 THITKTVkGGISETR    -0.832257     -0.032744
#
#                                                     ...  C3L.08371.N  \
# gene_site     Index                SequenceWindow   ...
# BAIAP2L1_K279 ENSP00000005260_K279 KDYDTLSkCSPKMPP  ...     0.292600
# RPS20_K30     ENSP00000009589_K30  TLTSRNVkSLEKVCA  ...     0.761752
# RPS20_K34     ENSP00000009589_K34  RNVKSLEkVCADLIR  ...     0.108265
# RPS20_K8      ENSP00000009589_K8   MAFKDTGkTPVEPEV  ...     0.224634
# RTF2_K122     ENSP00000023939_K122 IKNVTELkLSDNPAW  ...    -1.255461
# ...                                                 ...          ...
# EPB41L2_K270  ENSP00000516350_K270 FQESPEQkNWLDPAK  ...     0.163404
# EPB41L2_K374  ENSP00000516350_K374 QTKELEEkVAELHKT  ...    -0.107340
# EPB41L2_K399  ENSP00000516350_K399 SQFLENAkRLSMYGV  ...     0.198906
# EPB41L2_K86   ENSP00000516350_K86  PPWLKKQkSYTLVVA  ...     0.602494
# EPB41L2_K998  ENSP00000516350_K998 THITKTVkGGISETR  ...     0.832343
#
#                                                     C3L.07465.T  C3L.09972.T  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K279 ENSP00000005260_K279 KDYDTLSkCSPKMPP    -0.901060    -0.703619
# RPS20_K30     ENSP00000009589_K30  TLTSRNVkSLEKVCA    -0.003989    -0.543347
# RPS20_K34     ENSP00000009589_K34  RNVKSLEkVCADLIR    -0.327224     0.214371
# RPS20_K8      ENSP00000009589_K8   MAFKDTGkTPVEPEV    -0.864423    -0.719431
# RTF2_K122     ENSP00000023939_K122 IKNVTELkLSDNPAW     1.010425     1.002674
# ...                                                         ...          ...
# EPB41L2_K270  ENSP00000516350_K270 FQESPEQkNWLDPAK    -0.310110    -0.172418
# EPB41L2_K374  ENSP00000516350_K374 QTKELEEkVAELHKT    -0.577948    -0.196011
# EPB41L2_K399  ENSP00000516350_K399 SQFLENAkRLSMYGV    -0.191775    -0.062978
# EPB41L2_K86   ENSP00000516350_K86  PPWLKKQkSYTLVVA    -0.105598     0.941922
# EPB41L2_K998  ENSP00000516350_K998 THITKTVkGGISETR     0.336707     0.197318
#
#                                                     C3N.08952.T  C3N.08880.T  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K279 ENSP00000005260_K279 KDYDTLSkCSPKMPP    -0.484016    -1.068045
# RPS20_K30     ENSP00000009589_K30  TLTSRNVkSLEKVCA    -0.391744    -0.394004
# RPS20_K34     ENSP00000009589_K34  RNVKSLEkVCADLIR    -1.171349    -0.219757
# RPS20_K8      ENSP00000009589_K8   MAFKDTGkTPVEPEV    -0.755494    -1.300542
# RTF2_K122     ENSP00000023939_K122 IKNVTELkLSDNPAW     1.101739     1.266526
# ...                                                         ...          ...
# EPB41L2_K270  ENSP00000516350_K270 FQESPEQkNWLDPAK    -0.405939    -0.064256
# EPB41L2_K374  ENSP00000516350_K374 QTKELEEkVAELHKT    -0.596211    -0.406463
# EPB41L2_K399  ENSP00000516350_K399 SQFLENAkRLSMYGV    -0.071399     0.085953
# EPB41L2_K86   ENSP00000516350_K86  PPWLKKQkSYTLVVA     0.108946     0.393263
# EPB41L2_K998  ENSP00000516350_K998 THITKTVkGGISETR     0.265561     0.119684
#
#                                                     C3L.07606.N  C3L.07861.T  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K279 ENSP00000005260_K279 KDYDTLSkCSPKMPP    -0.522856    -1.138157
# RPS20_K30     ENSP00000009589_K30  TLTSRNVkSLEKVCA     0.046302    -0.306116
# RPS20_K34     ENSP00000009589_K34  RNVKSLEkVCADLIR     0.281876    -0.206765
# RPS20_K8      ENSP00000009589_K8   MAFKDTGkTPVEPEV    -0.097704    -0.974114
# RTF2_K122     ENSP00000023939_K122 IKNVTELkLSDNPAW    -0.565574     1.200829
# ...                                                         ...          ...
# EPB41L2_K270  ENSP00000516350_K270 FQESPEQkNWLDPAK     0.527518    -0.374347
# EPB41L2_K374  ENSP00000516350_K374 QTKELEEkVAELHKT     0.497609    -0.403987
# EPB41L2_K399  ENSP00000516350_K399 SQFLENAkRLSMYGV     0.699732    -0.132209
# EPB41L2_K86   ENSP00000516350_K86  PPWLKKQkSYTLVVA     0.029734    -0.119493
# EPB41L2_K998  ENSP00000516350_K998 THITKTVkGGISETR     0.647184     0.651304
#
#                                                     C3L.07606.T  C3L.07292.N  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K279 ENSP00000005260_K279 KDYDTLSkCSPKMPP    -0.994654    -0.809111
# RPS20_K30     ENSP00000009589_K30  TLTSRNVkSLEKVCA    -0.504787    -0.839142
# RPS20_K34     ENSP00000009589_K34  RNVKSLEkVCADLIR    -0.353703    -0.198535
# RPS20_K8      ENSP00000009589_K8   MAFKDTGkTPVEPEV    -1.343285    -1.309047
# RTF2_K122     ENSP00000023939_K122 IKNVTELkLSDNPAW     1.153749     0.793904
# ...                                                         ...          ...
# EPB41L2_K270  ENSP00000516350_K270 FQESPEQkNWLDPAK    -0.193463     0.201426
# EPB41L2_K374  ENSP00000516350_K374 QTKELEEkVAELHKT    -0.630055    -0.685793
# EPB41L2_K399  ENSP00000516350_K399 SQFLENAkRLSMYGV    -0.115764    -0.278468
# EPB41L2_K86   ENSP00000516350_K86  PPWLKKQkSYTLVVA     0.268983     0.032642
# EPB41L2_K998  ENSP00000516350_K998 THITKTVkGGISETR     0.455965    -0.100731
#
#                                                     CHTN.49141.T
# gene_site     Index                SequenceWindow
# BAIAP2L1_K279 ENSP00000005260_K279 KDYDTLSkCSPKMPP     -0.604100
# RPS20_K30     ENSP00000009589_K30  TLTSRNVkSLEKVCA     -0.749409
# RPS20_K34     ENSP00000009589_K34  RNVKSLEkVCADLIR     -1.565887
# RPS20_K8      ENSP00000009589_K8   MAFKDTGkTPVEPEV     -1.032418
# RTF2_K122     ENSP00000023939_K122 IKNVTELkLSDNPAW      0.123098
# ...                                                          ...
# EPB41L2_K270  ENSP00000516350_K270 FQESPEQkNWLDPAK     -0.227602
# EPB41L2_K374  ENSP00000516350_K374 QTKELEEkVAELHKT     -0.653306
# EPB41L2_K399  ENSP00000516350_K399 SQFLENAkRLSMYGV      0.514209
# EPB41L2_K86   ENSP00000516350_K86  PPWLKKQkSYTLVVA      0.395729
# EPB41L2_K998  ENSP00000516350_K998 THITKTVkGGISETR      0.411853
#
# [2376 rows x 171 columns]

# %%
samples = data.columns.tolist()
len(samples)
# Out:
# 171

# %%
set_tumors_included = set(tumors_included)
set_tumors_excluded = set(tumors_excluded)
set_normals = set(normals)
set_data = set(samples)
print((len(set_tumors_included), len(set_tumors_excluded), len(set_normals), len(set_data)))
# Out:
# (134, 16, 33, 171)

# %%
set_data - set_tumors_included - set_tumors_excluded - set_normals
# Out:
# {'C3L.06436.T',
#  'C3L.07292.N',
#  'C3L.07606.N',
#  'C3L.08546.T',
#  'C3L.09345.T',
#  'C3L.09373.T',
#  'C3L.09793.T',
#  'C3L.09832.T',
#  'C3L.09972.T',
#  'C3L.10301.T',
#  'CHTN.47295.T'}

# %%
data.boxplot(figsize=(40,6), rot=90)
# Out:
# <Axes: >

# %%
from omicsone_streamlit.plots.pca import plot_pca1

# %%
print(len(tumors_included), len(normals))
# Out:
# 134 33

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = "Tumor"
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"

# %%
len(set(data.columns) & set(tumors_included))
# Out:
# 129

# %%
x = set(tumors_included) & set(data.columns)
y = set(normals) & set(data.columns)

data2 = data_nomiss.T.loc[sorted(x) + sorted(y),:]
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')

# %%
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-40,40), ylim=(-40,40), figsize=(6,6),
                    title="PCA of ubi TMT log2ratio (colored by group)")

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = purity_map.get(i, "Tumor")
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-40,40), ylim=(-40,40), figsize=(6,6),
                    title="PCA of ubi TMT log2ratio (colored by tumor purity category)")

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = re.sub("[ABC]",'',stage_map.get(i, "Tumor"))
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-40,40), ylim=(-40,40), figsize=(6,6),
                    title="PCA of ubi TMT log2ratio (colored by stage)")
