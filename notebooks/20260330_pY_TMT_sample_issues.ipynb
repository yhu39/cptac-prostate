# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import re,sys,os
import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib

# Set font to Arial
matplotlib.rcParams['font.family'] = 'Arial'

# Optional: Set PDF to embed fonts (for Illustrator editing)
matplotlib.rcParams['pdf.fonttype'] = 42  # TrueType fonts for better editing

# %%
DATA_DIR = Path(r"D:\lab\cptac_prostate\data\v4\CPTAC")
OUTPUT_DIR = Path(r"D:\lab\cptac_prostate\runs\20260330_cptac_pY_tmt_sample_issues")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print(DATA_DIR.exists(), OUTPUT_DIR.exists())
meta_path = DATA_DIR / "20_MetaData_03_12_2026.csv"
# Out:
# True True

# %%
meta = pd.read_csv(meta_path)
meta
# Out:
#         case_id     common_ID Tissuetype include_or_excludetumor  \
# 0     C3L-07287   C3L.07287.T      tumor                 Include
# 1     C3L-11156   C3L.11156.T      tumor                 Include
# 2     C3L-09494   C3L.09494.T      tumor                 Include
# 3    CHTN-49141  CHTN.49141.T      tumor                 Include
# 4     C3L-11095   C3L.11095.T      tumor                 Include
# ..          ...           ...        ...                     ...
# 178   C3L-07872   C3L.07872.T      tumor                 Include
# 179   C3L-08642   C3L.08642.T      tumor                 Include
# 180   C3L-10399   C3L.10399.T      tumor                 Include
# 181   C3L-05301   C3L.05301.T      tumor                 Include
# 182   C3L-08384   C3L.08384.T      tumor                 Include
#
#          FirstCategory AdditionalSegments SecondCategory ThirdCategory  \
# 0    Sufficient Purity                ETS            ETS           NaN
# 1    Sufficient Purity                ETS            ETS           NaN
# 2    Sufficient Purity                ETS            ETS           NaN
# 3    Sufficient Purity                ETS            ETS           NaN
# 4    Sufficient Purity                ETS            ETS           NaN
# ..                 ...                ...            ...           ...
# 178         Low Purity                NaN            NaN           NaN
# 179         Low Purity                NaN            NaN           NaN
# 180         Low Purity                NaN            NaN           NaN
# 181         Low Purity                NaN            NaN           NaN
# 182         Low Purity                NaN            NaN           NaN
#
#     all_drivers Main_Groups  ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  \
# 0           ERG         ERG  ...    0.342000      0.000000   0.0   0.0   1.0
# 1           ERG         ERG  ...    0.000000      0.498000   0.0   0.0   1.0
# 2           ERG         ERG  ...    0.281000      0.000000   0.0   1.0   0.0
# 3           ERG         ERG  ...    0.420000      0.000000   0.0   1.0   0.0
# 4           ERG         ERG  ...    0.000000      0.369000   0.0   0.0   1.0
# ..          ...         ...  ...         ...           ...   ...   ...   ...
# 178         ERG         ERG  ...    0.000000      0.460832   1.0   0.0   0.0
# 179         ERG         ERG  ...    0.000000      0.334840   0.0   0.0   1.0
# 180         ERG         ERG  ...    0.000000      0.445334   0.0   0.0   1.0
# 181        ETV1        ETV1  ...    0.000000      0.457908   0.0   0.0   1.0
# 182         ERG         ERG  ...    0.789835      0.000000   0.0   0.0   0.0
#
#      LumB  Normal  agg_rank_raw  agg_rank_scaled  risk_group
# 0     0.0     0.0     55.333000         0.409000          IR
# 1     0.0     0.0     44.167000         0.325000          LR
# 2     0.0     0.0    123.167000         0.919000          HR
# 3     0.0     0.0    103.833000         0.773000          HR
# 4     0.0     0.0     44.667000         0.328000          LR
# ..    ...     ...           ...              ...         ...
# 178   0.0     0.0     73.666667         0.546366          IR
# 179   0.0     0.0     46.166667         0.339599          LR
# 180   0.0     0.0     60.000000         0.443609          IR
# 181   0.0     0.0     45.333333         0.333333          LR
# 182   1.0     0.0     88.166667         0.655000          HR
#
# [183 rows x 113 columns]

# %%
meta_include = meta[meta["include_or_excludetumor"] == "Include"]
meta_include
# Out:
#         case_id     common_ID Tissuetype include_or_excludetumor  \
# 0     C3L-07287   C3L.07287.T      tumor                 Include
# 1     C3L-11156   C3L.11156.T      tumor                 Include
# 2     C3L-09494   C3L.09494.T      tumor                 Include
# 3    CHTN-49141  CHTN.49141.T      tumor                 Include
# 4     C3L-11095   C3L.11095.T      tumor                 Include
# ..          ...           ...        ...                     ...
# 178   C3L-07872   C3L.07872.T      tumor                 Include
# 179   C3L-08642   C3L.08642.T      tumor                 Include
# 180   C3L-10399   C3L.10399.T      tumor                 Include
# 181   C3L-05301   C3L.05301.T      tumor                 Include
# 182   C3L-08384   C3L.08384.T      tumor                 Include
#
#          FirstCategory AdditionalSegments SecondCategory ThirdCategory  \
# 0    Sufficient Purity                ETS            ETS           NaN
# 1    Sufficient Purity                ETS            ETS           NaN
# 2    Sufficient Purity                ETS            ETS           NaN
# 3    Sufficient Purity                ETS            ETS           NaN
# 4    Sufficient Purity                ETS            ETS           NaN
# ..                 ...                ...            ...           ...
# 178         Low Purity                NaN            NaN           NaN
# 179         Low Purity                NaN            NaN           NaN
# 180         Low Purity                NaN            NaN           NaN
# 181         Low Purity                NaN            NaN           NaN
# 182         Low Purity                NaN            NaN           NaN
#
#     all_drivers Main_Groups  ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  \
# 0           ERG         ERG  ...    0.342000      0.000000   0.0   0.0   1.0
# 1           ERG         ERG  ...    0.000000      0.498000   0.0   0.0   1.0
# 2           ERG         ERG  ...    0.281000      0.000000   0.0   1.0   0.0
# 3           ERG         ERG  ...    0.420000      0.000000   0.0   1.0   0.0
# 4           ERG         ERG  ...    0.000000      0.369000   0.0   0.0   1.0
# ..          ...         ...  ...         ...           ...   ...   ...   ...
# 178         ERG         ERG  ...    0.000000      0.460832   1.0   0.0   0.0
# 179         ERG         ERG  ...    0.000000      0.334840   0.0   0.0   1.0
# 180         ERG         ERG  ...    0.000000      0.445334   0.0   0.0   1.0
# 181        ETV1        ETV1  ...    0.000000      0.457908   0.0   0.0   1.0
# 182         ERG         ERG  ...    0.789835      0.000000   0.0   0.0   0.0
#
#      LumB  Normal  agg_rank_raw  agg_rank_scaled  risk_group
# 0     0.0     0.0     55.333000         0.409000          IR
# 1     0.0     0.0     44.167000         0.325000          LR
# 2     0.0     0.0    123.167000         0.919000          HR
# 3     0.0     0.0    103.833000         0.773000          HR
# 4     0.0     0.0     44.667000         0.328000          LR
# ..    ...     ...           ...              ...         ...
# 178   0.0     0.0     73.666667         0.546366          IR
# 179   0.0     0.0     46.166667         0.339599          LR
# 180   0.0     0.0     60.000000         0.443609          IR
# 181   0.0     0.0     45.333333         0.333333          LR
# 182   1.0     0.0     88.166667         0.655000          HR
#
# [134 rows x 113 columns]

# %%
meta_exclude = meta[meta["include_or_excludetumor"] == "exclude"]
meta_exclude
# Out:
#        case_id    common_ID Tissuetype include_or_excludetumor FirstCategory  \
# 144  C3L-09492  C3L.09492.T      tumor                 exclude      No Tumor
# 145  C3L-09497  C3L.09497.T      tumor                 exclude      No Tumor
# 146  C3L-06260  C3L.06260.T      tumor                 exclude      No Tumor
# 147  C3L-06510  C3L.06510.T      tumor                 exclude      No Tumor
# 148  C3L-07890  C3L.07890.T      tumor                 exclude      No Tumor
# 149  C3L-09372  C3L.09372.T      tumor                 exclude      No Tumor
# 150  C3N-09047  C3N.09047.T      tumor                 exclude      No Tumor
# 151  C3L-07868  C3L.07868.T      tumor                 exclude      No Tumor
# 152  C3L-09563  C3L.09563.T      tumor                 exclude      No Tumor
# 153  C3L-10319  C3L.10319.T      tumor                 exclude      No Tumor
# 154  C3L-06657  C3L.06657.T      tumor                 exclude      No Tumor
# 155  C3L-07405  C3L.07405.T      tumor                 exclude      No Tumor
# 156  C3L-06573  C3L.06573.T      tumor                 exclude      No Tumor
# 157  C3L-07813  C3L.07813.T      tumor                 exclude      No Tumor
# 158  C3L-08377  C3L.08377.T      tumor                 exclude      No Tumor
# 159  C3L-08371  C3L.08371.T      tumor                 exclude      No Tumor
#
#     AdditionalSegments SecondCategory ThirdCategory all_drivers Main_Groups  \
# 144                NaN            NaN           NaN         NaN    No Tumor
# 145                NaN            NaN           NaN         NaN    No Tumor
# 146                NaN            NaN           NaN         NaN    No Tumor
# 147                NaN            NaN           NaN         NaN    No Tumor
# 148                NaN            NaN           NaN         NaN    No Tumor
# 149                NaN            NaN           NaN         NaN    No Tumor
# 150                NaN            NaN           NaN         NaN    No Tumor
# 151                NaN            NaN           NaN         NaN    No Tumor
# 152                NaN            NaN           NaN         NaN    No Tumor
# 153                NaN            NaN           NaN         NaN    No Tumor
# 154                NaN            NaN           NaN         NaN    No Tumor
# 155                NaN            NaN           NaN         NaN    No Tumor
# 156                NaN            NaN           NaN         NaN    No Tumor
# 157                NaN            NaN           NaN         NaN    No Tumor
# 158                NaN            NaN           NaN         NaN    No Tumor
# 159                NaN            NaN           NaN         NaN    No Tumor
#
#      ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  LumB  Normal  \
# 144  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 145  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 146  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 147  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 148  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 149  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 150  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 151  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 152  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 153  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 154  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 155  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 156  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 157  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 158  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 159  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
#
#      agg_rank_raw  agg_rank_scaled  risk_group
# 144           NaN              NaN         NaN
# 145           NaN              NaN         NaN
# 146           NaN              NaN         NaN
# 147           NaN              NaN         NaN
# 148           NaN              NaN         NaN
# 149           NaN              NaN         NaN
# 150           NaN              NaN         NaN
# 151           NaN              NaN         NaN
# 152           NaN              NaN         NaN
# 153           NaN              NaN         NaN
# 154           NaN              NaN         NaN
# 155           NaN              NaN         NaN
# 156           NaN              NaN         NaN
# 157           NaN              NaN         NaN
# 158           NaN              NaN         NaN
# 159           NaN              NaN         NaN
#
# [16 rows x 113 columns]

# %%
meta_normal = meta[meta["include_or_excludetumor"] == "normal"]
meta_normal
# Out:
#        case_id    common_ID Tissuetype include_or_excludetumor FirstCategory  \
# 111  C3L-07813  C3L.07813.N     normal                  normal        Normal
# 112  C3L-06504  C3L.06504.N     normal                  normal        Normal
# 113  C3L-06506  C3L.06506.N     normal                  normal        Normal
# 114  C3L-06741  C3L.06741.N     normal                  normal        Normal
# 115  C3L-06890  C3L.06890.N     normal                  normal        Normal
# 116  C3L-06901  C3L.06901.N     normal                  normal        Normal
# 117  C3L-06743  C3L.06743.N     normal                  normal        Normal
# 118  C3L-07607  C3L.07607.N     normal                  normal        Normal
# 119  C3L-06436  C3L.06436.N     normal                  normal        Normal
# 120  C3L-07809  C3L.07809.N     normal                  normal        Normal
# 121  C3L-07872  C3L.07872.N     normal                  normal        Normal
# 122  C3L-08293  C3L.08293.N     normal                  normal        Normal
# 123  C3L-07871  C3L.07871.N     normal                  normal        Normal
# 124  C3L-08084  C3L.08084.N     normal                  normal        Normal
# 125  C3L-08371  C3L.08371.N     normal                  normal        Normal
# 126  C3L-08372  C3L.08372.N     normal                  normal        Normal
# 127  C3L-08818  C3L.08818.N     normal                  normal        Normal
# 128  C3L-08380  C3L.08380.N     normal                  normal        Normal
# 129  C3L-08811  C3L.08811.N     normal                  normal        Normal
# 130  C3L-08378  C3L.08378.N     normal                  normal        Normal
# 131  C3L-08382  C3L.08382.N     normal                  normal        Normal
# 132  C3L-09107  C3L.09107.N     normal                  normal        Normal
# 133  C3L-09701  C3L.09701.N     normal                  normal        Normal
# 134  C3L-06252  C3L.06252.N     normal                  normal        Normal
# 135  C3L-08755  C3L.08755.N     normal                  normal        Normal
# 136  C3L-06260  C3L.06260.N     normal                  normal        Normal
# 137  C3L-06261  C3L.06261.N     normal                  normal        Normal
# 138  C3L-09691  C3L.09691.N     normal                  normal        Normal
# 139  C3L-11176  C3L.11176.N     normal                  normal        Normal
# 140  C3L-08800  C3L.08800.N     normal                  normal        Normal
# 141  C3L-08802  C3L.08802.N     normal                  normal        Normal
# 142  C3L-11192  C3L.11192.N     normal                  normal        Normal
# 143  C3L-11122  C3L.11122.N     normal                  normal        Normal
#
#     AdditionalSegments SecondCategory ThirdCategory all_drivers Main_Groups  \
# 111                NaN            NaN           NaN      normal      normal
# 112                NaN            NaN           NaN      normal      normal
# 113                NaN            NaN           NaN      normal      normal
# 114                NaN            NaN           NaN      normal      normal
# 115                NaN            NaN           NaN      normal      normal
# 116                NaN            NaN           NaN      normal      normal
# 117                NaN            NaN           NaN      normal      normal
# 118                NaN            NaN           NaN      normal      normal
# 119                NaN            NaN           NaN      normal      normal
# 120                NaN            NaN           NaN      normal      normal
# 121                NaN            NaN           NaN      normal      normal
# 122                NaN            NaN           NaN      normal      normal
# 123                NaN            NaN           NaN      normal      normal
# 124                NaN            NaN           NaN      normal      normal
# 125                NaN            NaN           NaN      normal      normal
# 126                NaN            NaN           NaN      normal      normal
# 127                NaN            NaN           NaN      normal      normal
# 128                NaN            NaN           NaN      normal      normal
# 129                NaN            NaN           NaN      normal      normal
# 130                NaN            NaN           NaN      normal      normal
# 131                NaN            NaN           NaN      normal      normal
# 132                NaN            NaN           NaN      normal      normal
# 133                NaN            NaN           NaN      normal      normal
# 134                NaN            NaN           NaN      normal      normal
# 135                NaN            NaN           NaN      normal      normal
# 136                NaN            NaN           NaN      normal      normal
# 137                NaN            NaN           NaN      normal      normal
# 138                NaN            NaN           NaN      normal      normal
# 139                NaN            NaN           NaN      normal      normal
# 140                NaN            NaN           NaN      normal      normal
# 141                NaN            NaN           NaN      normal      normal
# 142                NaN            NaN           NaN      normal      normal
# 143                NaN            NaN           NaN      normal      normal
#
#      ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  LumB  Normal  \
# 111  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 112  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 113  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 114  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 115  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 116  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 117  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 118  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 119  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 120  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 121  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 122  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 123  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 124  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 125  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 126  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 127  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 128  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 129  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 130  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 131  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 132  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 133  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 134  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 135  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 136  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 137  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 138  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 139  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 140  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 141  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 142  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 143  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
#
#      agg_rank_raw  agg_rank_scaled  risk_group
# 111           NaN              NaN         NaN
# 112           NaN              NaN         NaN
# 113           NaN              NaN         NaN
# 114           NaN              NaN         NaN
# 115           NaN              NaN         NaN
# 116           NaN              NaN         NaN
# 117           NaN              NaN         NaN
# 118           NaN              NaN         NaN
# 119           NaN              NaN         NaN
# 120           NaN              NaN         NaN
# 121           NaN              NaN         NaN
# 122           NaN              NaN         NaN
# 123           NaN              NaN         NaN
# 124           NaN              NaN         NaN
# 125           NaN              NaN         NaN
# 126           NaN              NaN         NaN
# 127           NaN              NaN         NaN
# 128           NaN              NaN         NaN
# 129           NaN              NaN         NaN
# 130           NaN              NaN         NaN
# 131           NaN              NaN         NaN
# 132           NaN              NaN         NaN
# 133           NaN              NaN         NaN
# 134           NaN              NaN         NaN
# 135           NaN              NaN         NaN
# 136           NaN              NaN         NaN
# 137           NaN              NaN         NaN
# 138           NaN              NaN         NaN
# 139           NaN              NaN         NaN
# 140           NaN              NaN         NaN
# 141           NaN              NaN         NaN
# 142           NaN              NaN         NaN
# 143           NaN              NaN         NaN
#
# [33 rows x 113 columns]

# %%
tumors_included = meta_include['common_ID'].tolist()
tumors_excluded = meta_exclude['common_ID'].tolist()
print(len(tumors_included), len(tumors_excluded))
# Out:
# 134 16

# %%
normals = meta_normal['common_ID'].tolist()
print(len(normals))
# Out:
# 33

# %%
# data
files = [i for i in DATA_DIR.iterdir() if i.is_file()]
files = [i for i in files if re.search(r"pY_TMT_ratio",i.stem, re.IGNORECASE) and not re.search(r"tumor_purity_corrected",i.stem, re.IGNORECASE)]
data_path = files[0]
header_cols = ["gene_site","Index","SequenceWindow"]
data = pd.read_csv(data_path,sep="\t").set_index(header_cols)
data_nomiss = data.dropna()

# %%
data
# Out:
#                                                     C3L.05292.T  C3L.09383.T  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF     0.075709    -0.137960
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS          NaN          NaN
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP     0.125084    -0.402779
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN          NaN
# ...                                                         ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.827454    -0.142827
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.552850     0.195790
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN          NaN
#
#                                                     CHTN.43798.T  C3L.06261.N  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF      0.181015     0.032786
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS           NaN          NaN
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK           NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP     -0.920958    -0.571512
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR           NaN          NaN
# ...                                                          ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK     -0.880328     0.714407
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL           NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT      0.380169    -0.045628
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK           NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK           NaN          NaN
#
#                                                     C3L.08811.T  C3L.06506.N  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF     0.291886     0.270585
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS          NaN          NaN
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP     0.556565    -1.039896
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN          NaN
# ...                                                         ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK     0.007626    -0.391110
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.303925     0.196359
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN          NaN
#
#                                                     C3L.07804.T  C3L.06595.T  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF     0.129022    -0.076118
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS          NaN          NaN
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP     0.586245    -0.642657
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN          NaN
# ...                                                         ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK     1.038525    -0.779882
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT     0.086441    -0.145550
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN          NaN
#
#                                                     C3L.06742.T  CHTN.45205.T  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF     0.640499      0.138065
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS          NaN           NaN
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN           NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.356508     -0.066525
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN           NaN
# ...                                                         ...           ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.677578     -0.552300
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN           NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT     0.058903     -0.033354
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN           NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN           NaN
#
#                                                     ...  C3L.07875.T  \
# gene_site     Index                SequenceWindow   ...
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF  ...          NaN
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS  ...    -0.099660
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK  ...          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP  ...    -0.409358
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR  ...          NaN
# ...                                                 ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK  ...    -0.786446
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL  ...          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT  ...    -0.211063
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK  ...          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK  ...          NaN
#
#                                                     CHTN.44966.T  C3L.11192.N  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF           NaN          NaN
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS     -0.006794     0.067250
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK           NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP     -0.838598    -0.714778
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR           NaN          NaN
# ...                                                          ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK     -0.658301     1.093583
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL           NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT     -0.058651     0.224787
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK           NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK           NaN          NaN
#
#                                                     C3L.08805.T  C3L.09760.T  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF          NaN          NaN
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS     1.224682     0.153919
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.494931     0.551731
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN          NaN
# ...                                                         ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.069713    -0.200951
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT     0.004024    -0.252657
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN          NaN
#
#                                                     C3L.08444.T  C3L.08291.T  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF          NaN          NaN
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS    -0.697774     0.011222
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.408248     0.002109
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN          NaN
# ...                                                         ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.542179    -0.416224
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.032761     0.092753
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN          NaN
#
#                                                     C3L.10583.T  C3L.07877.T  \
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF          NaN          NaN
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS     0.864579    -0.475067
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.363470    -0.632637
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN          NaN
# ...                                                         ...          ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK     0.227256    -0.140600
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.406497    -0.192579
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN          NaN
#
#                                                     C3L.08736.T
# gene_site     Index                SequenceWindow
# FKBP4_Y220    ENSP00000001008_Y220 KGEHSIVyLKPSYAF          NaN
# BAIAP2L1_Y274 ENSP00000005260_Y274 SNVVRKDyDTLSKCS     0.302777
# SKAP2_Y151    ENSP00000005587_Y151 LSKTVFYyYGSDKDK          NaN
# SKAP2_Y197    ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.172131
# PPP5C_Y434    ENSP00000012443_Y434 HEVKAEGyEVAHGGR          NaN
# ...                                                         ...
# PEAK1_Y635    ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.103145
# MPP7_Y417     ENSP00000507917_Y417 QESDGVEyIFISKHL          NaN
# ANXA6_Y302    ENSP00000514965_Y302 TKYEKSLySMIKNDT    -0.420909
# ANXA6_Y566    ENSP00000514965_Y566 EFIKMTNyDVEHTIK          NaN
# ANXA6_Y95     ENSP00000514965_Y95  GLMRPPAyCDAKEIK          NaN
#
# [1043 rows x 178 columns]

# %%
data_nomiss
# Out:
#                                                    C3L.05292.T  C3L.09383.T  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP     0.125084    -0.402779
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD    -0.172111    -0.810604
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP     0.284018     0.740617
# PTPN18_Y389  ENSP00000175756_Y389 SAEEAPLySKVTPRA    -0.358010    -0.539183
# MAPK13_Y182  ENSP00000211287_Y182 ADAEMTGyVVTRWYR    -0.544370     0.245563
# ...                                                        ...          ...
# TPM4_Y126    ENSP00000495347_Y126 AEEADRKyEEVARKL    -2.132004    -0.085055
# RPL35A_Y34   ENSP00000495672_Y34  LLKIEGVyARDETEF     0.084544    -0.001755
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK     0.231253     0.280108
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -1.210519    -1.664999
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.827454    -0.142827
#
#                                                    CHTN.43798.T  C3L.06261.N  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP     -0.920958    -0.571512
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD      0.107320    -0.208893
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP      0.019544     0.338889
# PTPN18_Y389  ENSP00000175756_Y389 SAEEAPLySKVTPRA     -0.144602    -0.047257
# MAPK13_Y182  ENSP00000211287_Y182 ADAEMTGyVVTRWYR     -0.535972     0.541866
# ...                                                         ...          ...
# TPM4_Y126    ENSP00000495347_Y126 AEEADRKyEEVARKL     -2.043330    -1.399712
# RPL35A_Y34   ENSP00000495672_Y34  LLKIEGVyARDETEF      0.448620    -0.267492
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK      0.367719     0.044338
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH     -1.134086    -0.928078
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK     -0.880328     0.714407
#
#                                                    C3L.08811.T  C3L.06506.N  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP     0.556565    -1.039896
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD    -0.090678    -0.037517
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP     0.522932     0.146001
# PTPN18_Y389  ENSP00000175756_Y389 SAEEAPLySKVTPRA    -0.050573    -0.189037
# MAPK13_Y182  ENSP00000211287_Y182 ADAEMTGyVVTRWYR    -0.803904     0.393037
# ...                                                        ...          ...
# TPM4_Y126    ENSP00000495347_Y126 AEEADRKyEEVARKL    -1.000343    -2.002887
# RPL35A_Y34   ENSP00000495672_Y34  LLKIEGVyARDETEF     0.354360     0.395548
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK     0.142879     0.345239
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -1.237016    -0.930810
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK     0.007626    -0.391110
#
#                                                    C3L.07804.T  C3L.06595.T  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP     0.586245    -0.642657
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD    -1.477555    -0.082455
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP     0.396034     0.227980
# PTPN18_Y389  ENSP00000175756_Y389 SAEEAPLySKVTPRA     0.079485     0.000798
# MAPK13_Y182  ENSP00000211287_Y182 ADAEMTGyVVTRWYR     1.198873    -1.169493
# ...                                                        ...          ...
# TPM4_Y126    ENSP00000495347_Y126 AEEADRKyEEVARKL    -1.269371    -1.840726
# RPL35A_Y34   ENSP00000495672_Y34  LLKIEGVyARDETEF    -0.042931     0.580525
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK     0.370048     0.211200
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -1.342014    -1.941266
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK     1.038525    -0.779882
#
#                                                    C3L.06742.T  CHTN.45205.T  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.356508     -0.066525
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD    -0.005112     -0.298522
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP     0.016988      0.528046
# PTPN18_Y389  ENSP00000175756_Y389 SAEEAPLySKVTPRA    -0.404126     -0.245493
# MAPK13_Y182  ENSP00000211287_Y182 ADAEMTGyVVTRWYR    -0.332695     -0.643930
# ...                                                        ...           ...
# TPM4_Y126    ENSP00000495347_Y126 AEEADRKyEEVARKL    -1.556630     -1.838495
# RPL35A_Y34   ENSP00000495672_Y34  LLKIEGVyARDETEF     0.499606     -0.052433
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK     0.558103      0.269474
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -0.205454     -1.145592
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.677578     -0.552300
#
#                                                    ...  C3L.07875.T  \
# gene_site    Index                SequenceWindow   ...
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP  ...    -0.409358
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD  ...     0.294426
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP  ...     0.272657
# PTPN18_Y389  ENSP00000175756_Y389 SAEEAPLySKVTPRA  ...     0.002447
# MAPK13_Y182  ENSP00000211287_Y182 ADAEMTGyVVTRWYR  ...    -0.536011
# ...                                                ...          ...
# TPM4_Y126    ENSP00000495347_Y126 AEEADRKyEEVARKL  ...    -0.472590
# RPL35A_Y34   ENSP00000495672_Y34  LLKIEGVyARDETEF  ...    -0.086324
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK  ...    -0.419334
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH  ...    -0.047569
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK  ...    -0.786446
#
#                                                    CHTN.44966.T  C3L.11192.N  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP     -0.838598    -0.714778
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD     -0.102778     0.544234
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP     -0.229498    -0.390365
# PTPN18_Y389  ENSP00000175756_Y389 SAEEAPLySKVTPRA      0.241817     0.199812
# MAPK13_Y182  ENSP00000211287_Y182 ADAEMTGyVVTRWYR     -1.305127     0.005155
# ...                                                         ...          ...
# TPM4_Y126    ENSP00000495347_Y126 AEEADRKyEEVARKL     -0.453297     3.692061
# RPL35A_Y34   ENSP00000495672_Y34  LLKIEGVyARDETEF     -0.137930    -0.647252
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK      0.446736     0.246673
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH      0.153083     0.938364
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK     -0.658301     1.093583
#
#                                                    C3L.08805.T  C3L.09760.T  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.494931     0.551731
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD     0.055242    -0.156129
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP    -1.313487    -0.101955
# PTPN18_Y389  ENSP00000175756_Y389 SAEEAPLySKVTPRA     1.894145     0.358599
# MAPK13_Y182  ENSP00000211287_Y182 ADAEMTGyVVTRWYR    -0.486599    -0.338085
# ...                                                        ...          ...
# TPM4_Y126    ENSP00000495347_Y126 AEEADRKyEEVARKL    -1.578192    -0.158473
# RPL35A_Y34   ENSP00000495672_Y34  LLKIEGVyARDETEF     0.561221     0.325277
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK    -0.497817     0.708454
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -0.073100     0.248104
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.069713    -0.200951
#
#                                                    C3L.08444.T  C3L.08291.T  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.408248     0.002109
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD    -0.261583    -0.359032
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP    -0.123263    -0.743751
# PTPN18_Y389  ENSP00000175756_Y389 SAEEAPLySKVTPRA    -0.075886    -0.036768
# MAPK13_Y182  ENSP00000211287_Y182 ADAEMTGyVVTRWYR    -0.933972    -1.249856
# ...                                                        ...          ...
# TPM4_Y126    ENSP00000495347_Y126 AEEADRKyEEVARKL    -2.544700    -0.239751
# RPL35A_Y34   ENSP00000495672_Y34  LLKIEGVyARDETEF    -0.524152    -0.104868
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK     0.452177     0.298747
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -0.096958    -0.263559
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.542179    -0.416224
#
#                                                    C3L.10583.T  C3L.07877.T  \
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.363470    -0.632637
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD    -0.010995    -0.433552
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP    -0.131267     0.118609
# PTPN18_Y389  ENSP00000175756_Y389 SAEEAPLySKVTPRA     0.523278     0.072091
# MAPK13_Y182  ENSP00000211287_Y182 ADAEMTGyVVTRWYR    -0.916885     1.428281
# ...                                                        ...          ...
# TPM4_Y126    ENSP00000495347_Y126 AEEADRKyEEVARKL    -0.442427    -2.826096
# RPL35A_Y34   ENSP00000495672_Y34  LLKIEGVyARDETEF    -0.133985    -0.233719
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK    -0.373143     0.427008
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH     0.152800     0.293748
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK     0.227256    -0.140600
#
#                                                    C3L.08736.T
# gene_site    Index                SequenceWindow
# SKAP2_Y197   ENSP00000005587_Y197 SAPDKRIyQFTAASP    -0.172131
# RCN1_Y290    ENSP00000054950_Y290 AEARHLVyESDKNKD    -0.824158
# ARHGEF5_Y656 ENSP00000056217_Y656 DRRSGRDySTVSASP    -0.106555
# PTPN18_Y389  ENSP00000175756_Y389 SAEEAPLySKVTPRA    -0.225745
# MAPK13_Y182  ENSP00000211287_Y182 ADAEMTGyVVTRWYR    -0.361478
# ...                                                        ...
# TPM4_Y126    ENSP00000495347_Y126 AEEADRKyEEVARKL    -2.806351
# RPL35A_Y34   ENSP00000495672_Y34  LLKIEGVyARDETEF    -0.005160
# CTPS1_Y96    ENSP00000496792_Y96  TTGKIYQyVINKERK     0.476946
# PDIA4_Y392   ENSP00000499129_Y392 IKDFVLKyALPLVGH    -0.203356
# PEAK1_Y635   ENSP00000507603_Y635 IVINPNAyDNLAIYK    -0.103145
#
# [195 rows x 178 columns]

# %%
samples = data.columns.tolist()
len(samples)
# Out:
# 178

# %%
set_tumors_included = set(tumors_included)
set_tumors_excluded = set(tumors_excluded)
set_normals = set(normals)
set_data = set(samples)
print((len(set_tumors_included), len(set_tumors_excluded), len(set_normals), len(set_data)))
# Out:
# (134, 16, 33, 178)

# %%
set_data - set_tumors_included - set_tumors_excluded - set_normals
# Out:
# {'C3L.06436.T',
#  'C3L.07292.N',
#  'C3L.07606.N',
#  'C3L.08546.T',
#  'C3L.09345.T',
#  'C3L.09373.T',
#  'C3L.09793.T',
#  'C3L.09832.T',
#  'C3L.09972.T',
#  'C3L.10301.T',
#  'CHTN.47295.T'}

# %%
import matplotlib.pyplot as plt
from venn import venn

# 四个集合
sets = {
    "Meta.T.In": set_tumors_included,
    "Meta.T.Ex": set_tumors_excluded,
    "Meta.N": set_normals,
    "Prot.Samples": set_data
}

plt.figure(figsize=(8, 8))
venn(sets)
plt.title("4-set Venn Diagram\n(Tumors Included, Tumors Excluded, Normals, Data Samples)\nUbi TMT Ratio Samples")
plt.show()
