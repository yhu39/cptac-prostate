# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import re,sys,os
import pandas as pd
import numpy as np
from tqdm import tqdm
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib

# Set font to Arial
matplotlib.rcParams['font.family'] = 'Arial'

# Optional: Set PDF to embed fonts (for Illustrator editing)
matplotlib.rcParams['pdf.fonttype'] = 42  # TrueType fonts for better editing

# %%
DATA_DIR = Path(r"D:\lab\cptac_prostate\data\v4\CPTAC")
OUTPUT_DIR = Path(r"D:\lab\cptac_prostate\runs\20260330_cptac_acetyl_tmt_normalized_pca")
print(DATA_DIR.exists(), OUTPUT_DIR.exists())
meta_path = DATA_DIR / "20_MetaData_03_12_2026.csv"
# Out:
# True False

# %%
meta = pd.read_csv(meta_path)
meta
# Out:
#         case_id     common_ID Tissuetype include_or_excludetumor  \
# 0     C3L-07287   C3L.07287.T      tumor                 Include
# 1     C3L-11156   C3L.11156.T      tumor                 Include
# 2     C3L-09494   C3L.09494.T      tumor                 Include
# 3    CHTN-49141  CHTN.49141.T      tumor                 Include
# 4     C3L-11095   C3L.11095.T      tumor                 Include
# ..          ...           ...        ...                     ...
# 178   C3L-07872   C3L.07872.T      tumor                 Include
# 179   C3L-08642   C3L.08642.T      tumor                 Include
# 180   C3L-10399   C3L.10399.T      tumor                 Include
# 181   C3L-05301   C3L.05301.T      tumor                 Include
# 182   C3L-08384   C3L.08384.T      tumor                 Include
#
#          FirstCategory AdditionalSegments SecondCategory ThirdCategory  \
# 0    Sufficient Purity                ETS            ETS           NaN
# 1    Sufficient Purity                ETS            ETS           NaN
# 2    Sufficient Purity                ETS            ETS           NaN
# 3    Sufficient Purity                ETS            ETS           NaN
# 4    Sufficient Purity                ETS            ETS           NaN
# ..                 ...                ...            ...           ...
# 178         Low Purity                NaN            NaN           NaN
# 179         Low Purity                NaN            NaN           NaN
# 180         Low Purity                NaN            NaN           NaN
# 181         Low Purity                NaN            NaN           NaN
# 182         Low Purity                NaN            NaN           NaN
#
#     all_drivers Main_Groups  ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  \
# 0           ERG         ERG  ...    0.342000      0.000000   0.0   0.0   1.0
# 1           ERG         ERG  ...    0.000000      0.498000   0.0   0.0   1.0
# 2           ERG         ERG  ...    0.281000      0.000000   0.0   1.0   0.0
# 3           ERG         ERG  ...    0.420000      0.000000   0.0   1.0   0.0
# 4           ERG         ERG  ...    0.000000      0.369000   0.0   0.0   1.0
# ..          ...         ...  ...         ...           ...   ...   ...   ...
# 178         ERG         ERG  ...    0.000000      0.460832   1.0   0.0   0.0
# 179         ERG         ERG  ...    0.000000      0.334840   0.0   0.0   1.0
# 180         ERG         ERG  ...    0.000000      0.445334   0.0   0.0   1.0
# 181        ETV1        ETV1  ...    0.000000      0.457908   0.0   0.0   1.0
# 182         ERG         ERG  ...    0.789835      0.000000   0.0   0.0   0.0
#
#      LumB  Normal  agg_rank_raw  agg_rank_scaled  risk_group
# 0     0.0     0.0     55.333000         0.409000          IR
# 1     0.0     0.0     44.167000         0.325000          LR
# 2     0.0     0.0    123.167000         0.919000          HR
# 3     0.0     0.0    103.833000         0.773000          HR
# 4     0.0     0.0     44.667000         0.328000          LR
# ..    ...     ...           ...              ...         ...
# 178   0.0     0.0     73.666667         0.546366          IR
# 179   0.0     0.0     46.166667         0.339599          LR
# 180   0.0     0.0     60.000000         0.443609          IR
# 181   0.0     0.0     45.333333         0.333333          LR
# 182   1.0     0.0     88.166667         0.655000          HR
#
# [183 rows x 113 columns]

# %%
meta_include = meta[meta["include_or_excludetumor"] == "Include"]
meta_include
# Out:
#         case_id     common_ID Tissuetype include_or_excludetumor  \
# 0     C3L-07287   C3L.07287.T      tumor                 Include
# 1     C3L-11156   C3L.11156.T      tumor                 Include
# 2     C3L-09494   C3L.09494.T      tumor                 Include
# 3    CHTN-49141  CHTN.49141.T      tumor                 Include
# 4     C3L-11095   C3L.11095.T      tumor                 Include
# ..          ...           ...        ...                     ...
# 178   C3L-07872   C3L.07872.T      tumor                 Include
# 179   C3L-08642   C3L.08642.T      tumor                 Include
# 180   C3L-10399   C3L.10399.T      tumor                 Include
# 181   C3L-05301   C3L.05301.T      tumor                 Include
# 182   C3L-08384   C3L.08384.T      tumor                 Include
#
#          FirstCategory AdditionalSegments SecondCategory ThirdCategory  \
# 0    Sufficient Purity                ETS            ETS           NaN
# 1    Sufficient Purity                ETS            ETS           NaN
# 2    Sufficient Purity                ETS            ETS           NaN
# 3    Sufficient Purity                ETS            ETS           NaN
# 4    Sufficient Purity                ETS            ETS           NaN
# ..                 ...                ...            ...           ...
# 178         Low Purity                NaN            NaN           NaN
# 179         Low Purity                NaN            NaN           NaN
# 180         Low Purity                NaN            NaN           NaN
# 181         Low Purity                NaN            NaN           NaN
# 182         Low Purity                NaN            NaN           NaN
#
#     all_drivers Main_Groups  ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  \
# 0           ERG         ERG  ...    0.342000      0.000000   0.0   0.0   1.0
# 1           ERG         ERG  ...    0.000000      0.498000   0.0   0.0   1.0
# 2           ERG         ERG  ...    0.281000      0.000000   0.0   1.0   0.0
# 3           ERG         ERG  ...    0.420000      0.000000   0.0   1.0   0.0
# 4           ERG         ERG  ...    0.000000      0.369000   0.0   0.0   1.0
# ..          ...         ...  ...         ...           ...   ...   ...   ...
# 178         ERG         ERG  ...    0.000000      0.460832   1.0   0.0   0.0
# 179         ERG         ERG  ...    0.000000      0.334840   0.0   0.0   1.0
# 180         ERG         ERG  ...    0.000000      0.445334   0.0   0.0   1.0
# 181        ETV1        ETV1  ...    0.000000      0.457908   0.0   0.0   1.0
# 182         ERG         ERG  ...    0.789835      0.000000   0.0   0.0   0.0
#
#      LumB  Normal  agg_rank_raw  agg_rank_scaled  risk_group
# 0     0.0     0.0     55.333000         0.409000          IR
# 1     0.0     0.0     44.167000         0.325000          LR
# 2     0.0     0.0    123.167000         0.919000          HR
# 3     0.0     0.0    103.833000         0.773000          HR
# 4     0.0     0.0     44.667000         0.328000          LR
# ..    ...     ...           ...              ...         ...
# 178   0.0     0.0     73.666667         0.546366          IR
# 179   0.0     0.0     46.166667         0.339599          LR
# 180   0.0     0.0     60.000000         0.443609          IR
# 181   0.0     0.0     45.333333         0.333333          LR
# 182   1.0     0.0     88.166667         0.655000          HR
#
# [134 rows x 113 columns]

# %%
purity_map = dict(zip(meta_include["common_ID"], meta_include["FirstCategory"]))
stage_map = dict(zip(meta_include["common_ID"], meta_include["stage"]))
gleason_map = dict(zip(meta_include["common_ID"], meta_include["Gleason_um"]))

# %%
meta_exclude = meta[meta["include_or_excludetumor"] == "exclude"]
meta_exclude
# Out:
#        case_id    common_ID Tissuetype include_or_excludetumor FirstCategory  \
# 144  C3L-09492  C3L.09492.T      tumor                 exclude      No Tumor
# 145  C3L-09497  C3L.09497.T      tumor                 exclude      No Tumor
# 146  C3L-06260  C3L.06260.T      tumor                 exclude      No Tumor
# 147  C3L-06510  C3L.06510.T      tumor                 exclude      No Tumor
# 148  C3L-07890  C3L.07890.T      tumor                 exclude      No Tumor
# 149  C3L-09372  C3L.09372.T      tumor                 exclude      No Tumor
# 150  C3N-09047  C3N.09047.T      tumor                 exclude      No Tumor
# 151  C3L-07868  C3L.07868.T      tumor                 exclude      No Tumor
# 152  C3L-09563  C3L.09563.T      tumor                 exclude      No Tumor
# 153  C3L-10319  C3L.10319.T      tumor                 exclude      No Tumor
# 154  C3L-06657  C3L.06657.T      tumor                 exclude      No Tumor
# 155  C3L-07405  C3L.07405.T      tumor                 exclude      No Tumor
# 156  C3L-06573  C3L.06573.T      tumor                 exclude      No Tumor
# 157  C3L-07813  C3L.07813.T      tumor                 exclude      No Tumor
# 158  C3L-08377  C3L.08377.T      tumor                 exclude      No Tumor
# 159  C3L-08371  C3L.08371.T      tumor                 exclude      No Tumor
#
#     AdditionalSegments SecondCategory ThirdCategory all_drivers Main_Groups  \
# 144                NaN            NaN           NaN         NaN    No Tumor
# 145                NaN            NaN           NaN         NaN    No Tumor
# 146                NaN            NaN           NaN         NaN    No Tumor
# 147                NaN            NaN           NaN         NaN    No Tumor
# 148                NaN            NaN           NaN         NaN    No Tumor
# 149                NaN            NaN           NaN         NaN    No Tumor
# 150                NaN            NaN           NaN         NaN    No Tumor
# 151                NaN            NaN           NaN         NaN    No Tumor
# 152                NaN            NaN           NaN         NaN    No Tumor
# 153                NaN            NaN           NaN         NaN    No Tumor
# 154                NaN            NaN           NaN         NaN    No Tumor
# 155                NaN            NaN           NaN         NaN    No Tumor
# 156                NaN            NaN           NaN         NaN    No Tumor
# 157                NaN            NaN           NaN         NaN    No Tumor
# 158                NaN            NaN           NaN         NaN    No Tumor
# 159                NaN            NaN           NaN         NaN    No Tumor
#
#      ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  LumB  Normal  \
# 144  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 145  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 146  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 147  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 148  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 149  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 150  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 151  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 152  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 153  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 154  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 155  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 156  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 157  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 158  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 159  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
#
#      agg_rank_raw  agg_rank_scaled  risk_group
# 144           NaN              NaN         NaN
# 145           NaN              NaN         NaN
# 146           NaN              NaN         NaN
# 147           NaN              NaN         NaN
# 148           NaN              NaN         NaN
# 149           NaN              NaN         NaN
# 150           NaN              NaN         NaN
# 151           NaN              NaN         NaN
# 152           NaN              NaN         NaN
# 153           NaN              NaN         NaN
# 154           NaN              NaN         NaN
# 155           NaN              NaN         NaN
# 156           NaN              NaN         NaN
# 157           NaN              NaN         NaN
# 158           NaN              NaN         NaN
# 159           NaN              NaN         NaN
#
# [16 rows x 113 columns]

# %%
meta_normal = meta[meta["include_or_excludetumor"] == "normal"]
meta_normal
# Out:
#        case_id    common_ID Tissuetype include_or_excludetumor FirstCategory  \
# 111  C3L-07813  C3L.07813.N     normal                  normal        Normal
# 112  C3L-06504  C3L.06504.N     normal                  normal        Normal
# 113  C3L-06506  C3L.06506.N     normal                  normal        Normal
# 114  C3L-06741  C3L.06741.N     normal                  normal        Normal
# 115  C3L-06890  C3L.06890.N     normal                  normal        Normal
# 116  C3L-06901  C3L.06901.N     normal                  normal        Normal
# 117  C3L-06743  C3L.06743.N     normal                  normal        Normal
# 118  C3L-07607  C3L.07607.N     normal                  normal        Normal
# 119  C3L-06436  C3L.06436.N     normal                  normal        Normal
# 120  C3L-07809  C3L.07809.N     normal                  normal        Normal
# 121  C3L-07872  C3L.07872.N     normal                  normal        Normal
# 122  C3L-08293  C3L.08293.N     normal                  normal        Normal
# 123  C3L-07871  C3L.07871.N     normal                  normal        Normal
# 124  C3L-08084  C3L.08084.N     normal                  normal        Normal
# 125  C3L-08371  C3L.08371.N     normal                  normal        Normal
# 126  C3L-08372  C3L.08372.N     normal                  normal        Normal
# 127  C3L-08818  C3L.08818.N     normal                  normal        Normal
# 128  C3L-08380  C3L.08380.N     normal                  normal        Normal
# 129  C3L-08811  C3L.08811.N     normal                  normal        Normal
# 130  C3L-08378  C3L.08378.N     normal                  normal        Normal
# 131  C3L-08382  C3L.08382.N     normal                  normal        Normal
# 132  C3L-09107  C3L.09107.N     normal                  normal        Normal
# 133  C3L-09701  C3L.09701.N     normal                  normal        Normal
# 134  C3L-06252  C3L.06252.N     normal                  normal        Normal
# 135  C3L-08755  C3L.08755.N     normal                  normal        Normal
# 136  C3L-06260  C3L.06260.N     normal                  normal        Normal
# 137  C3L-06261  C3L.06261.N     normal                  normal        Normal
# 138  C3L-09691  C3L.09691.N     normal                  normal        Normal
# 139  C3L-11176  C3L.11176.N     normal                  normal        Normal
# 140  C3L-08800  C3L.08800.N     normal                  normal        Normal
# 141  C3L-08802  C3L.08802.N     normal                  normal        Normal
# 142  C3L-11192  C3L.11192.N     normal                  normal        Normal
# 143  C3L-11122  C3L.11122.N     normal                  normal        Normal
#
#     AdditionalSegments SecondCategory ThirdCategory all_drivers Main_Groups  \
# 111                NaN            NaN           NaN      normal      normal
# 112                NaN            NaN           NaN      normal      normal
# 113                NaN            NaN           NaN      normal      normal
# 114                NaN            NaN           NaN      normal      normal
# 115                NaN            NaN           NaN      normal      normal
# 116                NaN            NaN           NaN      normal      normal
# 117                NaN            NaN           NaN      normal      normal
# 118                NaN            NaN           NaN      normal      normal
# 119                NaN            NaN           NaN      normal      normal
# 120                NaN            NaN           NaN      normal      normal
# 121                NaN            NaN           NaN      normal      normal
# 122                NaN            NaN           NaN      normal      normal
# 123                NaN            NaN           NaN      normal      normal
# 124                NaN            NaN           NaN      normal      normal
# 125                NaN            NaN           NaN      normal      normal
# 126                NaN            NaN           NaN      normal      normal
# 127                NaN            NaN           NaN      normal      normal
# 128                NaN            NaN           NaN      normal      normal
# 129                NaN            NaN           NaN      normal      normal
# 130                NaN            NaN           NaN      normal      normal
# 131                NaN            NaN           NaN      normal      normal
# 132                NaN            NaN           NaN      normal      normal
# 133                NaN            NaN           NaN      normal      normal
# 134                NaN            NaN           NaN      normal      normal
# 135                NaN            NaN           NaN      normal      normal
# 136                NaN            NaN           NaN      normal      normal
# 137                NaN            NaN           NaN      normal      normal
# 138                NaN            NaN           NaN      normal      normal
# 139                NaN            NaN           NaN      normal      normal
# 140                NaN            NaN           NaN      normal      normal
# 141                NaN            NaN           NaN      normal      normal
# 142                NaN            NaN           NaN      normal      normal
# 143                NaN            NaN           NaN      normal      normal
#
#      ...  LumB_Pam50  Normal_Pam50 Basal  Her2  LumA  LumB  Normal  \
# 111  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 112  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 113  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 114  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 115  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 116  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 117  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 118  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 119  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 120  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 121  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 122  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 123  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 124  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 125  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 126  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 127  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 128  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 129  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 130  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 131  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 132  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 133  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 134  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 135  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 136  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 137  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 138  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 139  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 140  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 141  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 142  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
# 143  ...         NaN           NaN   NaN   NaN   NaN   NaN     NaN
#
#      agg_rank_raw  agg_rank_scaled  risk_group
# 111           NaN              NaN         NaN
# 112           NaN              NaN         NaN
# 113           NaN              NaN         NaN
# 114           NaN              NaN         NaN
# 115           NaN              NaN         NaN
# 116           NaN              NaN         NaN
# 117           NaN              NaN         NaN
# 118           NaN              NaN         NaN
# 119           NaN              NaN         NaN
# 120           NaN              NaN         NaN
# 121           NaN              NaN         NaN
# 122           NaN              NaN         NaN
# 123           NaN              NaN         NaN
# 124           NaN              NaN         NaN
# 125           NaN              NaN         NaN
# 126           NaN              NaN         NaN
# 127           NaN              NaN         NaN
# 128           NaN              NaN         NaN
# 129           NaN              NaN         NaN
# 130           NaN              NaN         NaN
# 131           NaN              NaN         NaN
# 132           NaN              NaN         NaN
# 133           NaN              NaN         NaN
# 134           NaN              NaN         NaN
# 135           NaN              NaN         NaN
# 136           NaN              NaN         NaN
# 137           NaN              NaN         NaN
# 138           NaN              NaN         NaN
# 139           NaN              NaN         NaN
# 140           NaN              NaN         NaN
# 141           NaN              NaN         NaN
# 142           NaN              NaN         NaN
# 143           NaN              NaN         NaN
#
# [33 rows x 113 columns]

# %%
tumors_included = meta_include['common_ID'].tolist()
tumors_excluded = meta_exclude['common_ID'].tolist()
print(len(tumors_included), len(tumors_excluded))
# Out:
# 134 16

# %%
normals = meta_normal['common_ID'].tolist()
print(len(normals))
# Out:
# 33

# %%
# data
files = [i for i in DATA_DIR.iterdir() if i.is_file()]
files = [i for i in files if re.search(r"normalized_acetyl_TMT_ratio",i.stem, re.IGNORECASE) \
         and not re.search(r"tumor_purity_corrected",i.stem, re.IGNORECASE) \
            and re.search(r"normalized",i.stem, re.IGNORECASE) ]
data_path = files[0]
print(data_path)
header_cols = ["gene_site","Index","SequenceWindow"]
data = pd.read_csv(data_path,sep="\t").set_index(header_cols)
data_nomiss = data.dropna()
# Out:
# D:\lab\cptac_prostate\data\v4\CPTAC\prostate_CPTAC_normalized_acetyl_TMT_ratio_single_site_MD.tsv

# %%
files
# Out:
# [WindowsPath('D:/lab/cptac_prostate/data/v4/CPTAC/prostate_CPTAC_normalized_acetyl_TMT_ratio_single_site_MD.tsv')]

# %%
data
# Out:
#                                                            C3L.05292.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE    -1.093119
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK     0.113284
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___    -0.047342
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE    -0.134593
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI     0.195221
#
#                                                            C3L.09383.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE    -0.270130
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK    -0.196229
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___     0.017849
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE    -0.355821
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI    -0.602545
#
#                                                            CHTN.43798.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL           NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY           NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE     -1.218097
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK           NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK      0.321667
# ...                                                                 ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP           NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG           NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___      0.175266
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE     -0.310641
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI     -0.064553
#
#                                                            C3L.06261.N  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE    -0.521286
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK     0.136194
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___     0.085559
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE    -0.410962
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI    -0.251694
#
#                                                            C3L.08811.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE    -0.677914
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK     0.244108
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___    -0.057826
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE    -0.163461
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI    -0.789253
#
#                                                            C3L.06506.N  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE    -0.442421
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK     0.340571
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___    -0.057197
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE    -0.231145
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI    -0.306784
#
#                                                            C3L.07804.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE    -0.805482
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK     0.412367
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___    -0.486978
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE    -0.295815
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI    -0.270327
#
#                                                            C3L.06595.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE     0.162361
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK    -0.109698
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___     0.356758
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE    -0.349877
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI    -0.335177
#
#                                                            C3L.06742.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE    -1.004223
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK     0.287249
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___     0.033362
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE    -0.306338
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI    -0.842913
#
#                                                            CHTN.45205.T  ...  \
# gene_site            Index                SequenceWindow                 ...
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL           NaN  ...
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY           NaN  ...
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE     -0.591182  ...
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK           NaN  ...
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK     -0.133506  ...
# ...                                                                 ...  ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP           NaN  ...
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG           NaN  ...
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___     -0.000607  ...
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE     -0.252586  ...
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI     -0.063330  ...
#
#                                                            C3L.07875.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE          NaN
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK     0.082631
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___          NaN
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE    -0.106939
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI     0.440090
#
#                                                            CHTN.44966.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL           NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY           NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE           NaN
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK           NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK      0.234729
# ...                                                                 ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP           NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG           NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___           NaN
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE      0.071164
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI     -0.182697
#
#                                                            C3L.11192.N  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE          NaN
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK     0.016033
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___          NaN
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE     0.092830
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI    -0.469057
#
#                                                            C3L.08805.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE          NaN
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK    -0.278100
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___          NaN
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE    -1.277967
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI     0.355362
#
#                                                            C3L.09760.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE          NaN
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK    -0.233119
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___          NaN
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE     0.015853
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI     0.454592
#
#                                                            C3L.08444.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE          NaN
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK     0.002138
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___          NaN
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE     0.178418
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI    -0.391925
#
#                                                            C3L.08291.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE          NaN
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK    -0.231090
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___          NaN
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE     0.069148
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI     0.153789
#
#                                                            C3L.10583.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE          NaN
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK     0.487034
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___          NaN
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE    -0.039221
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI    -0.211299
#
#                                                            C3L.07877.T  \
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE          NaN
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK    -0.095007
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___          NaN
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE     0.145700
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI    -0.063000
#
#                                                            C3L.08736.T
# gene_site            Index                SequenceWindow
# FKBP4_K181           ENSP00000001008_K181 LEGYYKDkLFDQREL          NaN
# FKBP4_K213           ENSP00000001008_K213 RAIQRMEkGEHSIVY          NaN
# FKBP4_K354           ENSP00000001008_K354 ELDSNNEkGLFRRGE          NaN
# FKBP4_K76            ENSP00000001008_K76  SSLDRKDkFSFDLGK          NaN
# BAIAP2L1_K106        ENSP00000005260_K106 EIIHELEkKIELDVK    -0.372055
# ...                                                                ...
# ENSG00000290315_K246 ENSP00000515567_K246 ASVLQPVkKRKVDMP          NaN
# ENSG00000290315_K814 ENSP00000515567_K814 VRDVFEAkARHGFCG          NaN
# MACROH2A1_K196       ENSP00000515857_K196 KSLFLGQkPPQ-___          NaN
# PGAM5_K191           ENSP00000516057_K191 DPPVSHWkPEAVYYE     0.713489
# PGAM5_K93            ENSP00000516057_K93  ASKLDHYkAKATRHI     0.784492
#
# [5028 rows x 178 columns]

# %%
data_nomiss
# Out:
#                                                     C3L.05292.T  C3L.09383.T  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K106 ENSP00000005260_K106 EIIHELEkKIELDVK     0.113284    -0.196229
# NDUFAB1_K97   ENSP00000007516_K97  YDKIDPEkLSVNSHF     0.055842     0.462163
# HEBP1_K49     ENSP00000014930_K49  ATVEVTDkPVDEALR    -0.263797     0.835233
# VDAC3_K28     ENSP00000022615_K28  GYGFGMVkIDLKTKS     0.423137     0.183397
# VDAC3_K63     ENSP00000022615_K63  GNLETKYkVCNYGLT     0.732618    -0.373442
# ...                                                         ...          ...
# HNRNPF_K87    ENSP00000507787_K87  HRYIEVFkSHRTEMD     0.109028     0.554931
# MSN_K242      ENSP00000513134_K242 RNISFNDkKFVIKPI     0.084390    -0.066740
# MSN_K243      ENSP00000513134_K243 NISFNDKkFVIKPID     0.245635    -0.554918
# MSN_K49       ENSP00000513134_K49  KGFSTWLkLNKKVTA     0.158013     0.089283
# MSN_K68       ENSP00000513134_K68  KESPLLFkFRAKFYP     0.328211     0.068040
#
#                                                     CHTN.43798.T  C3L.06261.N  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K106 ENSP00000005260_K106 EIIHELEkKIELDVK      0.321667     0.136194
# NDUFAB1_K97   ENSP00000007516_K97  YDKIDPEkLSVNSHF     -0.425500     0.526706
# HEBP1_K49     ENSP00000014930_K49  ATVEVTDkPVDEALR     -0.091773     0.126919
# VDAC3_K28     ENSP00000022615_K28  GYGFGMVkIDLKTKS      0.272881     0.289020
# VDAC3_K63     ENSP00000022615_K63  GNLETKYkVCNYGLT      0.357332     0.033310
# ...                                                          ...          ...
# HNRNPF_K87    ENSP00000507787_K87  HRYIEVFkSHRTEMD      0.152599     0.597590
# MSN_K242      ENSP00000513134_K242 RNISFNDkKFVIKPI      0.300699     0.209137
# MSN_K243      ENSP00000513134_K243 NISFNDKkFVIKPID      0.419635    -0.140100
# MSN_K49       ENSP00000513134_K49  KGFSTWLkLNKKVTA      0.357008     0.120032
# MSN_K68       ENSP00000513134_K68  KESPLLFkFRAKFYP      0.614982     0.244432
#
#                                                     C3L.08811.T  C3L.06506.N  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K106 ENSP00000005260_K106 EIIHELEkKIELDVK     0.244108     0.340571
# NDUFAB1_K97   ENSP00000007516_K97  YDKIDPEkLSVNSHF    -0.082258     0.339720
# HEBP1_K49     ENSP00000014930_K49  ATVEVTDkPVDEALR     0.146340     0.345239
# VDAC3_K28     ENSP00000022615_K28  GYGFGMVkIDLKTKS     0.192572     0.233055
# VDAC3_K63     ENSP00000022615_K63  GNLETKYkVCNYGLT     0.397117    -0.432247
# ...                                                         ...          ...
# HNRNPF_K87    ENSP00000507787_K87  HRYIEVFkSHRTEMD     0.006665     0.920717
# MSN_K242      ENSP00000513134_K242 RNISFNDkKFVIKPI     0.198963     0.164624
# MSN_K243      ENSP00000513134_K243 NISFNDKkFVIKPID    -0.043089     0.307515
# MSN_K49       ENSP00000513134_K49  KGFSTWLkLNKKVTA     0.217938     0.023216
# MSN_K68       ENSP00000513134_K68  KESPLLFkFRAKFYP    -0.082391     0.369658
#
#                                                     C3L.07804.T  C3L.06595.T  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K106 ENSP00000005260_K106 EIIHELEkKIELDVK     0.412367    -0.109698
# NDUFAB1_K97   ENSP00000007516_K97  YDKIDPEkLSVNSHF     0.140771     0.359573
# HEBP1_K49     ENSP00000014930_K49  ATVEVTDkPVDEALR    -0.373006     0.977700
# VDAC3_K28     ENSP00000022615_K28  GYGFGMVkIDLKTKS    -0.184024    -0.166429
# VDAC3_K63     ENSP00000022615_K63  GNLETKYkVCNYGLT     0.731559    -0.526551
# ...                                                         ...          ...
# HNRNPF_K87    ENSP00000507787_K87  HRYIEVFkSHRTEMD     0.181567     0.085340
# MSN_K242      ENSP00000513134_K242 RNISFNDkKFVIKPI     0.084003    -0.066752
# MSN_K243      ENSP00000513134_K243 NISFNDKkFVIKPID    -0.165004    -0.046395
# MSN_K49       ENSP00000513134_K49  KGFSTWLkLNKKVTA    -0.440357    -0.190811
# MSN_K68       ENSP00000513134_K68  KESPLLFkFRAKFYP     0.061904    -0.111259
#
#                                                     C3L.06742.T  CHTN.45205.T  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K106 ENSP00000005260_K106 EIIHELEkKIELDVK     0.287249     -0.133506
# NDUFAB1_K97   ENSP00000007516_K97  YDKIDPEkLSVNSHF     0.283990      0.228028
# HEBP1_K49     ENSP00000014930_K49  ATVEVTDkPVDEALR    -0.483633      0.441260
# VDAC3_K28     ENSP00000022615_K28  GYGFGMVkIDLKTKS    -0.044269      0.113082
# VDAC3_K63     ENSP00000022615_K63  GNLETKYkVCNYGLT     0.080332      0.016455
# ...                                                         ...           ...
# HNRNPF_K87    ENSP00000507787_K87  HRYIEVFkSHRTEMD     0.292540     -0.038155
# MSN_K242      ENSP00000513134_K242 RNISFNDkKFVIKPI     0.015376      0.226969
# MSN_K243      ENSP00000513134_K243 NISFNDKkFVIKPID     0.411598     -0.244731
# MSN_K49       ENSP00000513134_K49  KGFSTWLkLNKKVTA     0.068664     -0.016098
# MSN_K68       ENSP00000513134_K68  KESPLLFkFRAKFYP     0.325031      0.216021
#
#                                                     ...  C3L.07875.T  \
# gene_site     Index                SequenceWindow   ...
# BAIAP2L1_K106 ENSP00000005260_K106 EIIHELEkKIELDVK  ...     0.082631
# NDUFAB1_K97   ENSP00000007516_K97  YDKIDPEkLSVNSHF  ...     0.819229
# HEBP1_K49     ENSP00000014930_K49  ATVEVTDkPVDEALR  ...     0.199391
# VDAC3_K28     ENSP00000022615_K28  GYGFGMVkIDLKTKS  ...    -0.124737
# VDAC3_K63     ENSP00000022615_K63  GNLETKYkVCNYGLT  ...    -0.734042
# ...                                                 ...          ...
# HNRNPF_K87    ENSP00000507787_K87  HRYIEVFkSHRTEMD  ...    -0.666233
# MSN_K242      ENSP00000513134_K242 RNISFNDkKFVIKPI  ...    -0.749223
# MSN_K243      ENSP00000513134_K243 NISFNDKkFVIKPID  ...    -0.097070
# MSN_K49       ENSP00000513134_K49  KGFSTWLkLNKKVTA  ...    -0.520448
# MSN_K68       ENSP00000513134_K68  KESPLLFkFRAKFYP  ...    -0.985590
#
#                                                     CHTN.44966.T  C3L.11192.N  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K106 ENSP00000005260_K106 EIIHELEkKIELDVK      0.234729     0.016033
# NDUFAB1_K97   ENSP00000007516_K97  YDKIDPEkLSVNSHF      0.190754     0.442369
# HEBP1_K49     ENSP00000014930_K49  ATVEVTDkPVDEALR     -0.003665     0.074872
# VDAC3_K28     ENSP00000022615_K28  GYGFGMVkIDLKTKS      0.113123     0.031961
# VDAC3_K63     ENSP00000022615_K63  GNLETKYkVCNYGLT     -0.490265    -0.289755
# ...                                                          ...          ...
# HNRNPF_K87    ENSP00000507787_K87  HRYIEVFkSHRTEMD      0.072156    -0.123808
# MSN_K242      ENSP00000513134_K242 RNISFNDkKFVIKPI     -0.204118    -0.190106
# MSN_K243      ENSP00000513134_K243 NISFNDKkFVIKPID     -0.008126     0.183955
# MSN_K49       ENSP00000513134_K49  KGFSTWLkLNKKVTA     -0.191355    -0.107257
# MSN_K68       ENSP00000513134_K68  KESPLLFkFRAKFYP     -0.083665     0.247106
#
#                                                     C3L.08805.T  C3L.09760.T  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K106 ENSP00000005260_K106 EIIHELEkKIELDVK    -0.278100    -0.233119
# NDUFAB1_K97   ENSP00000007516_K97  YDKIDPEkLSVNSHF    -0.192276    -0.156949
# HEBP1_K49     ENSP00000014930_K49  ATVEVTDkPVDEALR    -0.138704    -0.027758
# VDAC3_K28     ENSP00000022615_K28  GYGFGMVkIDLKTKS    -1.402463     0.265893
# VDAC3_K63     ENSP00000022615_K63  GNLETKYkVCNYGLT    -0.105263     0.072364
# ...                                                         ...          ...
# HNRNPF_K87    ENSP00000507787_K87  HRYIEVFkSHRTEMD    -0.028040    -0.372940
# MSN_K242      ENSP00000513134_K242 RNISFNDkKFVIKPI    -0.843277     0.024152
# MSN_K243      ENSP00000513134_K243 NISFNDKkFVIKPID    -0.450034    -0.036185
# MSN_K49       ENSP00000513134_K49  KGFSTWLkLNKKVTA    -0.558064    -0.007604
# MSN_K68       ENSP00000513134_K68  KESPLLFkFRAKFYP    -0.791353     0.099068
#
#                                                     C3L.08444.T  C3L.08291.T  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K106 ENSP00000005260_K106 EIIHELEkKIELDVK     0.002138    -0.231090
# NDUFAB1_K97   ENSP00000007516_K97  YDKIDPEkLSVNSHF    -0.001337    -0.582786
# HEBP1_K49     ENSP00000014930_K49  ATVEVTDkPVDEALR     0.059742    -0.345674
# VDAC3_K28     ENSP00000022615_K28  GYGFGMVkIDLKTKS     0.087571     0.170212
# VDAC3_K63     ENSP00000022615_K63  GNLETKYkVCNYGLT     0.227309     0.231504
# ...                                                         ...          ...
# HNRNPF_K87    ENSP00000507787_K87  HRYIEVFkSHRTEMD     0.114383    -0.423036
# MSN_K242      ENSP00000513134_K242 RNISFNDkKFVIKPI     0.078246     0.197810
# MSN_K243      ENSP00000513134_K243 NISFNDKkFVIKPID     0.073297    -0.140402
# MSN_K49       ENSP00000513134_K49  KGFSTWLkLNKKVTA     0.134933    -0.027177
# MSN_K68       ENSP00000513134_K68  KESPLLFkFRAKFYP     0.158146    -0.135617
#
#                                                     C3L.10583.T  C3L.07877.T  \
# gene_site     Index                SequenceWindow
# BAIAP2L1_K106 ENSP00000005260_K106 EIIHELEkKIELDVK     0.487034    -0.095007
# NDUFAB1_K97   ENSP00000007516_K97  YDKIDPEkLSVNSHF     0.405264    -0.021327
# HEBP1_K49     ENSP00000014930_K49  ATVEVTDkPVDEALR     0.153338    -0.095050
# VDAC3_K28     ENSP00000022615_K28  GYGFGMVkIDLKTKS     0.031869     0.155850
# VDAC3_K63     ENSP00000022615_K63  GNLETKYkVCNYGLT    -0.206039    -0.128362
# ...                                                         ...          ...
# HNRNPF_K87    ENSP00000507787_K87  HRYIEVFkSHRTEMD     0.036180    -0.147679
# MSN_K242      ENSP00000513134_K242 RNISFNDkKFVIKPI    -0.430754    -0.013363
# MSN_K243      ENSP00000513134_K243 NISFNDKkFVIKPID    -0.072267    -0.195198
# MSN_K49       ENSP00000513134_K49  KGFSTWLkLNKKVTA    -0.096189    -0.347980
# MSN_K68       ENSP00000513134_K68  KESPLLFkFRAKFYP    -0.011287    -0.314801
#
#                                                     C3L.08736.T
# gene_site     Index                SequenceWindow
# BAIAP2L1_K106 ENSP00000005260_K106 EIIHELEkKIELDVK    -0.372055
# NDUFAB1_K97   ENSP00000007516_K97  YDKIDPEkLSVNSHF    -0.588985
# HEBP1_K49     ENSP00000014930_K49  ATVEVTDkPVDEALR    -0.270437
# VDAC3_K28     ENSP00000022615_K28  GYGFGMVkIDLKTKS     0.577976
# VDAC3_K63     ENSP00000022615_K63  GNLETKYkVCNYGLT     0.762779
# ...                                                         ...
# HNRNPF_K87    ENSP00000507787_K87  HRYIEVFkSHRTEMD    -0.228530
# MSN_K242      ENSP00000513134_K242 RNISFNDkKFVIKPI    -0.082712
# MSN_K243      ENSP00000513134_K243 NISFNDKkFVIKPID    -0.251203
# MSN_K49       ENSP00000513134_K49  KGFSTWLkLNKKVTA     0.110485
# MSN_K68       ENSP00000513134_K68  KESPLLFkFRAKFYP    -0.389941
#
# [1665 rows x 178 columns]

# %%
samples = data.columns.tolist()
len(samples)
# Out:
# 178

# %%
set_tumors_included = set(tumors_included)
set_tumors_excluded = set(tumors_excluded)
set_normals = set(normals)
set_data = set(samples)
print((len(set_tumors_included), len(set_tumors_excluded), len(set_normals), len(set_data)))
# Out:
# (134, 16, 33, 178)

# %%
set_data - set_tumors_included - set_tumors_excluded - set_normals
# Out:
# {'C3L.06436.T',
#  'C3L.07292.N',
#  'C3L.07606.N',
#  'C3L.08546.T',
#  'C3L.09345.T',
#  'C3L.09373.T',
#  'C3L.09793.T',
#  'C3L.09832.T',
#  'C3L.09972.T',
#  'C3L.10301.T',
#  'CHTN.47295.T'}

# %%
data.boxplot(figsize=(40,6), rot=90)
# Out:
# <Axes: >

# %%
from omicsone_streamlit.plots.pca import plot_pca1

# %%
print(len(tumors_included), len(normals))
# Out:
# 134 33

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = "Tumor"
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"

# %%
len(set(data.columns) & set(tumors_included))
# Out:
# 134

# %%
data2 = data_nomiss.T.loc[tumors_included + normals,:]
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')

# %%
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-30,30), ylim=(-30,30), figsize=(6,6),
                    title="PCA of acetyl TMT normalized ratio (colored by group)")

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = purity_map.get(i, "Tumor")
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-30,30), ylim=(-30,30), figsize=(6,6),
                    title="PCA of acetyl TMT normalized ratio (colored by purity)")

# %%
group_map = dict()
for i in tumors_included + normals:
    # print(i)
    if i in tumors_included:
        group_map[i] = re.sub("[ABC]",'',stage_map.get(i, "Tumor"))
    elif i in normals:
        group_map[i] = "Normal"
    else:
        group_map[i] = "Other"
data2['Group'] = data2.index.map(group_map)
data2 = data2.sort_values(by='Group')
fig,pca = plot_pca1(data2, n=1, palette='bright', 
                    xlim=(-30,30), ylim=(-30,30), figsize=(6,6),
                    title="PCA of acetyl TMT normalized log2ratio (colored by stage)")
